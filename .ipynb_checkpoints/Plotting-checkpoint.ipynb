# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Seaborn Pairplot

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips = sns.load_dataset("tips")
sns.pairplot(tips, kind='reg')
#kind=reg adds trendline to scatter plots

# %%
sns.pairplot(tips)
#no kind=reg, no trendline

# %% [markdown]
# ## SNS Jointplot

# %%
#boston is a sklearn dataset
data = datasets.load_boston()

#printing data dictionary
print data.DESCR
#feature names, data (data for each feature name per each row), target = medv (median value)

# %%
print data.feature_names
print data.data[0]
print data.target[0]
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# [  6.32000000e-03   1.80000000e+01   2.31000000e+00   0.00000000e+00
#    5.38000000e-01   6.57500000e+00   6.52000000e+01   4.09000000e+00
#    1.00000000e+00   2.96000000e+02   1.53000000e+01   3.96900000e+02
#    4.98000000e+00]
# 24.0

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
targets = pd.DataFrame(data.target, columns=["MEDV"])
for i in df.columns.values:
    sns.jointplot(x=df[i], y=targets["MEDV"])

# %%
df_all = pd.concat([df, targets], axis=1, join_axes=[df.index])
sns.jointplot(x=df['RM'], y=targets['MEDV'])

# %% [markdown]
# ## Linear Regression ScatterPlot (Predictions vs. Actuals)

# %%
data = datasets.load_boston()
df = pd.DataFrame(data.data, columns=data.feature_names)
targets = pd.DataFrame(data.target, columns=["MEDV"])

lm = linear_model.LinearRegression()
X = df[["RM"]]
y = targets["MEDV"]
model = lm.fit(X, y)
predictions = lm.predict(X)
print "MSE:", mean_squared_error(y, predictions)

plt.figure(figsize=(6,3))
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted Values from RM")
plt.ylabel("Actual Values MEDV")
plt.show()
# Out:
# MSE: 43.6005517712

# %%
# Plot the residuals (y minus predictions)against y-hat. Do we have constant variance?
plt.figure(figsize=(6,3))
plt.scatter(predictions, y - predictions, c = 'b', marker = '+')
plt.axhline(0, color='r');
plt.xlabel("Predictions")
plt.ylabel("Residuals");
