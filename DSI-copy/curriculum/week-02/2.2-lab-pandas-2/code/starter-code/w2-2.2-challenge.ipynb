# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Let's use the Star Wars dataset again. Load it in and pull up the head.
#
# ```../../../1.2-study-design/assets/datasets/StarWars.csv```

# %%
df = pd.read_csv('/Users/kristensu/Dropbox/GA-DSI/DSI-copy/curriculum/week-02/2.2-lab-pandas-2/assets/datasets/StarWars.csv')

# %%
df.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %% [markdown]
# #### Create a hypothesis involving different subsections of the data.
#
# For example:
# - Are respondents more likely to respond "Han" to the question "Who shot first?" if they also say they are fans of Star Trek?
#
# Type your hypothesis in a markdown cell below:

# %% [markdown]
# Have you seen any of the 6 films in the Star Wars franchise?
# Hypothesis: People are more likely to respond 'No'

# %%
df['Have you seen any of the 6 films in the Star Wars franchise?'].unique()
# Out:
# array(['Response', 'Yes', 'No'], dtype=object)

# %%
df['Have you seen any of the 6 films in the Star Wars franchise?'].nunique()
# Out:
# 3

# %% [markdown]
# Use boolean indexing to create subsets of the data to support your hypothesis. See if you can answer questions using mutiple variables.

# %%
yes = df[df['Have you seen any of the 6 films in the Star Wars franchise?'].str.contains('Yes')]
yes
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# 30    3.292377e+09
# 31    3.292367e+09
# 32    3.292339e+09
# 33    3.292331e+09
# ...            ...
# 1148  3.288446e+09
# 1149  3.288445e+09
# 1150  3.288443e+09
# 1153  3.288429e+09
# 1155  3.288429e+09
# 1156  3.288428e+09
# 1157  3.288426e+09
# 1159  3.288423e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# ...

# %% [markdown]
# **Bonus** : Use matplotlib or seaborn to present your findings.

# %% [markdown]
# **Bonus 2** : Create another, more complex hypothesis, support it, and plot it below.
