# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline 

from sklearn import datasets
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import cross_val_predict

# %%
dfs = pd.read_csv('/Users/kristensu/dropbox/GA-DSI/DSI-copy/curriculum/week-03/5.1-regression-challenge/datasets/ranking-submission.csv')
dfc = pd.read_csv('/Users/kristensu/dropbox/GA-DSI/DSI-copy/curriculum/week-03/5.1-regression-challenge/datasets/challenge-dataset.csv')

# %%
dfc.loc[dfc['income'] == '-', 'income'] = 41.0 #MEDIAN of NON-DASHES
dfc['income'] = dfc['income'].astype(float)    
dfc['international_students'] = dfc['international_students'].str.replace('%', '')
dfc.loc[dfc['international_students'].isnull(), 'international_students'] = 13
dfc['international_students'] = dfc['international_students'].astype(float)
dfc.loc[dfc['international'] == '-', 'international'] = 50.3 #MEDIAN of NON-DASHES
dfc['international'] = dfc['international'].astype(float) 
dfc['world_rank'] = pd.to_numeric(dfc['world_rank'], errors='coerce')
dfc['world_rank'].fillna(value=100, inplace=True) # *100* = MEDIAN of NON-DASHES
dfc['world_rank'] = dfc['world_rank'].astype(int)
dfc['num_students'] = dfc['num_students'].str.replace(',', '')
dfc['num_students'] = dfc.loc[:, ['num_students']].astype(float)
dfc['num_students'] = dfc.loc[:, ['num_students']].astype(float)
dfc.loc[dfc['num_students'].isnull(), 'num_students'] = 20851.0 #MEDIAN of NON-NULLS
dfc.loc[dfc['student_staff_ratio'].isnull(), 'student_staff_ratio'] = 16.1 #MEDIAN of NON-NULLS

# %% [raw]
# dfc.dtypes

# %% [raw]
# dfc.columns

# %% [raw]
# train

# %% [raw]
# dfc.info()

# %%
cols = ['world_rank', 'teaching', 'research', 'total_score', 'year']
df2 = dfc.copy()[cols]
dfc_X = df2[(df2['total_score'] != '-') & (df2['total_score'].notnull())]
dfc_X.info()


dfc_u_2016 = dfc.copy()
dfc_u_2016 = dfc_u_2016['university_name'][(dfc_u_2016['year'] == 2016)]
dfc_train = dfc_X['total_score'].astype(float)
dfc_X.drop('total_score', axis=1, inplace=True)


dfc_X_2016 = df2[(df2['year'] == 2016)]
dfc_X_2016 =dfc_X_2016.drop('total_score', axis =1)
dfc_X_2016.info()
print dfc_X_2016['year'].unique()
#print dfc_X.dtypes
# train_cols = ['total_score']
# train = dfc_train.copy()[train_cols]

 
#print df2
sns.heatmap(df2.corr())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1001 entries, 0 to 1602
# Data columns (total 5 columns):
# world_rank     1001 non-null int64
# teaching       1001 non-null float64
# research       1001 non-null float64
# total_score    1001 non-null object
# year           1001 non-null int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 46.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1803 to 2602
# Data columns (total 4 columns):
# world_rank    800 non-null int64
# teaching      800 non-null float64
# research      800 non-null float64
# year          800 non-null int64
# dtypes: float64(2), int64(2)
# memory usage: 31.2 KB
# [2016]
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [raw]
# cols

# %% [raw]
# df2.isnull().sum()

# %% [raw]
# print y_pred

# %% [raw]
# print train

# %%
X = dfc_X
y =  dfc_train

lr = linear_model.LinearRegression()
lr_model = lr.fit(X,y)

y_pred = lr_model.predict(dfc_X_2016)
y_pred_df =  pd.DataFrame(y_pred)
pred = pd.Series(y_pred)

# %%
new = pd.concat([dfc_u_2016, dfc_X_2016],axis=1)
new.reset_index(drop=True, inplace=True)

# %%
pred_df = pred.to_frame('pred_score')
result_df = pd.concat([new,pred_df], axis = 1)
#result_df

"""dfLeft.reset_index(inplace=True)
dfRight.reset_index(inplace=True)
dfMerged = pd.merge(dfLeft, dfRight,
              left_on=['date', 'cusip'],
              right_on=['date', 'idc__id'],
              how='inner')
"""
dfLeft = dfs
dfRight = result_df
dfMerged = pd.merge(dfLeft, dfRight,
              left_on=['university_name'],
              right_on=['university_name'],
              how='inner')
dfMerged.info() 
dfs.info()
dfMerged.to_csv("/users/kristensu/Desktop/university_preds_SKJP.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 0 to 799
# Data columns (total 8 columns):
# world_rank_x       800 non-null object
# university_name    800 non-null object
# total_score        0 non-null float64
# world_rank_y       800 non-null int64
# teaching           800 non-null float64
# research           800 non-null float64
# year               800 non-null int64
# pred_score         800 non-null float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 56.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 3 columns):
# world_rank         800 non-null object
# university_name    800 non-null object
# total_score        0 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 18.8+ KB

# %%
type(pred)
# Out:
# pandas.core.series.Series

# %%
y.dtype
# Out:
# dtype('float64')

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
# world_rank                2603 non-null int64
# university_name           2603 non-null object
# country                   2603 non-null object
# teaching                  2603 non-null float64
# international             2603 non-null float64
# research                  2603 non-null float64
# citations                 2603 non-null float64
# income                    2603 non-null float64
# total_score               1803 non-null object
# num_students              2603 non-null float64
# student_staff_ratio       2603 non-null float64
# international_students    2603 non-null float64
# female_male_ratio         2370 non-null object
# year                      2603 non-null int64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 284.8+ KB

# %%
sns.regplot(x=y, y=y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-fda533f74f48> in <module>()
# ----> 1 sns.regplot(x=y, y=y_pred)
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     764                                  order, logistic, lowess, robust, logx,
#     765                                  x_partial, y_partial, truncate, dropna,
# --> 766                                  x_jitter, y_jitter, color, label)
#     767
#     768     if ax is None:
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     107         # Drop null observations
#     108         if dropna:
# --> 109             self.dropna("x", "y", "units", "x_partial", "y_partial")
#     110
#     111         # Regress nuisance variables out of the data
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in dropna(self, *vars)
#      56         vals = [getattr(self, var) for var in vars]
#      57         vals = [v for v in vals if v is not None]
# ---> 58         not_na = np.all(np.column_stack([pd.notnull(v) for v in vals]), axis=1)
#      59         for var in vars:
#      60             val = getattr(self, var)
#
# //anaconda/lib/python2.7/site-packages/numpy/lib/shape_base.pyc in column_stack(tup)
#     315             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     316         arrays.append(arr)
# --> 317     return _nx.concatenate(arrays, 1)
#     318
#     319 def dstack(tup):
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
dfs.head()
# Out:
#   world_rank                        university_name  total_score
# 0          1     California Institute of Technology          NaN
# 1          2                   University of Oxford          NaN
# 2          3                    Stanford University          NaN
# 3          4                University of Cambridge          NaN
# 4          5  Massachusetts Institute of Technology          NaN

# %%
dfc
# Out:
#       world_rank                                    university_name  \
# 0              1                                 Harvard University
# 1              2                 California Institute of Technology
# 2              3              Massachusetts Institute of Technology
# 3              4                                Stanford University
# 4              5                               Princeton University
# 5              6                            University of Cambridge
# 6              6                               University of Oxford
# 7              8                 University of California, Berkeley
# 8              9                            Imperial College London
# 9             10                                    Yale University
# 10            11              University of California, Los Angeles
# 11            12                              University of Chicago
# 12            13                           Johns Hopkins University
# 13            14                                 Cornell University
# 14            15  ETH Zurich � Swiss Federal Institute of Techno...
# 15            15                             University of Michigan
# 16            17                              University of Toronto
# 17            18                                Columbia University
# 18            19                         University of Pennsylvania
# 19            20                         Carnegie Mellon University
# 20            21                            University of Hong Kong
# 21            22                          University College London
# 22            23                           University of Washington
# 23            24                                    Duke University
# 24            25                            Northwestern University
# 25            26                                University of Tokyo
# 26            27                    Georgia Institute of Technology
# 27            28        Pohang University of Science and Technology
# 28            29            University of California, Santa Barbara
# 29            30                     University of British Columbia
# ...          ...                                                ...
# 2573         100                               University of Tehran
# 2574         100                     University of Texas at El Paso
# 2575         100                              Texas Tech University
# 2576         100                                   Tokai University
# 2577         100                               Tokushima University
# 2578         100  Tokyo University of Marine Science and Technology
# 2579         100                        Tokyo University of Science
# 2580         100                             Tomsk State University
# 2581         100                                 Tottori University
# 2582         100                 Toyohashi University of Technology
# 2583         100                     Universiti Kebangsaan Malaysia
# 2584         100                          Universiti Putra Malaysia
# 2585         100                          Universiti Sains Malaysia
# 2586         100                          Universiti Teknologi MARA
# 2587         100                            Ural Federal University
# 2588         100           V.N. Karazin Kharkiv National University
# 2589         100                                 University of Vigo
# 2590         100                                 Vilnius University
# 2591         100                    Warsaw University of Technology
# 2592         100                                  Waseda University
# 2593         100                         University of West Bohemia
# 2594         100                  University of the West of England
# 2595         100                       West University of Timi_oara
# 2596         100                          University of Westminster
# 2597         100                                  Xidian University
# 2598         100                                Yeungnam University
# 2599         100                        Y�ld�z Technical University
# 2600         100                           Yokohama City University
# 2601         100                       Yokohama National University
# 2602         100                                 Yuan Ze University
#
#                        country  teaching  international  research  citations  \
# 0     United States of America      99.7           72.4      98.7       98.8
# 1     United States of America      97.7           54.6      98.0       99.9
# 2     United States of America      97.8           82.3      91.4       99.9
# 3     United States of America      98.3           29.5      98.1       99.2
# 4     United States of America      90.9           70.3      95.4       99.9
# 5               United Kingdom      90.5           77.7      94.1       94.0
# 6               United Kingdom      88.2           77.2      93.9       95.1
# 7     United States of America      84.2           39.6      99.3       97.8
# 8               United Kingdom      89.2           90.0      94.5       88.3
# 9     United States of America      92.1           59.2      89.7       91.5
# 10    United States of America      83.0           48.1      92.9       93.2
# 11    United States of America      79.1           62.8      87.9       96.9
# 12    United States of America      80.9           58.5      89.2       92.3
# 13    United States of America      82.2           62.4      88.8       88.1
# 14                 Switzerland      77.5           93.7      87.8       83.1
# 15    United States of America      83.9           53.3      89.1       84.1
# 16                      Canada      75.8           50.3      87.9       82.2
# 17    United States of America      73.8           90.9      73.8       92.6
# 18    United States of America      71.8           32.9      82.7       93.6
# 19    United States of America      70.3           39.1      79.3       95.7
# 20                   Hong Kong      68.4           91.4      71.4       96.1
# 21              United Kingdom      74.0           90.8      81.6       80.6
# 22    United States of America      68.2           49.0      77.1       95.9
# 23    United States of America      66.8           49.4      71.5       92.3
# 24    United States of America      64.5           60.5      68.8       95.3
# 25                       Japan      87.7           18.4      91.9       58.1
# 26    United States of America      67.9           73.2      72.6       83.2
# 27                 South Korea      69.5           32.6      62.5       96.5
# 28    United States of America      56.6           64.3      68.0       98.8
# 29                      Canada      65.1           93.3      74.8       80.3
# ...                        ...       ...            ...       ...        ...
# 2573                      Iran      26.1           16.5      16.9       15.8
# 2574  United States of America      18.6           30.4      18.7       18.4
