# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Morning Exercise: Romans Numerals
# Week 6 | Exercise 1.0
#
# ![](http://blog.world-mysteries.com/wp-content/uploads/2012/02/gk_mtable.jpg)
#
# Take the Roman numerals from 1-1000. [Here's a lookup table](http://literacy.kent.edu/Minigrants/Cinci/romanchart.htm) if you need a refresher.
#
# 1. Write a function to_roman() that converts an integer to its value as a Roman numeral.
# 2. Write a function from_roman() that does the reverse: convert a string of Roman numerals to its integer value.
# 3. Submit each of your functions to Slack. Look at your classmates functions. See if you can find a way to break their code.
#
# Your functions should be able to handle integers from 1-1000 and return out the appropriate errors if the input is out of range, or of the wrong type.

# %%
def to_roman(number):

# %%
romans = ['M', 'CM', 'D', 'CD', 'C', 'XC', 'L', 'XL', 'X', 'IX', 'V', 'IV', 'I']
integers = [1000, 900, 500, 600, 100, 90, 50, 40, 10, 9, 5, 4, 1]
numbers_list = zip(integers,romans)
numbers_list
# Out:
# [(1000, 'M'),
#  (900, 'CM'),
#  (500, 'D'),
#  (600, 'CD'),
#  (100, 'C'),
#  (90, 'XC'),
#  (50, 'L'),
#  (40, 'XL'),
#  (10, 'X'),
#  (9, 'IX'),
#  (5, 'V'),
#  (4, 'IV'),
#  (1, 'I')]

# %%
for roman, integer in numbers_list:
    result = []
    count = int(50 / integer)
    print (count)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# 1
# 5
# 5
# 10
# 12
# 50

# %%
i = 50
for roman, integer in numbers_list:
    result = []
    count = int(i / integer)
    result.append(count)
    i -= integer * count
print i
print count
# Out:
# 0
# 0

# %%
result
# Out:
# [50]

# %%
def to_roman(i):
    result = []
    for roman, integer in numbers_list:
        count = int(i / integer)
        result.append(integer * count)
        i -= integer * count
    return ''.join(str(result))

# %%
to_roman(52)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-162-bb1d67c9499a> in <module>()
# ----> 1 to_roman(52)
#
# <ipython-input-161-bba8221f950b> in to_roman(i)
#       2     result = []
#       3     for roman, integer in numbers_list:
# ----> 4         count = int(i / integer)
#       5         result.append(integer * count)
#       6         i -= integer * count
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
x = 500
result = []
for i in integers:
    count = x/i
    print count
    for i in romans:
        print count * i
# Out:
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1
# M
# CM
# D
# CD
# C
# XC
# L
# XL
# X
# IX
# V
# IV
# I
# 0
#
#
#
#
#
#
#
#
#
#
#
#
#
# 5
# MMMMM
# CMCMCMCMCM
# DDDDD
# CDCDCDCDCD
# CCCCC
# XCXCXCXCXC
# LLLLL
# XLXLXLXLXL
# XXXXX
# IXIXIXIXIX
# VVVVV
# IVIVIVIVIV
# IIIII
# 5
# MMMMM
# CMCMCMCMCM
# DDDDD
# CDCDCDCDCD
# CCCCC
# XCXCXCXCXC
# LLLLL
# XLXLXLXLXL
# XXXXX
# IXIXIXIXIX
# VVVVV
# IVIVIVIVIV
# IIIII
# 10
# MMMMMMMMMM
# CMCMCMCMCMCMCMCMCMCM
# DDDDDDDDDD
# CDCDCDCDCDCDCDCDCDCD
# CCCCCCCCCC
# XCXCXCXCXCXCXCXCXCXC
# LLLLLLLLLL
# XLXLXLXLXLXLXLXLXLXL
# XXXXXXXXXX
# IXIXIXIXIXIXIXIXIXIX
# VVVVVVVVVV
# IVIVIVIVIVIVIVIVIVIV
# IIIIIIIIII
# 12
# MMMMMMMMMMMM
# CMCMCMCMCMCMCMCMCMCMCMCM
# DDDDDDDDDDDD
# CDCDCDCDCDCDCDCDCDCDCDCD
# CCCCCCCCCCCC
# XCXCXCXCXCXCXCXCXCXCXCXC
# LLLLLLLLLLLL
# XLXLXLXLXLXLXLXLXLXLXLXL
# XXXXXXXXXXXX
# IXIXIXIXIXIXIXIXIXIXIXIX
# VVVVVVVVVVVV
# IVIVIVIVIVIVIVIVIVIVIVIV
# IIIIIIIIIIII
# 50
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# CMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCM
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
# CDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCD
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# XCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXC
# LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL
# XLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXL
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# IXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIX
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# IVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIV
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# 55
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# CMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCM
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
# CDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCD
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# XCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXC
# LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL
# XLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXL
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# IXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIX
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# IVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIV
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# 100
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# CMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCM
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
# CDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCD
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# XCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXC
# LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL
# XLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXL
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# IXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIX
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# IVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIV
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# 125
# MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM
# CMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCMCM
# DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
# CDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCDCD
# CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC
# XCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXCXC
# LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL
# XLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXLXL
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# IXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIXIX
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV
# IVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIVIV
# IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# 500
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...

# %%
result
# Out:
# ['I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I', 'I']

# %%
def to_roman(i):
    result = []
    for integer, roman in numbers_list:
        count = int(i / integer)
        result.append(roman * count)
    i -= integer * count
    return ''.join(result)

to_roman(50)
# Out:
# 'LXLXXXXXIXIXIXIXIXVVVVVVVVVVIVIVIVIVIVIVIVIVIVIVIVIVIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII'

# %%
numbers_list
# Out:
# [(1000, 'M'),
#  (900, 'CM'),
#  (500, 'D'),
#  (600, 'CD'),
#  (100, 'C'),
#  (90, 'XC'),
#  (50, 'L'),
#  (40, 'XL'),
#  (10, 'X'),
#  (9, 'IX'),
#  (5, 'V'),
#  (4, 'IV'),
#  (1, 'I')]

# %%
for i in integers:
    print 501/i
# Out:
# 0
# 0
# 1
# 0
# 5
# 5
# 10
# 12
# 50
# 55
# 100
# 125
# 501

# %%
numbers_list
# Out:
# [(1000, 'M'),
#  (900, 'CM'),
#  (500, 'D'),
#  (600, 'CD'),
#  (100, 'C'),
#  (90, 'XC'),
#  (50, 'L'),
#  (40, 'XL'),
#  (10, 'X'),
#  (9, 'IX'),
#  (5, 'V'),
#  (4, 'IV'),
#  (1, 'I')]

# %%
def to_roman2(i):
    solution = []
    for integer, roman in numbers_list:
        count = int(i / integer)
        solution.append(roman * count)
        i -= integer * count
    return''.join(solution)

# %%
to_roman2(9)
# Out:
# 'IX'

# %%
romans = ['M', 'CM', 'D', 'CD', 'C', 'XC', 'L', 'XL', 'X', 'IX', 'V', 'IV', 'I']
integers = [1000, 900, 500, 600, 100, 90, 50, 40, 10, 9, 5, 4, 1]
numbers_list = zip(integers,romans)

def to_roman2(i):
    solution = []
    for integer, roman in numbers_list:
        count = int(i / integer)
        solution.append(roman * count)
        i -= integer * count
    return''.join(solution)

def to_roman(i):
    result = []
    if i == 0:
        print "Need number greater than 0"
    elif i < 0:
        i = -1*i
        return to_roman2(i)
    else:
        return to_roman2(i)

# %%
to_roman(865)
# Out:
# 'DCCCLXV'

# %%
def return_roman(number):
    new_number = str(number)
    new_number = list(new_number)
    if len(new_number) == 1:
        return_singles()new_number = number.split()
    if number <= 3:
        return 'I' * number
    elif 
    elif number == 5:
        return 'V'
    elif number <= 30 and number % 10 == 0:
        return (number/10) * 'X'
    else:
        pass

# %%
return_roman(30)
# Out:
# 'XXX'

# %%
number = 50
new_number = str(number)
new_number = list(new_number)
