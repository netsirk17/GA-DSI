# %% [markdown]
# ### Project 2 Requirements
#
# 1. Include a problem statement
# 2. State the risks and assumptions of your data
# 3. Import data using the Pandas library
# 4. Perform exploratory data analysis
# 5. Use Tableau and/or Python plotting modules to visualize data
# 6. Observe correlations in the data
# 7. Evaluate a hypothesis
# 8. Present results in a polished companion blog post of at least 500 words (& 1-2 graphics!)

# %% [markdown]
# ### Project 2 Deliverables
# 1. Jupyter Notebook analysis
# 2. Blog Post

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('/users/kristensu/dropbox/GA-DSI/DSI-copy/projects/projects-weekly/project-02/assets/billboard.csv')

# %%
#Examine raw data 1
print df.columns
print df.index
# Out:
# Index([u'year', u'artist.inverted', u'track', u'time', u'genre',
#        u'date.entered', u'date.peaked', u'x1st.week', u'x2nd.week',
#        u'x3rd.week', u'x4th.week', u'x5th.week', u'x6th.week', u'x7th.week',
#        u'x8th.week', u'x9th.week', u'x10th.week', u'x11th.week', u'x12th.week',
#        u'x13th.week', u'x14th.week', u'x15th.week', u'x16th.week',
#        u'x17th.week', u'x18th.week', u'x19th.week', u'x20th.week',
#        u'x21st.week', u'x22nd.week', u'x23rd.week', u'x24th.week',
#        u'x25th.week', u'x26th.week', u'x27th.week', u'x28th.week',
#        u'x29th.week', u'x30th.week', u'x31st.week', u'x32nd.week',
#        u'x33rd.week', u'x34th.week', u'x35th.week', u'x36th.week',
#        u'x37th.week', u'x38th.week', u'x39th.week', u'x40th.week',
#        u'x41st.week', u'x42nd.week', u'x43rd.week', u'x44th.week',
#        u'x45th.week', u'x46th.week', u'x47th.week', u'x48th.week',
#        u'x49th.week', u'x50th.week', u'x51st.week', u'x52nd.week',
#        u'x53rd.week', u'x54th.week', u'x55th.week', u'x56th.week',
#        u'x57th.week', u'x58th.week', u'x59th.week', u'x60th.week',
#        u'x61st.week', u'x62nd.week', u'x63rd.week', u'x64th.week',
#        u'x65th.week', u'x66th.week', u'x67th.week', u'x68th.week',
#        u'x69th.week', u'x70th.week', u'x71st.week', u'x72nd.week',
#        u'x73rd.week', u'x74th.week', u'x75th.week', u'x76th.week'],
#       dtype='object')
# RangeIndex(start=0, stop=317, step=1)

# %%
#Examine raw data 2
df.dtypes
# Out:
# year                int64
# artist.inverted    object
# track              object
# time               object
# genre              object
# date.entered       object
# date.peaked        object
# x1st.week           int64
# x2nd.week          object
# x3rd.week          object
# x4th.week          object
# x5th.week          object
# x6th.week          object
# x7th.week          object
# x8th.week          object
# x9th.week          object
# x10th.week         object
# x11th.week         object
# x12th.week         object
# x13th.week         object
# x14th.week         object
# x15th.week         object
# x16th.week         object
# x17th.week         object
# x18th.week         object
# x19th.week         object
# x20th.week         object
# x21st.week         object
# x22nd.week         object
# x23rd.week         object
#                     ...
# x47th.week         object
# x48th.week         object
# x49th.week         object
# x50th.week         object
# x51st.week         object
# x52nd.week         object
# x53rd.week         object
# x54th.week         object
# x55th.week         object
# x56th.week         object
# x57th.week         object
# x58th.week         object
# x59th.week         object
# x60th.week         object
# x61st.week         object
# x62nd.week         object
# x63rd.week         object
# x64th.week         object
# x65th.week         object
# x66th.week         object
# x67th.week         object
# x68th.week         object
# x69th.week         object
# x70th.week         object
# x71st.week         object
# x72nd.week         object
# x73rd.week         object
# x74th.week         object
# x75th.week         object
# x76th.week         object
# dtype: object

# %%
#Examine raw data 3
df.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# 0        63        49    ...              *          *          *          *
# 1         8         6    ...              *          *          *          *
# 2        48        43    ...              *          *          *          *
# 3        23        18    ...              *          *          *          *
# 4        47        45    ...              *          *          *          *
#
#   x71st.week x72nd.week x73rd.week x74th.week x75th.week x76th.week
# 0          *          *          *          *          *          *
# 1          *          *          *          *          *          *
# 2          *          *          *          *          *          *
# 3          *          *          *          *          *          *
# 4          *          *          *          *          *          *
#
# [5 rows x 83 columns]

# %%
#Examine raw data 4
df.describe()
# Out:
#          year   x1st.week
# count   317.0  317.000000
# mean   2000.0   79.958991
# std       0.0   14.686865
# min    2000.0   15.000000
# 25%    2000.0   74.000000
# 50%    2000.0   81.000000
# 75%    2000.0   91.000000
# max    2000.0  100.000000

# %%
#1: Replace all * with np.nan
def no_asterisk(x):
    if x == '*':
        return np.nan
    else:
        return x

df.applymap(no_asterisk)
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# 29   2000      Jordan, Montell
# ..    ...                  ...
# 287  2000              2Ge+her
# 288  2000       Madison Avenue
# 289  2000                  Eve
# 290  2000          Limp Bizkit
# 291  2000      Spencer, Tracie
# 292  2000            Nu Flavor
# 293  2000                Tamar
# 294  2000       Levert, Gerald
# 295  2000           Hart, Beth
# 296  2000          Diffie, Joe
# 297  2000      Funkmaster Flex
# 298  2000         Price, Kelly
# 299  2000             En Vogue
# 300  2000          Herndon, Ty
# 301  2000            Anastacia
# 302  2000                Trina
# 303  2000              Lil' Mo
# 304  2000              A*Teens
# 305  2000        Sheist, Shade
# 306  2000           De La Soul
# 307  2000       Larrieux, Amel
# 308  2000        Braxton, Toni
# 309  2000              Tuesday
# 310  2000            LL Cool J
# 311  2000             Master P
# 312  2000     Ghostface Killah
# 313  2000          Smith, Will
# 314  2000        Zombie Nation
# 309         Rock   December 30, 2000   December 30, 2000         98        98
# 310          Rap     August 12, 2000     August 19, 2000         99        98
# 311          Rap   November 18, 2000   November 18, 2000         98       NaN
# 312        R & B      August 5, 2000      August 5, 2000         98       NaN
# 313          Rap   February 12, 2000   February 12, 2000         99        99
# 314         Rock   September 2, 2000   September 2, 2000         99        99
# 315          Rap        July 1, 2000        July 1, 2000         99        99
# 316        R & B    October 28, 2000    October 28, 2000         99       NaN
#
#     x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# 0          49    ...            NaN        NaN        NaN        NaN
# 1           6    ...            NaN        NaN        NaN        NaN
# 2          43    ...            NaN        NaN        NaN        NaN
# 3          18    ...            NaN        NaN        NaN        NaN
# 4          45    ...            NaN        NaN        NaN        NaN
# 5          43    ...            NaN        NaN        NaN        NaN
# 6          44    ...            NaN        NaN        NaN        NaN
# 7          34    ...            NaN        NaN        NaN        NaN
# 8          61    ...            NaN        NaN        NaN        NaN
# 9          44    ...            NaN        NaN        NaN        NaN
# 10         51    ...            NaN        NaN        NaN        NaN
# 11         28    ...            NaN        NaN        NaN        NaN
# 12         53    ...            NaN        NaN        NaN        NaN
# 13         76    ...            NaN        NaN        NaN        NaN
# 14         38    ...            NaN        NaN        NaN        NaN
# 15         29    ...            NaN        NaN        NaN        NaN
# 16         50    ...            NaN        NaN        NaN        NaN
# 17         62    ...            NaN        NaN        NaN        NaN
# 18         52    ...            NaN        NaN        NaN        NaN
# 19         81    ...            NaN        NaN        NaN        NaN
# 20         48    ...            NaN        NaN        NaN        NaN
# 21         50    ...            NaN        NaN        NaN        NaN
# 22         34    ...            NaN        NaN        NaN        NaN
# 23         65    ...            NaN        NaN        NaN        NaN
# 24         68    ...            NaN        NaN        NaN        NaN
# 25         35    ...            NaN        NaN        NaN        NaN
# 26         30    ...            NaN        NaN        NaN        NaN
# 27         44    ...            NaN        NaN        NaN        NaN
# 28         69    ...            NaN        NaN        NaN        NaN
# 29         72    ...            NaN        NaN        NaN        NaN
# ..        ...    ...            ...        ...        ...        ...
# 287        92    ...            NaN        NaN        NaN        NaN
# 288        93    ...            NaN        NaN        NaN        NaN
# 289        88    ...            NaN        NaN        NaN        NaN
# 290        90    ...            NaN        NaN        NaN        NaN
# 291        98    ...            NaN        NaN        NaN        NaN
# 292        89    ...            NaN        NaN        NaN        NaN
# 293        92    ...            NaN        NaN        NaN        NaN
# 294        92    ...            NaN        NaN        NaN        NaN
# 295        98    ...            NaN        NaN        NaN        NaN
# 296       100    ...            NaN        NaN        NaN        NaN
# 297        95    ...            NaN        NaN        NaN        NaN
# 298        98    ...            NaN        NaN        NaN        NaN
# 299        97    ...            NaN        NaN        NaN        NaN
# 300        99    ...            NaN        NaN        NaN        NaN
# 301       NaN    ...            NaN        NaN        NaN        NaN
# 302        96    ...            NaN        NaN        NaN        NaN
# 303        97    ...            NaN        NaN        NaN        NaN
# 304        96    ...            NaN        NaN        NaN        NaN
# 305        99    ...            NaN        NaN        NaN        NaN
# 314        NaN        NaN        NaN        NaN        NaN        NaN
# 315        NaN        NaN        NaN        NaN        NaN        NaN
# 316        NaN        NaN        NaN        NaN        NaN        NaN
#
# [317 rows x 83 columns]

# %%
#2: Reformat 'time' and convert from dtype object to timedelta in seconds
df['time'] = df['time'].str.replace(',',':')
df['time'] = df['time'].str.strip('AM')
df['time'] = pd.to_timedelta(df['time'], unit = 's')

# %%
df['time'].head()
# Out:
# 0   03:38:00
# 1   04:18:00
# 2   04:07:00
# 3   03:45:00
# 4   03:38:00
# Name: time, dtype: timedelta64[ns]

# %%
#3: Convert dates ('date.entered', 'date.peaked') from dtype object to datetime
df['date.entered'] = pd.to_datetime(df['date.entered'], infer_datetime_format=True)
df['date.peaked'] = pd.to_datetime(df['date.peaked'], infer_datetime_format=True)

# %%
print df['date.entered'].head(3)
print df['date.peaked'].head(3)
# Out:
# 0   2000-09-23
# 1   2000-02-12
# 2   1999-10-23
# Name: date.entered, dtype: datetime64[ns]
# 0   2000-11-18
# 1   2000-04-08
# 2   2000-01-29
# Name: date.peaked, dtype: datetime64[ns]

# %%
#4: Rename 'artist.inverted' column to 'artist' 
df.rename(columns={'artist.inverted':'artist'}, inplace=True)
df['artist'].head(3)
# Out:
# 0    Destiny's Child
# 1            Santana
# 2      Savage Garden
# Name: artist, dtype: object

# %%
#5: Rename all column names with '.' to '_'
df.columns = [x.replace('.', '_') for x in df.columns]
df.columns.values
# Out:
# array(['year', 'artist', 'track', 'time', 'genre', 'date_entered',
#        'date_peaked', 'x1st_week', 'x2nd_week', 'x3rd_week', 'x4th_week',
#        'x5th_week', 'x6th_week', 'x7th_week', 'x8th_week', 'x9th_week',
#        'x10th_week', 'x11th_week', 'x12th_week', 'x13th_week',
#        'x14th_week', 'x15th_week', 'x16th_week', 'x17th_week',
#        'x18th_week', 'x19th_week', 'x20th_week', 'x21st_week',
#        'x22nd_week', 'x23rd_week', 'x24th_week', 'x25th_week',
#        'x26th_week', 'x27th_week', 'x28th_week', 'x29th_week',
#        'x30th_week', 'x31st_week', 'x32nd_week', 'x33rd_week',
#        'x34th_week', 'x35th_week', 'x36th_week', 'x37th_week',
#        'x38th_week', 'x39th_week', 'x40th_week', 'x41st_week',
#        'x42nd_week', 'x43rd_week', 'x44th_week', 'x45th_week',
#        'x46th_week', 'x47th_week', 'x48th_week', 'x49th_week',
#        'x50th_week', 'x51st_week', 'x52nd_week', 'x53rd_week',
#        'x54th_week', 'x55th_week', 'x56th_week', 'x57th_week',
#        'x58th_week', 'x59th_week', 'x60th_week', 'x61st_week',
#        'x62nd_week', 'x63rd_week', 'x64th_week', 'x65th_week',
#        'x66th_week', 'x67th_week', 'x68th_week', 'x69th_week',
#        'x70th_week', 'x71st_week', 'x72nd_week', 'x73rd_week',
#        'x74th_week', 'x75th_week', 'x76th_week'], dtype=object)

# %%
#6: Convert week columns from dtype object to dtype numeric
for i in range(7,len(df.columns)):
    df[df.columns[i]] = pd.to_numeric(df[df.columns[i]],errors='coerce')

# %%
df.dtypes
# Out:
# year                      int64
# artist                   object
# track                    object
# time            timedelta64[ns]
# genre                    object
# date_entered     datetime64[ns]
# date_peaked      datetime64[ns]
# x1st_week                 int64
# x2nd_week               float64
# x3rd_week               float64
# x4th_week               float64
# x5th_week               float64
# x6th_week               float64
# x7th_week               float64
# x8th_week               float64
# x9th_week               float64
# x10th_week              float64
# x11th_week              float64
# x12th_week              float64
# x13th_week              float64
# x14th_week              float64
# x15th_week              float64
# x16th_week              float64
# x17th_week              float64
# x18th_week              float64
# x19th_week              float64
# x20th_week              float64
# x21st_week              float64
# x22nd_week              float64
# x23rd_week              float64
#                      ...
# x47th_week              float64
# x48th_week              float64
# x49th_week              float64
# x50th_week              float64
# x51st_week              float64
# x52nd_week              float64
# x53rd_week              float64
# x54th_week              float64
# x55th_week              float64
# x56th_week              float64
# x57th_week              float64
# x58th_week              float64
# x59th_week              float64
# x60th_week              float64
# x61st_week              float64
# x62nd_week              float64
# x63rd_week              float64
# x64th_week              float64
# x65th_week              float64
# x66th_week              float64
# x67th_week              float64
# x68th_week              float64
# x69th_week              float64
# x70th_week              float64
# x71st_week              float64
# x72nd_week              float64
# x73rd_week              float64
# x74th_week              float64
# x75th_week              float64
# x76th_week              float64
# dtype: object

# %%
#7a: Determine what genre names are
print df['genre'].nunique()
print df['genre'].unique()
print ""
print df['genre'].value_counts()
# Out:
# 12
# ['Rock' "Rock'n'roll" 'Latin' 'Country' 'Rap' 'Pop' 'Electronica' 'Jazz'
#  'R&B' 'Reggae' 'Gospel' 'R & B']
#
# Rock           103
# Country         74
# Rap             58
# Rock'n'roll     34
# R&B             13
# R & B           10
# Pop              9
# Latin            9
# Electronica      4
# Gospel           1
# Jazz             1
# Reggae           1
# Name: genre, dtype: int64

# %%
#7b: Consolidate genre names
df['genre'].replace("Rock'n'roll", 'Rock', inplace=True)
df['genre'].replace('R & B', 'R&B', inplace=True)
print df['genre'].value_counts()
# Out:
# Rock           137
# Country         74
# Rap             58
# R&B             23
# Pop              9
# Latin            9
# Electronica      4
# Gospel           1
# Jazz             1
# Reggae           1
# Name: genre, dtype: int64

# %%
#8: Examine how many artists there are and how often each appears in df
#To determine if there are artists with multiple hits
df['artist'].value_counts()
# Out:
# Jay-Z                           5
# Houston, Whitney                4
# Dixie Chicks, The               4
# DMX                             3
# Aguilera, Christina             3
# McGraw, Tim                     3
# Backstreet Boys, The            3
# Thomas, Carl                    3
# N'Sync                          3
# Destiny's Child                 3
# SheDaisy                        3
# Sisqo                           3
# Braxton, Toni                   3
# Limp Bizkit                     3
# Price, Kelly                    3
# Spears, Britney                 3
# Rimes, LeAnn                    3
# Eminem                          3
# Lonestar                        3
# Martin, Ricky                   3
# Jackson, Alan                   3
# Jagged Edge                     2
# McEntire, Reba                  2
# 3 Doors Down                    2
# D'Angelo                        2
# Eve                             2
# Nine Days                       2
# Anthony, Marc                   2
# Paisley, Brad                   2
# Hill, Faith                     2
#                                ..
# Bega, Lou                       1
# Griggs, Andy                    1
# 2Ge+her                         1
# Kenny G                         1
# Gill, Vince                     1
# Stone, Angie                    1
# Moore, Mandy                    1
# Nas                             1
# R.E.M.                          1
# Next                            1
# Sammie                          1
# Cagle, Chris                    1
# Ja Rule                         1
# Lil Bow Wow                     1
# Black Rob                       1
# Moore, Chante                   1
# Tippin, Aaron                   1
# Drama                           1
# LL Cool J                       1
# Carter, Torrey                  1
# Trina                           1
# Papa Roach                      1
# Musiq                           1
# Anastacia                       1
# Master P                        1
# Elliott, Missy "Misdemeanor"    1
# Lil' Mo                         1
# Bon Jovi                        1
# Goo Goo Dolls                   1
# Clark Family Experience         1
# Name: artist, dtype: int64

# %%
df.head()
# Out:
#    year               artist                                  track     time  \
# 0  2000      Destiny's Child               Independent Women Part I 03:38:00
# 1  2000              Santana                           Maria, Maria 04:18:00
# 2  2000        Savage Garden                     I Knew I Loved You 04:07:00
# 3  2000              Madonna                                  Music 03:45:00
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You) 03:38:00
#
#   genre date_entered date_peaked  x1st_week  x2nd_week  x3rd_week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
#    x67th_week  x68th_week  x69th_week  x70th_week  x71st_week  x72nd_week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x73rd_week  x74th_week  x75th_week  x76th_week
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 83 columns]

# %%
#8: Reshape the data so that weeks become consolidated into one column (instead of each week spread as its own column)/
# and each week's rank becomes its own column
ndf = pd.melt(df, id_vars=['year', 'artist', 'track', 'time', 'genre', 'date_entered', 'date_peaked'], \
        var_name='week', value_name='list_rank')

# %%
ndf.head()
# Out:
#    year               artist                                  track     time  \
# 0  2000      Destiny's Child               Independent Women Part I 03:38:00
# 1  2000              Santana                           Maria, Maria 04:18:00
# 2  2000        Savage Garden                     I Knew I Loved You 04:07:00
# 3  2000              Madonna                                  Music 03:45:00
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You) 03:38:00
#
#   genre date_entered date_peaked       week  list_rank
# 0  Rock   2000-09-23  2000-11-18  x1st_week       78.0
# 1  Rock   2000-02-12  2000-04-08  x1st_week       15.0
# 2  Rock   1999-10-23  2000-01-29  x1st_week       71.0
# 3  Rock   2000-08-12  2000-09-16  x1st_week       41.0
# 4  Rock   2000-08-05  2000-10-14  x1st_week       57.0

# %%
#9: Reformat 'week' from dtype object to int
ndf['week'] = ndf['week'].str.extract('x(\d+)').astype(int)
ndf['week'].head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   from ipykernel import kernelapp as app
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: week, dtype: int64

# %%
#10: Sort the df by artist, track and then week
ndf.sort_values(by=['artist','track','week'], inplace=True)
ndf.head()
# Out:
#       year artist                                track     time genre  \
# 246   2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 563   2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 880   2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 1197  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 1514  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
#
#      date_entered date_peaked  week  list_rank
# 246    2000-02-26  2000-03-11     1       87.0
# 563    2000-02-26  2000-03-11     2       82.0
# 880    2000-02-26  2000-03-11     3       72.0
# 1197   2000-02-26  2000-03-11     4       77.0
# 1514   2000-02-26  2000-03-11     5       87.0

# %%
#Double check to see sort worked properly
ndf.iloc[145:155,:]
# Out:
#        year        artist                                              track  \
# 22160  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 22477  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 22794  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 23111  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 23428  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 23745  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 24062  2000       2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 24     2000  3 Doors Down                                         Kryptonite
# 341    2000  3 Doors Down                                         Kryptonite
# 658    2000  3 Doors Down                                         Kryptonite
#
#           time genre date_entered date_peaked  week  list_rank
# 22160 03:15:00   R&B   2000-09-02  2000-09-09    70        NaN
# 22477 03:15:00   R&B   2000-09-02  2000-09-09    71        NaN
# 22794 03:15:00   R&B   2000-09-02  2000-09-09    72        NaN
# 23111 03:15:00   R&B   2000-09-02  2000-09-09    73        NaN
# 23428 03:15:00   R&B   2000-09-02  2000-09-09    74        NaN
# 23745 03:15:00   R&B   2000-09-02  2000-09-09    75        NaN
# 24062 03:15:00   R&B   2000-09-02  2000-09-09    76        NaN
# 24    03:53:00  Rock   2000-04-08  2000-11-11     1       81.0
# 341   03:53:00  Rock   2000-04-08  2000-11-11     2       70.0
# 658   03:53:00  Rock   2000-04-08  2000-11-11     3       68.0

# %%
#Reshaping the df with pd.melt expanded in index range from 317 to 24092 (since each weekly column became) /
#its own row for each track
ndf.index
# Out:
# Int64Index([  246,   563,   880,  1197,  1514,  1831,  2148,  2465,  2782,
#              3099,
#             ...
#             20937, 21254, 21571, 21888, 22205, 22522, 22839, 23156, 23473,
#             23790],
#            dtype='int64', length=24092)

# %%
#11: Drop all the rows in the df that have NaN values
ndf.dropna(inplace=True)
ndf.iloc[145:155,:]
# Out:
#       year   artist          track     time genre date_entered date_peaked  \
# 6158  2000  Aaliyah  I Don't Wanna 04:15:00  Rock   2000-01-29  2000-03-04
# 14    2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 331   2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 648   2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 965   2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 1282  2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 1599  2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 1916  2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 2233  2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
# 2550  2000  Aaliyah      Try Again 04:03:00  Rock   2000-03-18  2000-06-17
#
#       week  list_rank
# 6158    20       86.0
# 14       1       59.0
# 331      2       53.0
# 648      3       38.0
# 965      4       28.0
# 1282     5       21.0
# 1599     6       18.0
# 1916     7       16.0
# 2233     8       14.0
# 2550     9       12.0

# %%
#Dropping NaN values reduced index length from 24092 to 5307
ndf.index
# Out:
# Int64Index([  246,   563,   880,  1197,  1514,  1831,  2148,   287,   604,
#               921,
#             ...
#              9208,  9525,  9842, 10159, 10476, 10793, 11110, 11427, 11744,
#             12061],
#            dtype='int64', length=5307)

# %%
#12: Create a column that gives the date of each week listed in 'week' column 
#This also makes date formats comparable for plotting
ndf['week_date'] = ndf['date_entered'] + pd.TimedeltaIndex(ndf['week'] - 1, unit='W')

# %%
ndf.head(3)
# Out:
#      year artist                                track     time genre  \
# 246  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 563  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 880  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
#
#     date_entered date_peaked  week  list_rank  week_date
# 246   2000-02-26  2000-03-11     1       87.0 2000-02-26
# 563   2000-02-26  2000-03-11     2       82.0 2000-03-04
# 880   2000-02-26  2000-03-11     3       72.0 2000-03-11

# %%
#13: Create a column that gives the time to took for a track from entering the charts to peaking
ndf['to_peak'] = (ndf['date_peaked'] - ndf['date_entered']).apply(lambda x: x).astype(np.timedelta64(1,'W'))

# %%
ndf.head(5)
# Out:
#       year artist                                track     time genre  \
# 246   2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 563   2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 880   2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 1197  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
# 1514  2000  2 Pac  Baby Don't Cry (Keep Ya Head Up II) 04:22:00   Rap
#
#      date_entered date_peaked  week  list_rank  week_date  to_peak
# 246    2000-02-26  2000-03-11     1       87.0 2000-02-26  14 days
# 563    2000-02-26  2000-03-11     2       82.0 2000-03-04  14 days
# 880    2000-02-26  2000-03-11     3       72.0 2000-03-11  14 days
# 1197   2000-02-26  2000-03-11     4       77.0 2000-03-18  14 days
# 1514   2000-02-26  2000-03-11     5       87.0 2000-03-25  14 days

# %%
ndf['to_peak'] = ndf['to_peak'].astype(np.timedelta64(1,'W'))

# %%
ndf['to_peak'].dtype
# Out:
# dtype('<m8[W]')

# %%
ndf.dtypes
# Out:
# year                      int64
# artist                   object
# track                    object
# time            timedelta64[ns]
# genre                    object
# date_entered     datetime64[ns]
# date_peaked      datetime64[ns]
# week                      int64
# list_rank               float64
# week_date        datetime64[ns]
# to_peak          timedelta64[W]
# dtype: object

# %%
ndf['to_peak'] = (ndf['date_peaked'] - ndf['date_entered']).apply(lambda x: x/np.timedelta64(1,'W'))

# %%
ndf.dtypes
# Out:
# year                      int64
# artist                   object
# track                    object
# time            timedelta64[ns]
# genre                    object
# date_entered     datetime64[ns]
# date_peaked      datetime64[ns]
# week                      int64
# list_rank               float64
# week_date        datetime64[ns]
# to_peak                 float64
# dtype: object

# %%
#pivot for no. of weeks on chart, for tracks, genres, time

max_week_tracks = pd.pivot_table(ndf, index=["track"], values=['week'], aggfunc=np.max) 
max_week_tracks.sort_values(by = ['week'], inplace=True)

max_week_genre = pd.pivot_table(ndf, index=["genre"], values=['week'], aggfunc=np.max) 
max_week_genre.sort_values(by = ['week'], inplace=True)

max_week_time = pd.pivot_table(ndf, index=["time"], values=['week'], aggfunc=np.max) 
max_week_time.sort_values(by = ['week'], inplace=True)

# %%
# pivot for change in rank, for genres/track and rank

delta_peak_genre_tracks = pd.pivot_table(ndf, index=['genre','track'], values=['list_rank'], \
                                                                   aggfunc=[np.amin, np.amax] ) 
delta_peak_genre_tracks.reset_index()
delta_peak_genre_tracks['difference'] = delta_peak_genre_tracks['amax'] - \
                                                                delta_peak_genre_tracks['amin'] 

delta_peak_genre_tracks.head()
# Out:
#                                        amin      amax difference
#                                   list_rank list_rank
# genre   track
# Country A Country Boy Can Survive      75.0      93.0       18.0
#         A Little Gasoline              75.0      99.0       24.0
#         Amazed                          1.0      81.0       80.0
#         Another Nine Minutes           74.0      95.0       21.0
#         Back At One                    36.0      99.0       63.0

# %%
# pivot for change in rank and time

delta_peak_time = pd.pivot_table(ndf, index=["time"], values=['list_rank'], \
                                                                   aggfunc=[np.amin, np.amax] ) 
delta_peak_time.reset_index()

delta_peak_time['difference'] = delta_peak_time['amax'] - delta_peak_time['amin']

delta_peak_time.head()
# Out:
#               amin      amax difference
#          list_rank list_rank
# time
# 02:36:00      45.0      99.0       54.0
# 02:38:00      23.0      78.0       55.0
# 02:52:00       6.0      89.0       83.0
# 02:53:00      37.0      99.0       62.0
# 02:55:00      40.0     100.0       60.0

# %%
#pivot for average no. of weeks on chart, for time

#avg_max_week_genre.sort_values(by = ['week'], inplace=True)
avg_max_week_time = pd.pivot_table(ndf, index=["time"], values=['week']) 
avg_max_week_time.sort_values(by = ['week'], inplace=True)

avg_max_week_time.head()
# Out:
#               week
# time
# 05:02:00  2.000000
# 03:58:00  2.166667
# 06:17:00  2.500000
# 05:10:00  2.500000
# 07:50:00  3.000000

# %%
# pivot for avg. number of weeks rise to peak by tracks

avg_week_to_peak_tracks = pd.pivot_table(ndf, index=["track"], values=['to_peak']) 
avg_week_to_peak_tracks.sort_values(by = ['to_peak'], inplace=True)
avg_week_to_peak_tracks.reset_index()

avg_week_to_peak_tracks.tail()
# Out:
#                    to_peak
# track
# I Wanna Know          26.0
# Sexual (Li Da Di)     30.0
# Kryptonite            31.0
# Amazed                39.0
# Higher                45.0

# %%
# pivot for avg. number of weeks rise to peak by genres
avg_week_to_peak_genre = pd.pivot_table(ndf, index=["genre"], values=['to_peak']) 
avg_week_to_peak_genre.sort_values(by = ['to_peak'], inplace=True)
avg_week_to_peak_genre.reset_index()
# Out:
#          genre    to_peak
# 0         Jazz   2.000000
# 1          R&B   5.494253
# 2       Reggae   6.000000
# 3       Gospel   8.000000
# 4          Pop   8.401460
# 5          Rap   8.575866
# 6  Electronica   8.611111
# 7      Country  10.339167
# 8        Latin  10.664740
# 9         Rock  11.255508

# %%
# pivot for avg. number of weeks rise to peak by time
avg_week_to_peak_time = pd.pivot_table(ndf, index=["time"], values=['to_peak']) 
avg_week_to_peak_time.sort_values(by = ['to_peak'], inplace=True)
avg_week_to_peak_time.reset_index()

avg_week_to_peak_time.tail()
# Out:
#             to_peak
# time
# 04:01:00  23.295455
# 04:38:00  23.589744
# 03:53:00  31.000000
# 04:25:00  39.000000
# 05:16:00  45.000000

# %%
def my_pivot(df, index, values, aggfunc, plt=False):
    piv = pd.pivot_table(df, index=index, values=values, aggfunc=aggfunc)
    #piv.sort_values(by = ['week'], inplace=True)
    #print piv
    if plt: piv.plot(title= 'Number of Weeks on BB Top 100 Chart',kind='hist', figsize=(8,4),\
                         bins=13, xticks=[5,10,15,20,25,30,35,40,45,50,55,60,65], legend=False)

my_pivot(ndf, index=["track"], values=['week'], aggfunc=np.max, plt=True)

# %%
def my_pivot_rise(df, index, values, aggfunc, plt=False):
    piv = pd.pivot_table(df, index=index, values=values, aggfunc=aggfunc)
    #piv.sort_values(by = ['week'], inplace=True)
    #print piv
    if plt: piv.plot(title= 'Time (in weeks) to reach peak position', kind='hist', \
        figsize=(8,4), bins=13, xticks=[5,10,15,20,25,30,35,40,45,50,55,60,65], legend=False)


my_pivot_rise(ndf, index=["track"], values=['to_peak'], aggfunc=np.max, plt=True)

# %%
max_week_genre['week'].plot(kind='bar',figsize = (10,4), fontsize = 12, \
            title = 'Avg. Amount of Time (Weeks) Spent on BB 100 chart by genre', color = 'red')
