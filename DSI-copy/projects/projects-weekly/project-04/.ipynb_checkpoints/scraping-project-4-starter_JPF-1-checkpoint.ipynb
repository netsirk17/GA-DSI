# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Webscraping Project 4 Lab
#
# Week 4 | Day 4

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com (or other sites at your team's discretion). In the second part, the focus is on using listings with salary information to build a model and predict high or low salaries and what features are predictive of that result.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist&l=New+York&start=20"
#URL = "http://www.indeed.com/viewjob?cmp=StreetID&t=Quantitative+Analyst&jk=7310f6c4a3e64d86&q=data+scientist+%2420%2C000"
#URL = "http://www.indeed.com/cmp/The-Real-Deal/jobs/Research-Analyst-f7ca8bb533116aa5?sjdu=Zzi_VW2ygsY1fzh3Ma9ZsPaqOkFrOZiF9heaw3NaNTj0OQvZGGtRbaXwwfcz5j-Cmo2b5pswEqp4hwhkngvpEg"
#URL = "http://www.indeed.com/viewjob?cmp=DTS&t=Senior+Machine+Learning+Data+Engineer&jk=52f498ef4a67d884&q=data+scientist+%2420%2C000"

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
## YOUR CODE HERE
import requests
import bs4
from bs4 import BeautifulSoup
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium import webdriver

dcap = dict(DesiredCapabilities.PHANTOMJS)
dcap["phantomjs.page.settings.userAgent"] = (
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36"
)

driver = webdriver.PhantomJS(executable_path='/Applications/anaconda/anaconda/bin/phantomJS', desired_capabilities=dcap)
driver.set_window_size(1024, 768) 

URL = "http://www.indeed.com/jobs?q=data+scientist&l=New+York&start=20"

driver.get(URL)
page_html = driver.page_source
soup = BeautifulSoup(page_html, "lxml")
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-3-aa71c7f3c8a3> in <module>()
#      11 )
#      12
# ---> 13 driver = webdriver.PhantomJS(executable_path='/Applications/anaconda/anaconda/bin/phantomJS', desired_capabilities=dcap)
#      14 driver.set_window_size(1024, 768)
#      15
#
# //anaconda/lib/python2.7/site-packages/selenium/webdriver/phantomjs/webdriver.pyc in __init__(self, executable_path, port, desired_capabilities, service_args, service_log_path)
#      50             service_args=service_args,
#      51             log_path=service_log_path)
# ---> 52         self.service.start()
#      53
#      54         try:
#
# //anaconda/lib/python2.7/site-packages/selenium/webdriver/common/service.pyc in start(self)
#      69                 raise WebDriverException(
#      70                     "'%s' executable needs to be in PATH. %s" % (
# ---> 71                         os.path.basename(self.path), self.start_error_message)
#      72                 )
#      73             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'phantomJS' executable needs to be in PATH.

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above
# - Include any other features you may want to use later (e.g. summary, #of reviews...)

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# ### Complete the following code to collect results from multiple cities and starting points.
# - Indeed.com only has salary information for an estimated 20% of job postings. You may want to add other cities to the list below to gather more data.
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
################################################################
############### EDIT THESE CONSTANTS
############### 
###############        EDIT THESE CONSTANTS

MAX_RESULTS_PER_CITY = 1000      ### DO NOT SET MORE THAN 1000
URL_SEARCH_TERM = 'Data Scientist' ### DO NOT SET MORE THAN SINGLE SEARCH TERM (TITLE)
CITY_SET = ['New York', 'Chicago', 'San Francisco', 'Austin', 'Atlanta', '', 'Boston', 'Seattle'\
            'Los Angeles','Washington, DC', 'San Jose','Denver', 'Atlanta','Houston',\
            'Dallas','Nashville','San Diego','Cleveland','Minneapolis','Baltimore','Philadelphia','Detroit']
###############
################################################################


import requests
import bs4
import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium import webdriver
import datetime
import urllib

def extract_location_from_resultRow(result):
    try:
        location = (result.find(class_='location').text.strip())
    except:
        location = ''
    return location

def extract_company_from_resultRow(result):
    try:
        company = (result.find(class_='company').text.strip())
    except:
        company = ''
    return company

def extract_jkid_from_resultRow(result):
    try:
        row = (result.find(class_='jobtitle turnstileLink'))
        jkid = result['data-jk']
    except: 
        jkid = ''
    return jkid

def extract_title_from_resultRow(result):
    try:
        title = (result.find(class_='turnstileLink'))
        title_text = title.text
    except: 
        title_text = ''
    return title_text

def extract_salary_from_resultRow(result):
    try:
        salary = (result.find(class_='snip').find('nobr').text)
    except:
        salary = ''
    salary_text = salary
    return salary_text

def extract_reviews_from_resultRow(result):
    try:
        reviews = (result.find(class_='slNoUnderline').text.strip().strip(' reviews').replace(',',''))
    except: 
        reviews = ''
    return reviews

def extract_stars_from_resultRow(result):
    try: 
        stars = (result.find(class_='rating')['style']).split(';background-position:')[1].split(':')[1].split('px')[0].strip()
    except: 
        stars = ''
    return stars

def extract_date_from_resultRow(result):
    try: 
        date = (result.find(class_='date').text.strip(' ago').strip())
    except: 
        date = ''
    return date

def extract_summary_from_resultRow(result):
    try: 
        summary = (result.find("span", {"itemprop" : "description"}).text.strip())
    except: 
        summary = ''
    return summary

dcap = dict(DesiredCapabilities.PHANTOMJS)
dcap["phantomjs.page.settings.userAgent"] = ("Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36")

driver = webdriver.PhantomJS(executable_path='/Applications/anaconda/anaconda/bin/phantomJS', desired_capabilities=dcap)
driver.set_window_size(1024, 768) 

for city in CITY_SET:
    job_dict = []
    now = datetime.datetime.now()
    for start in range(0, MAX_RESULTS_PER_CITY, 10):

        URL = "http://www.indeed.com/jobs?q="+urllib.quote(URL_SEARCH_TERM)+"&l="+urllib.quote(city)+"&start="+str(start)
        driver.get(URL)
        soup = BeautifulSoup(driver.page_source, "lxml")

        for i in soup.findAll("div", {"data-tn-component" : "organicJob"}):

            location = extract_location_from_resultRow(i)
            company = extract_company_from_resultRow(i)
            summary = extract_summary_from_resultRow(i)
            jkid = extract_jkid_from_resultRow(i)
            title = extract_title_from_resultRow(i)
            salary = extract_salary_from_resultRow(i)
            reviews = extract_reviews_from_resultRow(i)
            stars = extract_stars_from_resultRow(i)
            post_date = extract_date_from_resultRow(i)

            job_dict.append([location, company, summary, jkid, title, salary, stars, reviews, post_date, now])
            
        job_df = pd.DataFrame(job_dict, columns=['location', 'company', 'summary', 'jkid', 'title', 'salary', 'stars', 'reviews', 'post_date', 'pull_date'])       

    job_df.to_csv('scrape'+city+'_'+str(MAX_RESULTS_PER_CITY)+'.csv', encoding='utf-8')

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
import numpy as np
import pandas as pd
from selenium import webdriver
import datetime
import urllib
import urllib2
import re
from time import sleep # To prevent overwhelming the server between connections
from collections import Counter # Keep track of our term counts
from nltk.corpus import stopwords # Filter out stopwords, such as 'the', 'or', 'and'

# %%
master_df = pd.read_csv('master.csv')

# DELETE ANY HEADER ROWS LEFT OVER FROM CSV MERGE
try: master_df = master_df[master_df['reviews'] != 'reviews'] 
except: pass

# %%
###### REVIEWS CLEAN TO FLOAT
######

master_df['reviews'] = master_df['reviews'].fillna(0)

def indeed_review_cleanup(review): 
    try:
        review = review.str.replace(',','')
        review = review.strip(' reviews')
        review = review.strip(' review')
        review = review.strip('reviews')
        review = review.strip()
        review = float(review)
    except:
        #print review
        pass
    return review

master_df['clean_review'] = master_df[['reviews']].applymap(lambda x:indeed_review_cleanup(x))

master_df['clean_review'].sort_values().unique()

master_df['clean_review'] = master_df['clean_review'].astype(float)
master_df['reviews'] = master_df['clean_review']
master_df.drop('clean_review', axis=1, inplace=True)

#########  END CLEAN REVIEWS
###################

# %%
###### POST_DATE CLEAN TO FLOAT
######

try:
    master_df['clean_post_date'] = master_df['post_date']
except: pass


def post_date_to_day_float(dateValue):
    try:
        temp = dateValue
        dateValue.replace('s','')
        if 'day' in dateValue:
            temp = dateValue.split()[0]
        elif 'hour' in dateValue:
            temp = dateValue.split()[0]
            temp = float(temp)/24
        elif 'minute' in dateValue:
            temp = dateValue.split()[0]
            temp = float(temp)/24/60
        if '+' in dateValue:
            temp = 45           
    except: 
        pass
    return temp

master_df['clean_post_date'] = master_df[['clean_post_date']].applymap(lambda x: post_date_to_day_float(x))

master_df['clean_post_date'].sort_values().unique()

master_df['clean_post_date'] = master_df['clean_post_date'].astype(float)
master_df['post_date'] = master_df['clean_post_date']
master_df.drop('clean_post_date', axis=1, inplace=True)
master_df.rename(columns = {'post_date':'post_date_daysAgo'}, inplace=True)

#########  END CLEAN POST_DATE
###################

# %%
###### STARS CLEAN TO FLOAT
######


master_df['clean_stars'] = master_df['stars'].fillna(0)
master_df['clean_stars'] = master_df[['stars']].astype(float).applymap(lambda x: x//6/2)


master_df['stars'] = master_df['clean_stars']
master_df.drop('clean_stars', axis=1, inplace=True)


#########  END CLEAN STARS
###################

# %%
#####Create JOB_LINK column from JKID
#####

master_df['job_link'] = master_df[['jkid']].applymap(lambda x: 'http://www.indeed.com/rc/clk?jk='+x)

#########  END JOB_LINK COLUMN
###################

# %%
##### Location Cleanup
#####

def location_cleanup(location):
    temp = location
    temp_city = location.split(',')[0]
    try:
        temp_state = location.split(',')[1].split()[0]
    except: 
        temp_state = ''
    return temp_city+", "+temp_state
    
master_df['location_clean'] = master_df[['location']].applymap(lambda x: location_cleanup(x))
master_df['location_clean'].sort_values().unique()

master_df['location'] = master_df['location_clean']
master_df.drop('location_clean', axis=1, inplace=True)

#########  END LOCATION CLEANUP COLUMN
###################

# %%
##### Salary Cleanup
#####

master_df['salary'] = master_df['salary'].fillna(0)

def cleanup_salary(salary):
    if "year" in str(salary):
        temp = salary.strip(" a year")
        temp = temp.split('-')
        low_range = int(temp[0].strip().replace("$","").replace(",",""))
        high_range = int(temp[-1].strip().replace("$","").replace(",",""))
        avg = (low_range + high_range) / 2
        salary_list = [low_range,high_range,avg]
    elif "month" in str(salary):
        temp = salary.replace("a month","")
        temp = temp.split('-')
        low_range = int(temp[0].replace("$","").replace(",",""))*12
        high_range = int(temp[-1].replace("$","").replace(",",""))*12
        avg = (low_range + high_range) / 2
        salary_list = [low_range,high_range,avg]
    elif "hour" in str(salary):
        temp = salary.replace("an hour","")
        temp = temp.split('-')
        low_range = float(temp[0].replace("$","").replace(",",""))*2080
        high_range = float(temp[-1].replace("$","").replace(",",""))*2080
        avg = (low_range + high_range) / 2
        salary_list = [low_range,high_range,avg]
    else:
        salary_list = [0,0,0]
        low_range = 0
        high_range = 0
        avg = 0
        
    return low_range, high_range, avg

master_df['salary_clean'] = master_df[['salary']].applymap(lambda x: cleanup_salary(x))

master_df['salary'] = master_df['salary_clean']
master_df.drop('salary_clean', axis=1, inplace=True)

#########  END SALARY CLEANUP COLUMN
###################

# %%
has_salary = master_df[master_df['salary'] != (0,0,0)].shape[0]
all_records = master_df.shape[0]
print "Job listings with salary info:", has_salary
print "Total job listings: ", all_records
print "Salaried listings / Total listings", round((float(has_salary) / all_records) * 100, 3), '%'
master_df.head(5)
master_df['title'].sort_values().unique()

# stacked = pd.DataFrame(master_df['summary'].str.split().tolist()).stack()
# final = pd.DataFrame(stacked.value_counts())
# final.reset_index(inplace=True)
# final['unique'] = final['index'].sort_values().unique()
# final['unique']
# import nltk
# final['tagged'] = final[['index']].applymap(lambda x: nltk.pos_tag(x.strip()))
# final.info()
master_df.shape
# Out:
# Job listings with salary info: 616
# Total job listings:  13138
# Salaried listings / Total listings 4.689 %
# (13138, 14)

# %%
URL = 'https://www.expatistan.com/cost-of-living/index/north-america' 
driver = webdriver.PhantomJS(executable_path='/Users/amishdalal/Downloads/phantomjs-2.1.1-macosx/bin/phantomjs')
driver.set_window_size(1024, 768) 
driver.get(URL)
soup = BeautifulSoup(driver.page_source,'lxml')
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <title>
#    Cost of Living Ranking in North America (USA and Canada). Updated Oct 2016
#   </title>
#   <meta content="2016 Cost Of Living in US and Canada. What are the most expensive, and the cheapest, American cities?" name="description"/>
#   <meta content="Cost of Living Ranking in North America (USA and Canada). Updated Oct 2016" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="2016 Cost Of Living in US and Canada. What are the most expensive, and the cheapest, American cities?" property="og:description"/>
#   <meta content="//d2y05869ftj0yg.cloudfront.net/images/map-preview.png" property="og:image"/>
#   <meta content="https://www.expatistan.com/cost-of-living/index" property="og:url"/>
#   <meta content="Expatistan, cost of living comparisons" property="og:site_name"/>
#   <meta content="502752123,gerardo.robledillo" property="fb:admins"/>
#   <meta content="145554152152105" property="fb:page_id"/>
#   <!--[if lt IE 9]>
#     <script src="//html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#     <![endif]-->
#   <link href="https://plus.google.com/116871999905881326091" rel="publisher"/>
#   <link href="https://d2y05869ftj0yg.cloudfront.net/stylesheets/cache/expatistan.050.hrh.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script async="" src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.FttDLlUdXcw.O/m=auth/exm=plusone/rt=j/sv=1/d=1/ed=1/am=EQ/rs=AGLTcCO6rxixa7pa711_uOW2yjCmjc9Cfw/cb=gapi.loaded_1">
#   </script>
#   <script async="" src="https://apis.google.com/_/scs/apps-static/_/js/k=oz.gapi.en_US.FttDLlUdXcw.O/m=plusone/rt=j/sv=1/d=1/ed=1/am=EQ/rs=AGLTcCO6rxixa7pa711_uOW2yjCmjc9Cfw/cb=gapi.loaded_0">
#   </script>
#   <script async="" gapi_processed="true" src="https://apis.google.com/js/plusone.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.google-analytics.com/ga.js">
#   </script>
#   <script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js#xfbml=1&amp;version=v2.3&amp;appId=120841561302378">
#   </script>
#   <script src="https://d2y05869ftj0yg.cloudfront.net/javascripts/cache/expatistan.050.hrh.js" type="text/javascript">
#   </script>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="F47618516423F3A8E60A452A6355C810" name="msvalidate.01"/>
#   <!-- Begin Cookie Consent plugin by Silktide - http://silktide.com/cookieconsent -->
#   <script type="text/javascript">
#    window.cookieconsent_options = {"message":"This website uses cookies to ensure you get the best experience on our website","dismiss":"Got it!","learnMore":"More info","link":"https://www.expatistan.com/tos#cookies","theme":"light-bottom"};
#   </script>
#   <script src="//d2y05869ftj0yg.cloudfront.net/javascripts/cookieconsent2.1.0.9.min.js" type="text/javascript">
#   </script>
#   <!-- End Cookie Consent plugin -->
#   <script src="//www.google.com/jsapi?callback=googleLoadCallback" type="text/javascript">
#   </script>
#   <script src="https://www.google.com/uds/?file=visualization&amp;v=1&amp;packages=geochart&amp;async=2" type="text/javascript">
#   </script>
#   <link href="https://www.google.com/uds/api/visualization/1.0/b5ac9efed10eef460d14e653d05f5fbf/ui+en.css" rel="stylesheet" type="text/css"/>
#   <script src="https://www.google.com/uds/api/visualization/1.0/b5ac9efed10eef460d14e653d05f5fbf/format+en,default+en,ui+en,geochart+en.I.js" type="text/javascript">
#   </script>
#   <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/1.0.9/light-bottom.css" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    .fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}.fb_link img{border:none}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_reset .fb_dialog_legacy{overflow:visible}.fb_dialog_advanced{padding:10px;-moz-border-radius:8px;-webkit-border-radius:8px;border-radius:8px}.fb_dialog_content{background:#fff;color:#333}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;_background-image:url(https://static.xx.fbcdn.net/rsrc.php/v3/yL/r/s816eWC-2sl.gif);cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{top:5px;left:5px;right:auto}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent;_background-image:url(https://static.xx.fbcdn.net/rsrc.php/v3/yL/r/s816eWC-2sl.gif)}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent;_background-image:url(https://static.xx.fbcdn.net/rsrc.php/v3/yL/r/s816eWC-2sl.gif)}.fb_dialog_loader{background-color:#f6f7f9;border:1px solid #606060;font-size:24px;padding:20px}.fb_dialog_top_left,.fb_dialog_top_right,.fb_dialog_bottom_left,.fb_dialog_bottom_right{height:10px;width:10px;overflow:hidden;position:absolute}.fb_dialog_top_left{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 0;left:-10px;top:-10px}.fb_dialog_top_right{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 -10px;right:-10px;top:-10px}.fb_dialog_bottom_left{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 -20px;bottom:-10px;left:-10px}.fb_dialog_bottom_right{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ye/r/8YeTNIlTZjm.png) no-repeat 0 -30px;right:-10px;bottom:-10px}.fb_dialog_vert_left,.fb_dialog_vert_right,.fb_dialog_horiz_top,.fb_dialog_horiz_bottom{position:absolute;background:#525252;filter:alpha(opacity=70);opacity:.7}.fb_dialog_vert_left,.fb_dialog_vert_right{width:10px;height:100%}.fb_dialog_vert_left{margin-left:-10px}.fb_dialog_vert_right{right:0;margin-right:-10px}.fb_dialog_horiz_top,.fb_dialog_horiz_bottom{width:100%;height:10px}.fb_dialog_horiz_top{margin-top:-10px}.fb_dialog_horiz_bottom{bottom:0;margin-bottom:-10px}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{-webkit-transform:none;height:100%;margin:0;overflow:visible;position:absolute;top:-10000px;left:0;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{width:auto;height:auto;min-height:initial;min-width:initial;background:none}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{color:#fff;display:block;padding-top:20px;clear:both;font-size:18px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .45);position:absolute;bottom:0;left:0;right:0;top:0;width:100%;min-height:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_content .dialog_header{-webkit-box-shadow:white 0 1px 1px -1px inset;background:-webkit-gradient(linear, 0% 0%, 0% 100%, from(#738ABA), to(#2C4987));border-bottom:1px solid;border-color:#1d40 ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_hide_iframes iframe{position:relative;left:-10000px}.fb_iframe_widget_loader{position:relative;display:inline-block}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}.fb_iframe_widget_loader iframe{min-height:32px;z-index:2;zoom:1}.fb_iframe_widget_loader .FB_Loader{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat;height:32px;width:32px;margin-left:-16px;position:absolute;left:50%;z-index:4}
#   </style>
#  </head>
#  <body class=" " onload="initialize();">
#   <div id="wrapper">
#    <!-- start header -->
#    <div class="cf" id="header">
#     <div class="left">
#      <a href="https://www.expatistan.com/">
#       <div class="sprite sprite-logo" title="Expatistan, cost of living comparisons">
#       </div>
#       <div class="sprite sprite-sublogo">
#       </div>
#      </a>
#     </div>
#     <div class="right">
#      <div id="select_city">
#       <form action="/" id="compare_form" method="GET" onsubmit="return compare_cities('header');">
#        <div class="holder" id="first_city">
#         <div class="label">
#          Compare cost of living between
#         </div>
#         <div class="input">
#          <!-- TODO: add hint_content class if value is empty -->
#          <input aria-autocomplete="list" aria-haspopup="true" autocomplete="off" class="home_input city-2 hint_content ui-autocomplete-input" id="city_other_english_name" name="city[other][english_name]" role="textbox" size="28" type="text" value="where you want to move"/>
#          <input class="handle" name="city[other][handle]" type="hidden" value=""/>
#         </div>
#        </div>
#        <div class="holder" id="second_city">
#         <div class="label" style="padding-right:0px;">
#          and
#         </div>
#         <div class="input">
#          <input aria-autocomplete="list" aria-haspopup="true" autocomplete="off" class="home_input city-1 ui-autocomplete-input" id="city_this_english_name" name="city[this][english_name]" role="textbox" size="28" type="text" value="Paris"/>
#          <input class="handle" name="city[this][handle]" type="hidden" value="Paris"/>
#         </div>
#        </div>
#        <div class="holder round" id="button">
#         <input class="submit" name="commit" type="submit" value="Compare!"/>
#        </div>
#       </form>
#      </div>
#      <div id="error_message" style="display:none;">
#       Please, fill in both cities
#      </div>
#      <div style="width:400px;height:27px;float:right;padding-top:6px;">
#       <div id="___plusone_0" style="text-indent: 0px; margin: 0px; padding: 0px; background-color: transparent; border-style: none; float: none; line-height: normal; font-size: 1px; vertical-align: baseline; display: inline-block; width: 400px; height: 24px; background-position: initial initial; background-repeat: initial initial;">
#        <iframe data-gapiattached="true" frameborder="0" hspace="0" id="I0_1476739096455" marginheight="0" marginwidth="0" name="I0_1476739096455" scrolling="no" src="https://apis.google.com/se/0/_/+1/fastbutton?usegapi=1&amp;annotation=inline&amp;width=400&amp;origin=https%3A%2F%2Fwww.expatistan.com&amp;url=https%3A%2F%2Fwww.expatistan.com%2F&amp;gsrc=3p&amp;ic=1&amp;jsh=m%3B%2F_%2Fscs%2Fapps-static%2F_%2Fjs%2Fk%3Doz.gapi.en_US.FttDLlUdXcw.O%2Fm%3D__features__%2Fam%3DEQ%2Frt%3Dj%2Fd%3D1%2Frs%3DAGLTcCO6rxixa7pa711_uOW2yjCmjc9Cfw#_methods=onPlusOne%2C_ready%2C_close%2C_open%2C_resizeMe%2C_renderstart%2Concircled%2Cdrefresh%2Cerefresh%2Conload&amp;id=I0_1476739096455&amp;parent=https%3A%2F%2Fwww.expatistan.com&amp;pfname=&amp;rpctoken=80232372" style="position: static; top: 0px; width: 400px; margin: 0px; border-style: none; left: 0px; visibility: visible; height: 24px;" tabindex="0" title="+1" vspace="0" width="100%">
#        </iframe>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- end header -->
#    <div class="cf" id="content">
#     <div class="cf">
#      <ul id="breadcrumbs" itemscope="" itemtype="http://schema.org/BreadcrumbList">
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <a href="/cost-of-living" itemprop="item">
#         <span itemprop="name">
#          Cost of Living
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
#        <span itemprop="name">
#         Index
#        </span>
#        <meta content="2" itemprop="position"/>
#       </li>
#      </ul>
#      <div class="home-module centered" style="width:auto;margin-left:auto;margin-right:auto;">
#       <h1>
#        Expatistan's Cost of Living Map of North America
#       </h1>
#       <script type="text/javascript">
#        $( document ).ready(function() {
#         // Load Google AJAX APIs loader module (google.load)
#         var script = document.createElement('script');
#         script.src = '//www.google.com/jsapi?callback=googleLoadCallback';
#         script.type = 'text/javascript';
#         document.getElementsByTagName('head')[0].appendChild(script);
#     });
#   function googleLoadCallback() {
#     google.load('visualization', '1', {'packages': ['geochart'], 'callback' : start});
# //  google.setOnLoadCallback(start);
#   }
#
#   var data = null;
#   var geomap = null;
#   var region = '021';
#   var options = {};
#   var counter = 0;
#
#   function setupMap(countryCode) {
#     geomap = new google.visualization.GeoChart(document.getElementById('countryMap'));
#
#     options = {
#       region: countryCode,
#       //resolution: 'provinces',
#       displayMode: 'markers',
#       markerOpacity: 1,
#       colorAxis: {colors: ['0BFF00', 'FFFE00', 'FF0A00']},
#       sizeAxis:  {minSize: 6,  maxSize: 8},
#       datalessRegionColor: 'F4F3F0',
#       backgroundColor: 'A5BFDD',
#       width: 948,
#       height: 586,
#       enableRegionInteractivity: true
#     }
#
#       google.visualization.events.addListener(geomap, 'select', function() {
#         var selection = geomap.getSelection()[0];
#         goToCity(cities[selection.row]);
#       });
#
#       google.visualization.events.addListener(geomap, 'regionClick', function(c) {
#         zoomIn(c.region);
#       });
#   }
#   function setupData() {
#     var cityCount = cities.length;
#     data = new google.visualization.DataTable();
#     data.addRows(cityCount);
#     data.addColumn('number', 'Latitude');
#     data.addColumn('number', 'Longitude');
#     data.addColumn('string', 'DESCRIPTION');
#     data.addColumn('number', 'Cost Of Living Index');
#     data.addColumn('number', 'Population')
#     data.addColumn({type:'string', role:'tooltip'}); // https://developers.google.com/chart/interactive/docs/roles
#   }
#   function start() {
#     setTimeout(function(){
#       setupMap(region);
#       setupData();
#       loadCities();
#       geomap.draw(data, options);
#     },100);
#   }
#   function loadCities() {
#     for (var i=0; i<cities.length; i++) {
#       var city = cities[i];
#       loadCity(city[0],city[1],city[2],city[3],city[4],city[5]);
#     }
#   }
#   function loadCity(lat,lng,name,idx,population,tooltip) {
#     data.setValue(counter,0,lat);
#     data.setValue(counter,1,lng);
#     data.setValue(counter,2,name);
#     data.setValue(counter,3,idx);
#     data.setValue(counter,4,population);
#     data.setValue(counter,5,tooltip);
#     counter += 1;
#   }
#   function goToCity(city) {
#     var url = 'https://www.expatistan.com/cost-of-living/ghost'.replace("ghost",city[6]);
#     this.document.location.href = url;
#   }
#   function zoomIn(toRegion) {
#     console.log('zoomIn',toRegion,region);
#     if (region == 'world') {
#       region = countryToRegionMapping[toRegion];
#     } else {
#       region = toRegion;
#     }
#     setupMap(region);
#     geomap.draw(data, options);
#   }
#   function zoomOut() {
#     console.log('zoomOut',region);
#     if (countryToRegionMapping[region]) {
#       region = countryToRegionMapping[region];
#     } else {
#       region = 'world';
#     }
#     setupMap(region);
#     geomap.draw(data, options);
#   }
#   function redirectToMainMap() {
#   }
#   var cities = [
#         [40.7143,-74.006,'New York City',281,8008278,'Cost of Living Index: 281','new-york-city','US'],
#         [37.7793,-122.419,'San Francisco, California',278,808976,'Cost of Living Index: 278','san-francisco','US'],
#         [38.8951,-77.0364,'Washington D.C.',263,552433,'Cost of Living Index: 263','washington-d-c','US'],
#         [42.3584,-71.0598,'Boston, Massachusetts',229,589141,'Cost of Living Index: 229','boston','US'],
#         [37.3394,-121.895,'San Jose, California',228,894943,'Cost of Living Index: 228','san-jose-california','US'],
#         [21.3089,-157.826,'Honolulu, Hawaii',227,909000,'Cost of Living Index: 227','honolulu','US'],
#         [34.0522,-118.244,'Los Angeles, California',223,3694820,'Cost of Living Index: 223','los-angeles','US'],
#         [37.8044,-122.271,'Oakland, California',221,390724,'Cost of Living Index: 221','oakland-california','US'],
#         [47.6062,-122.332,'Seattle, Washington',212,569369,'Cost of Living Index: 212','seattle','US'],
#         [39.9523,-75.1638,'Philadelphia, Pennsylvania',211,1517550,'Cost of Living Index: 211','philadelphia','US'],
#         [41.85,-87.6501,'Chicago, Illinois',209,2841952,'Cost of Living Index: 209','chicago','US'],
#         [32.7153,-117.157,'San Diego, California',204,1223400,'Cost of Living Index: 204','san-diego','US'],
#         [45.5235,-122.676,'Portland, Oregon',198,540513,'Cost of Living Index: 198','portland','US'],
#         [61.2183,-149.899,'Anchorage, Alaska',197,300000,'Cost of Living Index: 197','anchorage','US'],
#         [39.7392,-104.985,'Denver, Colorado',197,554636,'Cost of Living Index: 197','denver','US'],
#         [25.7878,-80.2242,'Miami, Florida',196,362470,'Cost of Living Index: 196','miami','US'],
#         [44.9801,-93.2519,'Minneapolis - St. Paul, Minnesota',194,3269814,'Cost of Living Index: 194','minneapolis','US'],
#         [40.4417,-80.0,'Pittsburgh, Pennsylvania',192,1753136,'Cost of Living Index: 192','pittsburgh','US'],
#         [41.7627,-72.6743,'Hartford, Connecticut',191,125000,'Cost of Living Index: 191','hartford-connecticut','US'],
#         [43.7001,-79.4163,'Toronto',190,4612191,'Cost of Living Index: 190','toronto','CA'],
#         [39.2904,-76.6122,'Baltimore, Maryland',189,610892,'Cost of Living Index: 189','baltimore','US'],
#         [33.749,-84.388,'Atlanta, Georgia',187,422908,'Cost of Living Index: 187','atlanta','US'],
#         [30.2672,-97.7431,'Austin, Texas',185,678368,'Cost of Living Index: 185','austin','US'],
#         [43.6,-79.65,'Mississauga',183,706000,'Cost of Living Index: 183','mississauga','CA'],
#         [38.5816,-121.494,'Sacramento, California',182,467898,'Cost of Living Index: 182','sacramento','US'],
#         [49.2497,-123.119,'Vancouver',182,1837969,'Cost of Living Index: 182','vancouver','CA'],
#         [29.9546,-90.0751,'New Orleans, Louisiana',181,484674,'Cost of Living Index: 181','new-orleans','US'],
#         [26.1333,-80.15,'Fort Lauderdale, Florida',181,172389,'Cost of Living Index: 181','fort-lauderdale','US'],
#         [29.7633,-95.3633,'Houston, Texas',177,2027712,'Cost of Living Index: 177','houston','US'],
#         [43.0389,-87.9065,'Milwaukee, Wisconsin',177,579180,'Cost of Living Index: 177','milwaukee','US'],
#         [32.7831,-96.8067,'Dallas, Texas',175,1211704,'Cost of Living Index: 175','dallas','US'],
#         [36.175,-115.137,'Las Vegas, Nevada',175,478434,'Cost of Living Index: 175','las-vegas','US'],
#         [36.1659,-86.7844,'Nashville, Tennessee',174,530852,'Cost of Living Index: 174','nashville','US'],
#         [32.7254,-97.3208,'Fort Worth, Texas',174,618119,'Cost of Living Index: 174','fort-worth','US'],
#         [28.5436,-81.3728,'Orlando, Florida',172,238300,'Cost of Living Index: 172','orlando','US'],
#         [45.4209,-75.6903,'Ottawa',172,812129,'Cost of Living Index: 172','ottawa','CA'],
#         [51.0501,-114.085,'Calgary',171,1019942,'Cost of Living Index: 171','calgary','CA'],
#         [35.4676,-97.5164,'Oklahoma City, Oklahoma',171,532950,'Cost of Living Index: 171','oklahoma-city','US'],
#         [35.2271,-80.8431,'Charlotte, North Carolina',170,598351,'Cost of Living Index: 170','charlotte-united-states','US'],
#         [43.0731,-89.4012,'Madison, Wisconsin',170,224625,'Cost of Living Index: 170','madison','US'],
#         [39.9612,-82.9988,'Columbus, Ohio',170,736836,'Cost of Living Index: 170','columbus','US'],
#         [53.5501,-113.469,'Edmonton',169,712391,'Cost of Living Index: 169','edmonton','CA'],
#         [27.9472,-82.4586,'Tampa, Florida',169,2700000,'Cost of Living Index: 169','tampa','US'],
#         [38.6272,-90.1978,'St. Louis, Missouri',168,2816710,'Cost of Living Index: 168','st-louis','US'],
#         [41.4995,-81.6954,'Cleveland, Ohio',168,449514,'Cost of Living Index: 168','cleveland','US'],
#         [40.75,-111.883,'Salt Lake City, Utah',166,1130000,'Cost of Living Index: 166','salt-lake-city','US'],
#         [30.3322,-81.6556,'Jacksonville, Florida',164,797557,'Cost of Living Index: 164','jacksonville','US'],
#         [35.8189,-78.6447,'Raleigh, North Carolina',163,403892,'Cost of Living Index: 163','raleigh-north-carolina','US'],
#         [44.652,-63.5968,'Halifax',161,359111,'Cost of Living Index: 161','halifax','CA'],
#         [42.9047,-78.8494,'Buffalo, New York',161,1254066,'Cost of Living Index: 161','buffalo','US'],
#         [48.4286,-123.366,'Victoria',160,330000,'Cost of Living Index: 160','victoria-canada','CA'],
#         [33.4484,-112.074,'Phoenix, Arizona',158,1321045,'Cost of Living Index: 158','phoenix','US'],
#         [36.1314,-95.9372,'Tulsa, Oklahoma',157,391000,'Cost of Living Index: 157','tulsa-oklahoma','US'],
#         [45.5168,-73.6492,'Montreal',157,3268513,'Cost of Living Index: 157','montreal','CA'],
#         [33.5248,-86.8127,'Birmingham, Alabama',157,212237,'Cost of Living Index: 157','birmingham-alabama','US'],
#         [39.1361,-84.5031,'Cincinnati, Ohio',156,2155137,'Cost of Living Index: 156','cincinnati','US'],
#         [39.0997,-94.5786,'Kansas City, Missouri',156,441545,'Cost of Living Index: 156','kansas-city','US'],
#         [34.8444,-82.3856,'Greenville, South Carolina',155,61674,'Cost of Living Index: 155','greenville-south-carolina','US'],
#         [42.3314,-83.0458,'Detroit, Michigan',155,951270,'Cost of Living Index: 155','detroit','US'],
#         [39.7684,-86.158,'Indianapolis, Indiana',155,773283,'Cost of Living Index: 155','indianapolis','US'],
#         [49.8844,-97.147,'Winnipeg',154,632063,'Cost of Living Index: 154','winnipeg','CA'],
#         [41.25,-96.0,'Omaha, Nebraska',153,849517,'Cost of Living Index: 153','omaha','US'],
#         [35.0845,-106.651,'Albuquerque, New Mexico',152,487378,'Cost of Living Index: 152','albuquerque','US'],
#         [43.1656,-77.6114,'Rochester, New York',152,210565,'Cost of Living Index: 152','rochester-new-york','US'],
#         [35.9728,-83.9422,'Knoxville, Tennessee',150,182200,'Cost of Living Index: 150','knoxville-tn','US'],
#         [29.4167,-98.5,'San Antonio, Texas',150,1382951,'Cost of Living Index: 150','san-antonio-texas','US'],
#         [49.8836,-119.493,'Kelowna',149,120812,'Cost of Living Index: 149','kelowna','CA'],
#         [38.2542,-85.7603,'Louisville, Kentucky',146,1266454,'Cost of Living Index: 146','louisville','US'],
#         [35.1495,-90.049,'Memphis, Tennessee',143,650100,'Cost of Living Index: 143','memphis','US'],
#         [43.6136,-116.203,'Boise, Idaho',140,585207,'Cost of Living Index: 140','boise','US']
#   ]
#
#   var countryToRegionMapping = {};
#   countryToRegionMapping['VA'] = '039';
#   countryToRegionMapping['ZR'] = '017';
#   countryToRegionMapping['GT'] = '013';
#   countryToRegionMapping['JP'] = '030';
#   countryToRegionMapping['SE'] = '154';
#   countryToRegionMapping['TZ'] = '014';
#   countryToRegionMapping['CD'] = '017';
#   countryToRegionMapping['GU'] = '057';
#   countryToRegionMapping['MM'] = '035';
#   countryToRegionMapping['DZ'] = '015';
#   countryToRegionMapping['MN'] = '030';
#   countryToRegionMapping['PK'] = '034';
#   countryToRegionMapping['SG'] = '035';
#   countryToRegionMapping['VC'] = '029';
#   countryToRegionMapping['CF'] = '017';
#   countryToRegionMapping['GW'] = '011';
#   countryToRegionMapping['MO'] = '030';
#   countryToRegionMapping['PL'] = '151';
#   countryToRegionMapping['SH'] = '011';
#   countryToRegionMapping['VE'] = '005';
#   countryToRegionMapping['CG'] = '017';
#   countryToRegionMapping['MP'] = '057';
#   countryToRegionMapping['PM'] = '021';
#   countryToRegionMapping['SI'] = '039';
#   countryToRegionMapping['GY'] = '005';
#   countryToRegionMapping['ZW'] = '014';
#   countryToRegionMapping['CH'] = '155';
#   countryToRegionMapping['MQ'] = '029';
#   countryToRegionMapping['PN'] = '061';
#   countryToRegionMapping['SJ'] = '154';
#   countryToRegionMapping['CI'] = '011';
#   countryToRegionMapping['MR'] = '011';
#   countryToRegionMapping['SK'] = '151';
#   countryToRegionMapping['VG'] = '029';
#   countryToRegionMapping['MS'] = '029';
#   countryToRegionMapping['SL'] = '011';
#   countryToRegionMapping['YD'] = '145';
#   countryToRegionMapping['CK'] = '061';
#   countryToRegionMapping['ID'] = '035';
#   countryToRegionMapping['MT'] = '039';
#   countryToRegionMapping['SM'] = '039';
#   countryToRegionMapping['VI'] = '029';
#   countryToRegionMapping['YE'] = '145';
#   countryToRegionMapping['CL'] = '005';
#   countryToRegionMapping['IE'] = '154';
#   countryToRegionMapping['LA'] = '035';
#   countryToRegionMapping['MU'] = '014';
#   countryToRegionMapping['SN'] = '011';
#   countryToRegionMapping['CM'] = '017';
#   countryToRegionMapping['FI'] = '154';
#   countryToRegionMapping['LB'] = '145';
#   countryToRegionMapping['MV'] = '034';
#   countryToRegionMapping['PR'] = '029';
#   countryToRegionMapping['SO'] = '014';
#   countryToRegionMapping['CN'] = '030';
#   countryToRegionMapping['FJ'] = '054';
#   countryToRegionMapping['LC'] = '029';
#   countryToRegionMapping['MW'] = '014';
#   countryToRegionMapping['PS'] = '145';
#   countryToRegionMapping['FK'] = '005';
#   countryToRegionMapping['CO'] = '005';
#   countryToRegionMapping['MX'] = '013';
#   countryToRegionMapping['PT'] = '039';
#   countryToRegionMapping['SR'] = '005';
#   countryToRegionMapping['MY'] = '035';
#   countryToRegionMapping['VN'] = '035';
#   countryToRegionMapping['FM'] = '057';
#   countryToRegionMapping['MZ'] = '014';
#   countryToRegionMapping['CR'] = '013';
#   countryToRegionMapping['PW'] = '057';
#   countryToRegionMapping['CS'] = '039';
#   countryToRegionMapping['FO'] = '154';
#   countryToRegionMapping['ST'] = '017';
#   countryToRegionMapping['PY'] = '005';
#   countryToRegionMapping['IL'] = '145';
#   countryToRegionMapping['LI'] = '155';
#   countryToRegionMapping['SU'] = '151';
#   countryToRegionMapping['BA'] = '039';
#   countryToRegionMapping['CU'] = '029';
#   countryToRegionMapping['IM'] = '154';
#   countryToRegionMapping['SV'] = '013';
#   countryToRegionMapping['CV'] = '011';
#   countryToRegionMapping['FR'] = '155';
#   countryToRegionMapping['IN'] = '034';
#   countryToRegionMapping['LK'] = '034';
#   countryToRegionMapping['BB'] = '029';
#   countryToRegionMapping['VU'] = '054';
#   countryToRegionMapping['RE'] = '014';
#   countryToRegionMapping['UA'] = '151';
#   countryToRegionMapping['SY'] = '145';
#   countryToRegionMapping['CY'] = '145';
#   countryToRegionMapping['IQ'] = '145';
#   countryToRegionMapping['SZ'] = '018';
#   countryToRegionMapping['BD'] = '034';
#   countryToRegionMapping['YT'] = '014';
#   countryToRegionMapping['CZ'] = '151';
#   countryToRegionMapping['IR'] = '034';
#   countryToRegionMapping['BE'] = '155';
#   countryToRegionMapping['EC'] = '005';
#   countryToRegionMapping['IS'] = '154';
#   countryToRegionMapping['YU'] = '039';
#   countryToRegionMapping['BF'] = '011';
#   countryToRegionMapping['FX'] = '155';
#   countryToRegionMapping['IT'] = '039';
#   countryToRegionMapping['OM'] = '145';
#   countryToRegionMapping['BG'] = '151';
#   countryToRegionMapping['BH'] = '145';
#   countryToRegionMapping['LR'] = '011';
#   countryToRegionMapping['UG'] = '014';
#   countryToRegionMapping['BI'] = '014';
#   countryToRegionMapping['EE'] = '154';
#   countryToRegionMapping['LS'] = '018';
#   countryToRegionMapping['BJ'] = '011';
#   countryToRegionMapping['EG'] = '015';
#   countryToRegionMapping['LT'] = '154';
#   countryToRegionMapping['EH'] = '015';
#   countryToRegionMapping['BL'] = '029';
#   countryToRegionMapping['LU'] = '155';
#   countryToRegionMapping['RO'] = '151';
#   countryToRegionMapping['BM'] = '021';
#   countryToRegionMapping['LV'] = '154';
#   countryToRegionMapping['BN'] = '035';
#   countryToRegionMapping['BO'] = '005';
#   countryToRegionMapping['LY'] = '015';
#   countryToRegionMapping['KE'] = '014';
#   countryToRegionMapping['NA'] = '018';
#   countryToRegionMapping['BR'] = '005';
#   countryToRegionMapping['KG'] = '143';
#   countryToRegionMapping['NC'] = '054';
#   countryToRegionMapping['RS'] = '039';
#   countryToRegionMapping['BS'] = '029';
#   countryToRegionMapping['HK'] = '030';
#   countryToRegionMapping['KH'] = '035';
#   countryToRegionMapping['BT'] = '034';
#   countryToRegionMapping['KI'] = '057';
#   countryToRegionMapping['NE'] = '011';
#   countryToRegionMapping['QA'] = '145';
#   countryToRegionMapping['RU'] = '151';
#   countryToRegionMapping['BU'] = '035';
#   countryToRegionMapping['NF'] = '053';
#   countryToRegionMapping['US'] = '021';
#   countryToRegionMapping['ER'] = '014';
#   countryToRegionMapping['HN'] = '013';
#   countryToRegionMapping['NG'] = '011';
#   countryToRegionMapping['RW'] = '014';
#   countryToRegionMapping['BW'] = '018';
#   countryToRegionMapping['ES'] = '039';
#   countryToRegionMapping['ET'] = '014';
#   countryToRegionMapping['NI'] = '013';
#   countryToRegionMapping['AD'] = '039';
#   countryToRegionMapping['BY'] = '151';
#   countryToRegionMapping['KM'] = '014';
#   countryToRegionMapping['AE'] = '145';
#   countryToRegionMapping['BZ'] = '013';
#   countryToRegionMapping['HR'] = '039';
#   countryToRegionMapping['KN'] = '029';
#   countryToRegionMapping['TC'] = '029';
#   countryToRegionMapping['AF'] = '034';
#   countryToRegionMapping['NL'] = '155';
#   countryToRegionMapping['TD'] = '017';
#   countryToRegionMapping['UY'] = '005';
#   countryToRegionMapping['AG'] = '029';
#   countryToRegionMapping['HT'] = '029';
#   countryToRegionMapping['KP'] = '030';
#   countryToRegionMapping['DD'] = '155';
#   countryToRegionMapping['GA'] = '017';
#   countryToRegionMapping['HU'] = '151';
#   countryToRegionMapping['UZ'] = '143';
#   countryToRegionMapping['AI'] = '029';
#   countryToRegionMapping['DE'] = '155';
#   countryToRegionMapping['GB'] = '154';
#   countryToRegionMapping['KR'] = '030';
#   countryToRegionMapping['TG'] = '011';
#   countryToRegionMapping['NO'] = '154';
#   countryToRegionMapping['TH'] = '035';
#   countryToRegionMapping['GD'] = '029';
#   countryToRegionMapping['NP'] = '034';
#   countryToRegionMapping['ZA'] = '018';
#   countryToRegionMapping['AL'] = '039';
#   countryToRegionMapping['GE'] = '145';
#   countryToRegionMapping['TJ'] = '143';
#   countryToRegionMapping['WF'] = '061';
#   countryToRegionMapping['GF'] = '005';
#   countryToRegionMapping['AM'] = '145';
#   countryToRegionMapping['NR'] = '057';
#   countryToRegionMapping['TK'] = '061';
#   countryToRegionMapping['AN'] = '029';
#   countryToRegionMapping['DJ'] = '014';
#   countryToRegionMapping['KW'] = '145';
#   countryToRegionMapping['TL'] = '035';
#   countryToRegionMapping['DK'] = '154';
#   countryToRegionMapping['GG'] = '154';
#   countryToRegionMapping['NT'] = '145';
#   countryToRegionMapping['TM'] = '143';
#   countryToRegionMapping['TN'] = '015';
#   countryToRegionMapping['MA'] = '015';
#   countryToRegionMapping['GH'] = '011';
#   countryToRegionMapping['JE'] = '154';
#   countryToRegionMapping['KY'] = '029';
#   countryToRegionMapping['NU'] = '061';
#   countryToRegionMapping['DM'] = '029';
#   countryToRegionMapping['GI'] = '039';
#   countryToRegionMapping['KZ'] = '143';
#   countryToRegionMapping['TO'] = '061';
#   countryToRegionMapping['AR'] = '005';
#   countryToRegionMapping['MC'] = '155';
#   countryToRegionMapping['TP'] = '035';
#   countryToRegionMapping['MD'] = '151';
#   countryToRegionMapping['AS'] = '061';
#   countryToRegionMapping['DO'] = '029';
#   countryToRegionMapping['ME'] = '039';
#   countryToRegionMapping['PA'] = '013';
#   countryToRegionMapping['TR'] = '145';
#   countryToRegionMapping['AT'] = '155';
#   countryToRegionMapping['GL'] = '021';
#   countryToRegionMapping['MF'] = '029';
#   countryToRegionMapping['NZ'] = '053';
#   countryToRegionMapping['AU'] = '053';
#   countryToRegionMapping['GM'] = '011';
#   countryToRegionMapping['MG'] = '014';
#   countryToRegionMapping['GN'] = '011';
#   countryToRegionMapping['ZM'] = '014';
#   countryToRegionMapping['MH'] = '057';
#   countryToRegionMapping['TT'] = '029';
#   countryToRegionMapping['AW'] = '029';
#   countryToRegionMapping['PE'] = '005';
#   countryToRegionMapping['SA'] = '145';
#   countryToRegionMapping['AX'] = '154';
#   countryToRegionMapping['GP'] = '029';
#   countryToRegionMapping['PF'] = '061';
#   countryToRegionMapping['SB'] = '054';
#   countryToRegionMapping['TV'] = '061';
#   countryToRegionMapping['WS'] = '061';
#   countryToRegionMapping['CA'] = '021';
#   countryToRegionMapping['GQ'] = '017';
#   countryToRegionMapping['JM'] = '029';
#   countryToRegionMapping['SC'] = '014';
#   countryToRegionMapping['TW'] = '030';
#   countryToRegionMapping['AZ'] = '145';
#   countryToRegionMapping['GR'] = '039';
#   countryToRegionMapping['MK'] = '039';
#   countryToRegionMapping['PG'] = '054';
#   countryToRegionMapping['SD'] = '015';
#   countryToRegionMapping['JO'] = '145';
#   countryToRegionMapping['ML'] = '011';
#   countryToRegionMapping['PH'] = '035';
#       </script>
#       <div id="countryMapContainer" onclick="redirectToMainMap();" style="position:relative;">
#        <img onclick="zoomOut();" src="https://d2y05869ftj0yg.cloudfront.net/images/zoomout.png" style="position:absolute;z-index:10;position:absolute;top:6px;left:6px;cursor:pointer;"/>
#        <div id="countryMap" style="width:948px;height:586px;position:relative;border:1px solid #D1CAC7;">
#         <img alt="loading..." src="https://d2y05869ftj0yg.cloudfront.net/images/ajax-loader.gif" style="position:absolute;top:277px;left:458px;"/>
#        </div>
#       </div>
#       <p class="left-align">
#        This map shows only the top cities in the world. We also have a list of
#        <a href="https://www.expatistan.com/cost-of-living/all-cities">
#         all the cities available in Expatistan
#        </a>
#        .
#       </p>
#       <p class="left-align">
#        The color of the markers corresponds with the Cost of Living in the city. Red markers show more expensive cities, green ones show cheaper cities.
#        <br/>
#        The size of the markers correspond with the population of each city.
#        <br/>
#        Moving the mouse on top of a city will show its name and the
#        <acronym title="Cost of Living Index">
#         Cost of Living Index
#        </acronym>
#        of the city.
#       </p>
#       <p class="left-align">
#        <strong>
#         What is the
#         <acronym title="Cost of Living Index">
#          Cost of Living Index
#         </acronym>
#         ?
#        </strong>
#        To calculate each cities' Cost of Living Index value, we start by assigning a value of 100 to a
#        <dfn title="City that gives the fixed reference point for the index.">
#         central reference
#        </dfn>
#        city (that happens to be Prague).
# Once the reference point has been established, the Price Index value of every other city in the
# database is calculated by comparing their cost of living to the cost of living in Prague.
#        <br/>
#        Therefore, if a city has a Price Index of 134, that means that living there is 34% more expensive than living in Prague.
#       </p>
#      </div>
#      <div class="block first comparison colindex" id="ranking">
#       <div class="prices">
#        <h1>
#         Expatistan Cost of Living Index in North America
#        </h1>
#        <ul class="regions">
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/index">
#           the world
#          </a>
#         </li>
#         <li>
#          <a href="/cost-of-living/index/europe">
#           europe
#          </a>
#         </li>
#         <li>
#          north america
#         </li>
#         <li>
#          <a href="/cost-of-living/index/latin-america">
#           latin america
#          </a>
#         </li>
#         <li>
#          <a href="/cost-of-living/index/asia">
#           asia
#          </a>
#         </li>
#         <li>
#          <a href="/cost-of-living/index/middle-east">
#           middle east
#          </a>
#         </li>
#         <li>
#          <a href="/cost-of-living/index/africa">
#           africa
#          </a>
#         </li>
#         <li>
#          <a href="/cost-of-living/index/oceania">
#           oceania
#          </a>
#         </li>
#        </ul>
#        <!-- Add the list of indices -->
#        <table class="city-index">
#         <thead>
#          <tr>
#           <th class="ranking">
#            Ranking
#           </th>
#           <th class="city-name">
#            City
#           </th>
#           <th class="price-index">
#            Price Index
#            <a href="#price-index-explanation">
#             *
#            </a>
#           </th>
#           <!-- <th>Flags <a href="#reliability-explanation">**</a></th> -->
#          </tr>
#         </thead>
#         <tbody>
#          <tr class="odd" id="ranking_1">
#           <td class="ranking">
#            1
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/new-york-city">
#             New York City (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            281
#           </td>
#          </tr>
#          <tr class="even" id="ranking_2">
#           <td class="ranking">
#            2
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/san-francisco">
#             San Francisco, California (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            278
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_3">
#           <td class="ranking">
#            3
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/washington-d-c">
#             Washington D.C. (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            263
#           </td>
#          </tr>
#          <tr class="even" id="ranking_4">
#           <td class="ranking">
#            4
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/boston">
#             Boston, Massachusetts (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            229
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_5">
#           <td class="ranking">
#            5
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/san-jose-california">
#             San Jose, California (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            228
#           </td>
#          </tr>
#          <tr class="even" id="ranking_6">
#           <td class="ranking">
#            6
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/honolulu">
#             Honolulu, Hawaii (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            227
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_7">
#           <td class="ranking">
#            7
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/los-angeles">
#             Los Angeles, California (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            223
#           </td>
#          </tr>
#          <tr class="even" id="ranking_8">
#           <td class="ranking">
#            8
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/oakland-california">
#             Oakland, California (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            221
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_9">
#           <td class="ranking">
#            9
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/seattle">
#             Seattle, Washington (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            212
#           </td>
#          </tr>
#          <tr class="even" id="ranking_10">
#           <td class="ranking">
#            10
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/philadelphia">
#             Philadelphia, Pennsylvania (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            211
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_11">
#           <td class="ranking">
#            11
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/chicago">
#             Chicago, Illinois (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            209
#           </td>
#          </tr>
#          <tr class="even" id="ranking_12">
#           <td class="ranking">
#            12
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/san-diego">
#             San Diego, California (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            204
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_13">
#           <td class="ranking">
#            13
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/portland">
#             Portland, Oregon (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            198
#           </td>
#          </tr>
#          <tr class="even" id="ranking_14">
#           <td class="ranking">
#            14
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/anchorage">
#             Anchorage, Alaska (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            197
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_15">
#           <td class="ranking">
#            15
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/denver">
#             Denver, Colorado (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            197
#           </td>
#          </tr>
#          <tr class="even" id="ranking_16">
#           <td class="ranking">
#            16
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/miami">
#             Miami, Florida (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            196
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_17">
#           <td class="ranking">
#            17
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/minneapolis">
#             Minneapolis - St. Paul, Minnesota (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            194
#           </td>
#          </tr>
#          <tr class="even" id="ranking_18">
#           <td class="ranking">
#            18
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/pittsburgh">
#             Pittsburgh, Pennsylvania (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            192
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_19">
#           <td class="ranking">
#            19
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/hartford-connecticut">
#             Hartford, Connecticut (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            191
#           </td>
#          </tr>
#          <tr class="even" id="ranking_20">
#           <td class="ranking">
#            20
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/toronto">
#             Toronto (Canada)
#            </a>
#           </td>
#           <td class="price-index">
#            190
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_21">
#           <td class="ranking">
#            21
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/baltimore">
#             Baltimore, Maryland (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            189
#           </td>
#          </tr>
#          <tr class="even" id="ranking_22">
#           <td class="ranking">
#            22
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/atlanta">
#             Atlanta, Georgia (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            187
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_23">
#           <td class="ranking">
#            23
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/austin">
#             Austin, Texas (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            185
#           </td>
#          </tr>
#          <tr class="even" id="ranking_24">
#           <td class="ranking">
#            24
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/mississauga">
#             Mississauga (Canada)
#            </a>
#           </td>
#           <td class="price-index">
#            183
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_25">
#           <td class="ranking">
#            25
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/sacramento">
#             Sacramento, California (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            182
#           </td>
#          </tr>
#          <tr class="even" id="ranking_26">
#           <td class="ranking">
#            26
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/vancouver">
#             Vancouver (Canada)
#            </a>
#           </td>
#           <td class="price-index">
#            182
#           </td>
#          </tr>
#          <tr class="odd" id="ranking_27">
#           <td class="ranking">
#            27
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/new-orleans">
#             New Orleans, Louisiana (United States)
#            </a>
#           </td>
#           <td class="price-index">
#            181
#           </td>
#          </tr>
#          <tr class="even" id="ranking_28">
#           <td class="ranking">
#            28
#           </td>
#           <td class="city-name">
#            <a href="https://www.expatistan.com/cost-of-living/fort-lauderdale">
#             Fort Lauderdale, Florida (United States)
#            </a>
# ...
#           <span class="city-1" style="font-weight:bold;">
#            Sydney
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/caracas/amsterdam">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Amsterdam
#           </span>
#           is
#           <span class="content cheaper">
#            50% cheaper
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Caracas
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/riyadh/dubai">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Dubai
#           </span>
#           is
#           <span class="content expensiver">
#            56% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Riyadh
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/puerto-galera/ciudad-guayana">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Ciudad Guayana
#           </span>
#           is
#           <span class="content expensiver">
#            101% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Puerto Galera
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/kuwait/dubai">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Dubai
#           </span>
#           is
#           <span class="content expensiver">
#            33% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Kuwait
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/london/toronto">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Toronto
#           </span>
#           is
#           <span class="content cheaper">
#            22% cheaper
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            London
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/riyadh/new-york-city">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            New York
#           </span>
#           is
#           <span class="content expensiver">
#            116% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Riyadh
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/toronto/vancouver">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Vancouver
#           </span>
#           is
#           <span class="content cheaper">
#            4% cheaper
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Toronto
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/kuwait/london">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            London
#           </span>
#           is
#           <span class="content expensiver">
#            58% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Kuwait
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/kuwait/seattle">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            Seattle
#           </span>
#           is
#           <span class="content expensiver">
#            39% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Kuwait
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/paris/london">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            London
#           </span>
#           is
#           <span class="content expensiver">
#            12% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Paris
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.expatistan.com/cost-of-living/comparison/istanbul/london">
#           Cost of living in
#           <span class="city-2" style="font-weight:bold;">
#            London
#           </span>
#           is
#           <span class="content expensiver">
#            88% more expensive
#           </span>
#           <span class="compartxt">
#            than
#           </span>
#           in
#           <span class="city-1" style="font-weight:bold;">
#            Istanbul
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="home-module centered right">
#        <h2 class="centered">
#         What is Expatistan?
#        </h2>
#        <p>
#         Expatistan is a cost of living calculator that allows you to compare the cost of living
#     between cities around the world. The comparisons allow you to get a better understanding
#     of the cost of living of any city before you move there.
#        </p>
#        <p>
#         What makes us unique is that we collect the prices that we use to calculate our cost of living index
#     from visitors like you. Naturally, the more data entered, the more accurate the index and the calculations will be.
#        </p>
#        <p>
#         That's why we need your help to keep prices accurate and up to date.
#         You can help by
#         <a href="/cost-of-living/rate/paris">
#          entering the prices that you know in Paris.
#         </a>
#        </p>
#       </div>
#       <div style="clear:both;">
#       </div>
#       <div class="home-module centered left" id="latestRatings">
#        <h2 class="centered">
#         Recent Prices Added
#        </h2>
#        <ul class="left-aligned">
#         <li>
#          Ipod nano 16gb in
#          <a href="https://www.expatistan.com/cost-of-living/houston" title="Prices and Cost of Living in Houston, Texas, United States">
#           Houston, Texas
#          </a>
#          costs $149
#          <span class="time-ago">
#           (1 minute ago)
#          </span>
#         </li>
#         <li>
#          Basic lunchtime menu (including a drink) in the business district in
#          <a href="https://www.expatistan.com/cost-of-living/oxford" title="Prices and Cost of Living in Oxford, United Kingdom">
#           Oxford
#          </a>
#          costs £12
#          <span class="time-ago">
#           (5 minutes ago)
#          </span>
#         </li>
#         <li>
#          Monthly rent - 900 sqft furnished accommodation in expensive area in
#          <a href="https://www.expatistan.com/cost-of-living/riverside" title="Prices and Cost of Living in Riverside, California, United States">
#           Riverside, California
#          </a>
#          costs $1,423
#          <span class="time-ago">
#           (7 minutes ago)
#          </span>
#         </li>
#         <li>
#          Summer dress in a high street store (zara, h&amp;m or similar retailers) in
#          <a href="https://www.expatistan.com/cost-of-living/san-juan-puerto-rico" title="Prices and Cost of Living in San Juan, Puerto Rico">
#           San Juan
#          </a>
#          costs $40
#          <span class="time-ago">
#           (12 minutes ago)
#          </span>
#         </li>
#         <li>
#          Volkswagen golf 2.0 tdi 140 cv (or equivalent), with no extras, new in
#          <a href="https://www.expatistan.com/cost-of-living/ipatinga" title="Prices and Cost of Living in Ipatinga, Brazil">
#           Ipatinga
#          </a>
#          costs R$ 30,000
#          <span class="time-ago">
#           (18 minutes ago)
#          </span>
#         </li>
#         <li>
#          Monthly rent - 900 sqft furnished accommodation in expensive area in
#          <a href="https://www.expatistan.com/cost-of-living/dallas" title="Prices and Cost of Living in Dallas, Texas, United States">
#           Dallas, Texas
#          </a>
#          costs $3,044
#          <span class="time-ago">
#           (38 minutes ago)
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="footer">
#     <h3 style="margin:2px;font-weight:normal;">
#      Collaborative international cost of living index.
#     </h3>
#     <h4 style="margin:0px 0px 60px 0px;font-weight:normal;">
#      You enter the prices, we make the comparisons.
#     </h4>
#     <!-- google_ad_section_start(weight=ignore) -->
#     <hr/>
#     <ul class="footerLinks">
#      <li class="first">
#       <a href="https://www.expatistan.com/international-schools-database?utm_campaign=internal_schools&amp;utm_content=footer&amp;utm_medium=internal&amp;utm_name=cost_of_life%3A%3Aindex&amp;utm_source=internal_schools">
#        International Schools Database
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/reports">
#        Salary Conversion Reports
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/reports/hr-services">
#        <strong>
#         Services for Human Resources
#        </strong>
#       </a>
#      </li>
#     </ul>
#     <hr/>
#     <br/>
#     <ul class="footerLinks">
#      <li class="first">
#       <a href="https://www.expatistan.com/faq">
#        Frequently Asked Questions
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/cost-of-living/index">
#        Cost of Living Index
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/cost-of-living/press-room">
#        Press room
#       </a>
#      </li>
#      <li>
#       <a href="//www.expatistan.com/blog">
#        Blog
#       </a>
#      </li>
#     </ul>
#     <ul class="footerLinks">
#      <li class="first">
#       <a href="https://www.expatistan.com/what-is-it">
#        What is it?
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/how-does-it-work">
#        How does it work?
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/who-are-we">
#        Who are we?
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/security">
#        Security
#       </a>
#      </li>
#      <li>
#       <a href="mailto:gerardo@expatistan.com">
#        Contact
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/sitemap/cost-of-living/comparison">
#        Sitemap
#       </a>
#      </li>
#      <li>
#       <a href="https://www.expatistan.com/tos">
#        Disclaimer &amp; Privacy policy
#       </a>
#      </li>
#     </ul>
#     <p id="copyright">
#      <a class="link" href="/cost-of-living/index/north-america?mobver=mobile">
#       Mobile version
#      </a>
#      <a class="link" href="/cost-of-living/index/north-america?mobver=full">
#       Full version
#      </a>
#      © 2009-2016 Expatistan.com
#     </p>
#     <!-- google_ad_section_end -->
#    </div>
#    <div class=" fb_reset" id="fb-root">
#     <div style="position: absolute; top: -10000px; height: 0px; width: 0px;">
#      <div>
#       <iframe allowfullscreen="true" allowtransparency="true" aria-hidden="true" frameborder="0" id="fb_xdm_frame_https" name="fb_xdm_frame_https" scrolling="no" src="https://staticxx.facebook.com/connect/xd_arbiter/r/P5DLcu0KGJB.js?version=42#channel=f73c6136c&amp;origin=https%3A%2F%2Fwww.expatistan.com" style="border: none;" tabindex="-1" title="Facebook Cross Domain Communication Frame">
#       </iframe>
#      </div>
#     </div>
#     <div style="position: absolute; top: -10000px; height: 0px; width: 0px;">
#      <div>
#      </div>
#     </div>
#    </div>
#    <script>
#     (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.3&appId=120841561302378";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#    </script>
#    <script type="text/javascript">
#     var _gaq = [['_setAccount', 'UA-6791730-1'], ['_trackPageview'], ['_trackPageLoadTime']];
#       (function(d, t) {
#     var g = d.createElement(t),
#         s = d.getElementsByTagName(t)[0];
#     g.async = g.src = '//www.google-analytics.com/ga.js';
#     s.parentNode.insertBefore(g, s);
#   }(document, 'script'));
#    </script>
#    <script type="text/javascript">
#     jQuery('document').ready(function(){ var a=Math.floor(Math.random()*11); var b=Math.floor(Math.random()*11);var x=jQuery.post('https://www.expatistan.com/ajax/humanize', {a: a, b: b, c: a+b}) });
#    </script>
#   </div>
#   <div id="flags_holder_rolling_down">
#   </div>
#   <script type="text/javascript">
#    (function() {
#           var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
#           po.src = 'https://apis.google.com/js/plusone.js';
#           var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
#         })();
#   </script>
#   <ul aria-activedescendant="ui-active-menuitem" class="ui-autocomplete ui-menu ui-widget ui-widget-content ui-corner-all" role="listbox" style="z-index: 1; top: 0px; left: 0px; display: none;">
#   </ul>
#   <ul aria-activedescendant="ui-active-menuitem" class="ui-autocomplete ui-menu ui-widget ui-widget-content ui-corner-all" role="listbox" style="z-index: 1; top: 0px; left: 0px; display: none;">
#   </ul>
#   <div id="fancybox-tmp">
#   </div>
#   <div id="fancybox-loading">
#    <div>
#    </div>
#   </div>
#   <div id="fancybox-overlay">
#   </div>
#   <div id="fancybox-wrap">
#    <div id="fancybox-outer">
#     <div class="fancybox-bg" id="fancybox-bg-n">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-ne">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-e">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-se">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-s">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-sw">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-w">
#     </div>
#     <div class="fancybox-bg" id="fancybox-bg-nw">
#     </div>
#     <div id="fancybox-content">
#     </div>
#     <a id="fancybox-close">
#     </a>
#     <div id="fancybox-title">
#     </div>
#     <a href="javascript:;" id="fancybox-left">
#      <span class="fancy-ico" id="fancybox-left-ico">
#      </span>
#     </a>
#     <a href="javascript:;" id="fancybox-right">
#      <span class="fancy-ico" id="fancybox-right-ico">
#      </span>
#     </a>
#    </div>
#   </div>
#   <iframe aria-hidden="true" id="oauth2relay811515187" name="oauth2relay811515187" src="https://accounts.google.com/o/oauth2/postmessageRelay?parent=https%3A%2F%2Fwww.expatistan.com&amp;jsh=m%3B%2F_%2Fscs%2Fapps-static%2F_%2Fjs%2Fk%3Doz.gapi.en_US.FttDLlUdXcw.O%2Fm%3D__features__%2Fam%3DEQ%2Frt%3Dj%2Fd%3D1%2Frs%3DAGLTcCO6rxixa7pa711_uOW2yjCmjc9Cfw#rpctoken=861512477&amp;forcesecure=1" style="width: 1px; height: 1px; position: absolute; top: -100px;" tabindex="-1">
#   </iframe>
#  </body>
# </html>

# %%
c = []
r = []
for city in soup.findAll('table',class_="city-index"):
    for cities in soup.findAll('td',class_='city-name'):
        c.append(cities.text)
    for rank in soup.findAll('td',class_='price-index'):
        r.append(rank.text)


COL = pd.DataFrame([c, r]).T
COL = COL.rename(columns = {0:'Cities',1:'price_index'})
COL['Cities'] = COL['Cities'].apply(lambda x: str(x).split(',')).apply(lambda x: x[0]).apply(lambda x: str(x).replace(' (United States)',''))
COL['price_index'] = COL['price_index'].astype(int)
new_base  = COL.loc[0,'price_index']
COL['COL_new'] = COL['price_index'].apply(lambda x: float(new_base)/x)
COL.loc[16,'Cities'] = 'Minneapolis'
COL.loc[2,'Cities'] = 'Washington, DC'
print master_df.shape
master_df = pd.merge(master_df,COL.iloc[:,[0,-1]], left_on='search_city',right_on='Cities',how='left')
del master_df['Cities']
del master_df['Unnamed: 0']
del master_df['Unnamed: 0.1']
master_df
# print COL['Cities'].unique()
# print master_df['search_city'].unique()
# COL
# Out:
# (13138, 17)
#                          location  \
# 0                     Atlanta, GA
# 1                     Atlanta, GA
# 2                     Atlanta, GA
# 3                     Atlanta, GA
# 4                     Atlanta, GA
# 5                     Atlanta, GA
# 6                     Atlanta, GA
# 7                     Atlanta, GA
# 8                     Atlanta, GA
# 9                     Atlanta, GA
# 10                    Atlanta, GA
# 11                    Atlanta, GA
# 12                    Atlanta, GA
# 13                    Atlanta, GA
# 14                    Atlanta, GA
# 15                    Atlanta, GA
# 16                    Atlanta, GA
# 17                    Atlanta, GA
# 18                    Atlanta, GA
# 19                    Atlanta, GA
# 20                    Atlanta, GA
# 21                    Atlanta, GA
# 22                    Atlanta, GA
# 23                    Atlanta, GA
# 24                 Alpharetta, GA
# 25                 Alpharetta, GA
# 26                    Atlanta, GA
# 27                    Atlanta, GA
# 28                    Atlanta, GA
# 29                    Atlanta, GA
# ...                           ...
# 13108             Santa Clara, CA
# 13109                New York, NY
# 13110                  McLean, VA
# 13111                Carlsbad, CA
# 13112              Pittsburgh, PA
# 13113                New York, NY
# 13114                 Houston, TX
# 13115                New York, NY
# 13116                New York, NY
# 13117                 Redmond, WA
# 13118                 Hershey, PA
# 13119               Manhattan, NY
# 13120                New York, NY
# 13121             Westchester, NY
# 13122                New York, NY
# 13123                 Clayton, MO
# 13124                Hartford, CT
# 13125                 Chicago, IL
# 13126              Pleasanton, CA
# 13127               Cambridge, MA
# 13128                 Seattle, WA
# 13129  Research Triangle Park, NC
# 13130                 Medford, MA
# 13131                  Carmel, IN
# 13132             Morrisville, NC
# 13133             Minneapolis, MN
# 13134                 Atlanta, GA
# 13135                   Tampa, FL
# 13136                  Michigan,
# 13137      Santa Clara Valley, CA
#
#                                               company  \
# 0                                                KPMG
# 1                                            ASSURANT
# 2                                                360i
# 3          Centers for Disease Control and Prevention
# 4                                   Vesta Corporation
# 5                                      Cox Automotive
# 6                                            ASSURANT
# 7                        Ga. Dept. of Admin. Services
# 8      State Farm Mutual Automobile Insurance Company
# 9                                           Honeywell
# 10                                             Google
# 11                                         Travelport
# 12                                            Kabbage
# 13                                         Home Depot
# 14                                               360i
# 15                                         eHire, LLC
# 16                                           Bastille
# 17                                          Honeywell
# 18                    Georgia Tech Research Institute
# 19         Centers for Disease Control and Prevention
# 20                                          HD Supply
# 21                                         Stackfolio
# 22                                               KPMG
# 23                                           SunTrust
# 24                                 krg technology inc
# 25                                            Verizon
# 26                                           GE Power
# 27                                  NIIT Technologies
# 28                                            Feedzai
# 29                                          Honeywell
# ...                                               ...
# 13108                                        LeanTaas
# 13109                                         Averity
# 13110                                 Cognosante, LLC
# 13111                                  CDM Technology
# 13112                                 Health Fidelity
# 13113                                             NBA
# 13114                       MD Anderson Cancer Center
# 13115                       automotiveMastermind Inc.
# 13116                               Analytic Partners
# 13117                               Posh Technologies
# 13118                                         Hershey
# 13119                   DEPT OF HEALTH/MENTAL HYGIENE
# 13120                                 Correlation One
# 13121                          L.J. Gonzer Associates
# 13122                               Rockstar New York
# 13123                   Business Intelligence-Finance
# 13124                            PNS IT Solutions LLC
# 13125                                            HERE
# 13126                                    10X Genomics
# 13127                                        BioPoint
# 13128                        Adaptive Biotechnologies
# 13129                                      SciMetrika
# 13130                                     Agero, Inc.
# 13131                                      Adesa Inc.
# 13132                                     Lab Support
# 13133                                   General Mills
# 13134                                      eHire, LLC
# 13135                            Elite WorkForce, Inc
# 13136                           Sparrow Health System
# 13137                                           Apple
#
#                                                  summary              jkid  \
# 0      Machine learning, data visualization, statisti...  53b7f855d4891e19
# 1      3+ years of relevant experience in analytics, ...  9ecd8095dd0355f8
# 2      The Associate Data Scientist will be mentored ...  c2b6dcbcb0895072
# 3      Whether we are protecting the American people ...  40d8215afa28f4bb
# 4      Or PhD in Computer Science, Statistics, Applie...  24cec20de39398ca
# 5      Interprets problems and develops solutions to ...  4dd0428a36b610d7
# 6      The primary objective of this position is to e...  ed7467a761020f51
# 7      SQL Server knowledge for developing queries an...  134c301ec3ba87c4
# 8      Academic background in quantitative discipline...  594e039f37d4ec5d
# 9      Data modeling, mining, pattern analysis, data ...  9b253c3eeae5f37a
# 10     The Google Cloud training team already develop...  b96291bcf9c19e0a
# 11     Developing and implementing advanced analytics...  324aa9db249c02a7
# 12     As a part of the Data Science team, you will d...  6e3ccea1c8472429
# 13     3 years of experience in data mining and stati...  07d2ec530def558d
# 14     Data Scientist will work directly with 360i cl...  abb5e77d57d05bfb
# 15     Strong background in applying statistical mach...  f0341f282e4dc253
# 16     Position Bastille is seeking badass Data Scien...  f5d182f58df6fd06
# 17     Master’s degree in Computer Science, Mathemati...  3ab193931df8ad50
# 18     The Georgia Tech Research Institute's Machine ...  0b18bd331be1a5ca
# 19     Whether we are protecting the American people ...  ece367560a42bf9b
# 20     Responsible for modeling complex enterprise pr...  5e4122b4e399341b
# 21     A competitive full-time salary as well as a gr...  be3a7444db34e9a3
# 22     Machine learning, data visualization, statisti...  57dc2330cb3ed3c0
# 23     Performs sophisticated data analytics (encompa...  16b342fb19d2cf92
# 24     Data scientist with either a Masters or PhD. S...  c033d176ea5a13bf
# 25     Apply machine learning and statistical techniq...  2eeab08cd59a3296
# 26     Architects, Data Scientists, Businesses and Pr...  3cd633102b36edc1
# 27     Expertise in operations research, applied stat...  42835cf45915a966
# 28     Implement Feedzai's machine learning algorithm...  241bf43cfe61f5c0
# 29     Support and mentor data scientists. Master’s d...  78f1a9a1e62191ef
# ...                                                  ...               ...
# 13108  LeanTaaS is looking for extraordinary data sci...  5d731bfd520450cd
# 13109  Enabling our Data Scientists to create product...  65ec1f25972d992b
# 13110  Cognosante is looking for a few talented data ...  8d1e1f06592788ab
# 13111  You like the idea of partnering with scientist...  f7b51f642226d60c
# 13112  Using groundbreaking NLP and analytics technol...  d7b8192c8ed6599f
# 13113  Deep bench and experience in leading data scie...  95d2ca6db8e5c267
# 13114  The primary purpose of the Research Statistica...  c3d60a2a43db94fe
# 13115  An MS/PhD program in Statistics, Mathematics, ...  2d12ad4b56eb3cb8
# 13116  Lead/assist in methodology research and soluti...  d156a798af051399
# 13117  Design and build new data set processes for mo...  11cf38718f8c5eec
# 13118  8+ years experience in Statistics, Machine Lea...  88b5434ff5ebee2c
# 13119  Today, PHL responds to essential and emergency...  f94515b4ae33dd47
# 13120  We are a science-driven systematic trading fir...  d3afe33484d088a4
# 13121  Data analysis and interpretation. Preparing ma...  0640e5d08d73f155
# 13122  Serve as a subject matter expert to the securi...  0e486be090f66c4e
# 13123  Master’s degree in Statistics, Mathematics, Co...  46cdbbd2f5a93a98
# 13124  Leadership of the team involves direct managem...  0cb4527a47b567d7
# 13125  Data mining, machine learning, and optimizatio...  1636eef60b3362f7
# 13126  Deep understanding of the NGS applications spa...  50a2e75ed126754e
# 13127  Strong statistical quantitative skills, includ...  8e3b71a666945af0
# 13128  Maintain and establish good working relationsh...  f9957b82b86276f7
# 13129  ScitoVation scientist have earned a reputation...  5a6bca92e8012c2a
# 13130  5 years of experience building and applying so...  cb8cea591851c2a5
# 13131  Data access by data scientists and the mainten...  14777a837760f869
# 13132  Ability to identify aberrant/out of spec data ...  664005e69d87418a
# 13133  Comfortable in basic statistical analysis, mod...  7b3a98f4ccc83b68
# 13134  Strong background in applying statistical mach...  f0341f282e4dc253
# 13135  Senior Data Scientist Location:. Data Scientis...  cad4d0671d1752c3
# 13136  Work with and assist Sparrow Graduate Medical ...  8a102fe16026588b
# 13137  Experience with machine learning tools and lib...  269a60a59d86d234
#
#                                                    title  \
# 0                                         Data Scientist
# 1                                         Data Scientist
# 2                               Associate Data Scientist
# 3                                       HEALTH SCIENTIST
# 4                                  Senior Data Scientist
# 5                                         Data Scientist
# 6                              Sr Data Scientist - Fraud
# 7                               Statistical Data Analyst
# 8                                  Research Statistician
# 9                               Analytics Data Scientist
# 10     Cloud Instructor (Big Data, Machine Learning),...
# 11                                        Data Scientist
# 12                                        Data Scientist
# 13                                        DATA SCIENTIST
# 14                                     Sr Data Scientist
# 15                                     Sr Data Scientist
# 16                                        Data Scientist
# 17                       Sr Data Scientist - Atlanta, GA
# 18     Machine Learning-Data Science Computer Vision ...
# 19                        Health Scientist (Informatics)
# 20                                        Data Scientist
# 21                                   Lead Data Scientist
# 22                         Sr Associate - Data Scientist
# 23         Consumer Banking Data Scientist - Atlanta, GA
# 24                                        Data Scientist
# 25                                 Senior Data Scientist
# 26             Staff Analytics Engineer – Installed Base
# 27                                        Data Scientist
# 28                                        Data Scientist
# 29                Principal Data Scientist - Atlanta, GA
# ...                                                  ...
# 13108                              Senior Data Scientist
# 13109     Executive Director of Data Engineering (Media)
# 13110                                Data Analyst Intern
# 13111                      Java/Python Software Engineer
# 13112                                     Data Scientist
# 13113                 Senior Director, Data Intelligence
# 13114                       Research Statistical Analyst
# 13115                                     Data Scientist
# 13116                                     Data Scientist
# 13117                          Data Scientist(Position5)
# 13118                                     Data Scientist
# 13119  Senior Laboratory Data Analyst, Bureau of the ...
# 13120                      Quantitative Research Analyst
# 13121                                Ph.D Data Scientist
# 13122                            Security Data Scientist
# 13123                                   Data Scientist I
# 13124     Data Scientist / Data Modeling / Data Engineer
# 13125                           Principal Data Scientist
# 13126                          Applications Data Analyst
# 13127              Outcomes Research Statistician (8480)
# 13128                                    Biostatistician
# 13129                                Statistical Modeler
# 13130                                     Data Scientist
# 13131                              Data Science Arhitect
# 13132                   Associate Scientist- Data Review
# 13133         Data Scientist - Global Business Solutions
# 13134                                  Sr Data Scientist
# 13135                              Senior Data Scientist
# 13136                         SCRI-RESEARCH DATA ANALYST
# 13137                          Data Scientist - Maps POI
#
#                                salary  stars  reviews  post_date_daysAgo  \
# 0                           (0, 0, 0)    4.0   1768.0           2.000000
# 1                           (0, 0, 0)    3.5   1107.0          10.000000
# 2                           (0, 0, 0)    4.0      9.0          11.000000
# 3             (88305, 114802, 101553)    4.5     64.0           1.000000
# 4                           (0, 0, 0)    3.0     31.0           9.000000
# 5                           (0, 0, 0)    3.0     42.0          12.000000
# 6                           (0, 0, 0)    3.5   1107.0           1.000000
# 7                           (0, 0, 0)    NaN      0.0           5.000000
# 8                           (0, 0, 0)    4.0   3358.0           3.000000
# 9                           (0, 0, 0)    3.5   3474.0          10.000000
# 10                          (0, 0, 0)    4.0   1218.0           3.000000
# 11                          (0, 0, 0)    4.0     52.0          30.000000
# 12                          (0, 0, 0)    NaN      0.0          45.000000
# 13                          (0, 0, 0)    3.5  20594.0          29.000000
# 14                          (0, 0, 0)    4.0      9.0          19.000000
# 15           (150000, 150000, 150000)    NaN      0.0          16.000000
# 16                          (0, 0, 0)    NaN      0.0          45.000000
# 17                          (0, 0, 0)    3.5   3474.0          24.000000
# 18                          (0, 0, 0)    4.0    255.0          11.000000
# 19           (104349, 135656, 120002)    4.5     64.0           2.000000
# 20                          (0, 0, 0)    3.5    489.0          45.000000
# 21              (80000, 80000, 80000)    NaN      0.0          45.000000
# 22                          (0, 0, 0)    4.0   1768.0          24.000000
# 23                          (0, 0, 0)    3.5   2101.0          45.000000
# 24                          (0, 0, 0)    NaN      0.0          45.000000
# 25                          (0, 0, 0)    3.5  11112.0          19.000000
# 26                          (0, 0, 0)    4.0    153.0          13.000000
# 27                          (0, 0, 0)    3.5    122.0          45.000000
# 28                          (0, 0, 0)    NaN      0.0          45.000000
# 29                          (0, 0, 0)    3.5   3474.0          24.000000
# ...                               ...    ...      ...                ...
# 13108                       (0, 0, 0)    NaN      0.0          16.000000
# 13109        (200000, 230000, 215000)    NaN      0.0           4.000000
# 13110                       (0, 0, 0)    3.5     14.0           0.041667
# 13111  (124800.0, 124800.0, 124800.0)    NaN      0.0           4.000000
# 13112                       (0, 0, 0)    NaN      0.0          45.000000
# 13113                       (0, 0, 0)    4.0     20.0          45.000000
# 13114                       (0, 0, 0)    4.0    250.0          30.000000
# 13115                       (0, 0, 0)    NaN      0.0          45.000000
# 13116                       (0, 0, 0)    NaN      0.0          45.000000
# 13117                       (0, 0, 0)    NaN      0.0          45.000000
# 13118                       (0, 0, 0)    3.5    308.0          45.000000
# 13119                       (0, 0, 0)    4.0      5.0          22.000000
# 13120                       (0, 0, 0)    NaN      0.0          11.000000
# 13121                       (0, 0, 0)    3.5      2.0          20.000000
# 13122                       (0, 0, 0)    NaN      0.0          45.000000
# 13123                       (0, 0, 0)    NaN      0.0          45.000000
# 13124                       (0, 0, 0)    NaN      0.0          12.000000
# 13125                       (0, 0, 0)    3.5     56.0          10.000000
# 13126                       (0, 0, 0)    NaN      0.0          20.000000
# 13127                       (0, 0, 0)    NaN      0.0           1.000000
# 13128                       (0, 0, 0)    NaN      0.0          20.000000
# 13129                       (0, 0, 0)    4.0      3.0           1.000000
# 13130                       (0, 0, 0)    NaN      0.0          45.000000
# 13131                       (0, 0, 0)    3.0    205.0          45.000000
# 13132                       (0, 0, 0)    3.5     55.0           1.000000
# 13133                       (0, 0, 0)    4.0    559.0          20.000000
# 13134        (150000, 150000, 150000)    NaN      0.0          16.000000
# 13135                       (0, 0, 0)    NaN      0.0          20.000000
# 13136                       (0, 0, 0)    3.5     56.0          16.000000
# 13137                       (0, 0, 0)    4.0   2570.0          22.000000
#
#                         pull_date search_city  \
# 0      2016-10-17 00:20:29.507371     Atlanta
# 1      2016-10-17 00:20:29.507371     Atlanta
# 2      2016-10-17 00:20:29.507371     Atlanta
# 3      2016-10-17 00:20:29.507371     Atlanta
# 4      2016-10-17 00:20:29.507371     Atlanta
# 5      2016-10-17 00:20:29.507371     Atlanta
# 6      2016-10-17 00:20:29.507371     Atlanta
# 7      2016-10-17 00:20:29.507371     Atlanta
# 8      2016-10-17 00:20:29.507371     Atlanta
# 9      2016-10-17 00:20:29.507371     Atlanta
# 10     2016-10-17 00:20:29.507371     Atlanta
# 11     2016-10-17 00:20:29.507371     Atlanta
# 12     2016-10-17 00:20:29.507371     Atlanta
# 13     2016-10-17 00:20:29.507371     Atlanta
# 14     2016-10-17 00:20:29.507371     Atlanta
# 15     2016-10-17 00:20:29.507371     Atlanta
# 16     2016-10-17 00:20:29.507371     Atlanta
# 17     2016-10-17 00:20:29.507371     Atlanta
# 18     2016-10-17 00:20:29.507371     Atlanta
# 19     2016-10-17 00:20:29.507371     Atlanta
# 20     2016-10-17 00:20:29.507371     Atlanta
# 21     2016-10-17 00:20:29.507371     Atlanta
# 22     2016-10-17 00:20:29.507371     Atlanta
# 23     2016-10-17 00:20:29.507371     Atlanta
# 24     2016-10-17 00:20:29.507371     Atlanta
# 25     2016-10-17 00:20:29.507371     Atlanta
# 26     2016-10-17 00:20:29.507371     Atlanta
# 27     2016-10-17 00:20:29.507371     Atlanta
# 28     2016-10-17 00:20:29.507371     Atlanta
# 29     2016-10-17 00:20:29.507371     Atlanta
# ...                           ...         ...
# 13108  2016-10-17 00:12:22.949204         NaN
# 13109  2016-10-17 00:12:22.949204         NaN
# 13110  2016-10-17 00:12:22.949204         NaN
# 13111  2016-10-17 00:12:22.949204         NaN
# 13112  2016-10-17 00:12:22.949204         NaN
# 13113  2016-10-17 00:12:22.949204         NaN
# 13114  2016-10-17 00:12:22.949204         NaN
# 13115  2016-10-17 00:12:22.949204         NaN
# 13116  2016-10-17 00:12:22.949204         NaN
# 13117  2016-10-17 00:12:22.949204         NaN
# 13118  2016-10-17 00:12:22.949204         NaN
# 13119  2016-10-17 00:12:22.949204         NaN
# 13120  2016-10-17 00:12:22.949204         NaN
# 13121  2016-10-17 00:12:22.949204         NaN
# 13122  2016-10-17 00:12:22.949204         NaN
# 13123  2016-10-17 00:12:22.949204         NaN
# 13124  2016-10-17 00:12:22.949204         NaN
# 13125  2016-10-17 00:12:22.949204         NaN
# 13126  2016-10-17 00:12:22.949204         NaN
# 13127  2016-10-17 00:12:22.949204         NaN
# 13128  2016-10-17 00:12:22.949204         NaN
# 13129  2016-10-17 00:12:22.949204         NaN
# 13130  2016-10-17 00:12:22.949204         NaN
# 13131  2016-10-17 00:12:22.949204         NaN
# 13132  2016-10-17 00:12:22.949204         NaN
# 13133  2016-10-17 00:12:22.949204         NaN
# 13134  2016-10-17 00:12:22.949204         NaN
# 13135  2016-10-17 00:12:22.949204         NaN
# 13136  2016-10-17 00:12:22.949204         NaN
# 13137  2016-10-17 00:12:22.949204         NaN
#
#                                                job_link  COL_new_x  COL_new_y  \
# 0      http://www.indeed.com/rc/clk?jk=53b7f855d4891e19   1.502674   1.502674
# 1      http://www.indeed.com/rc/clk?jk=9ecd8095dd0355f8   1.502674   1.502674
# 2      http://www.indeed.com/rc/clk?jk=c2b6dcbcb0895072   1.502674   1.502674
# 3      http://www.indeed.com/rc/clk?jk=40d8215afa28f4bb   1.502674   1.502674
# 4      http://www.indeed.com/rc/clk?jk=24cec20de39398ca   1.502674   1.502674
# 5      http://www.indeed.com/rc/clk?jk=4dd0428a36b610d7   1.502674   1.502674
# 6      http://www.indeed.com/rc/clk?jk=ed7467a761020f51   1.502674   1.502674
# 7      http://www.indeed.com/rc/clk?jk=134c301ec3ba87c4   1.502674   1.502674
# 8      http://www.indeed.com/rc/clk?jk=594e039f37d4ec5d   1.502674   1.502674
# 9      http://www.indeed.com/rc/clk?jk=9b253c3eeae5f37a   1.502674   1.502674
# 10     http://www.indeed.com/rc/clk?jk=b96291bcf9c19e0a   1.502674   1.502674
# 11     http://www.indeed.com/rc/clk?jk=324aa9db249c02a7   1.502674   1.502674
# 12     http://www.indeed.com/rc/clk?jk=6e3ccea1c8472429   1.502674   1.502674
# 13     http://www.indeed.com/rc/clk?jk=07d2ec530def558d   1.502674   1.502674
# 14     http://www.indeed.com/rc/clk?jk=abb5e77d57d05bfb   1.502674   1.502674
# 15     http://www.indeed.com/rc/clk?jk=f0341f282e4dc253   1.502674   1.502674
# 16     http://www.indeed.com/rc/clk?jk=f5d182f58df6fd06   1.502674   1.502674
# 17     http://www.indeed.com/rc/clk?jk=3ab193931df8ad50   1.502674   1.502674
# 18     http://www.indeed.com/rc/clk?jk=0b18bd331be1a5ca   1.502674   1.502674
# 19     http://www.indeed.com/rc/clk?jk=ece367560a42bf9b   1.502674   1.502674
# 20     http://www.indeed.com/rc/clk?jk=5e4122b4e399341b   1.502674   1.502674
# 21     http://www.indeed.com/rc/clk?jk=be3a7444db34e9a3   1.502674   1.502674
# 22     http://www.indeed.com/rc/clk?jk=57dc2330cb3ed3c0   1.502674   1.502674
# 23     http://www.indeed.com/rc/clk?jk=16b342fb19d2cf92   1.502674   1.502674
# 24     http://www.indeed.com/rc/clk?jk=c033d176ea5a13bf   1.502674   1.502674
# 25     http://www.indeed.com/rc/clk?jk=2eeab08cd59a3296   1.502674   1.502674
# 26     http://www.indeed.com/rc/clk?jk=3cd633102b36edc1   1.502674   1.502674
# 27     http://www.indeed.com/rc/clk?jk=42835cf45915a966   1.502674   1.502674
# 28     http://www.indeed.com/rc/clk?jk=241bf43cfe61f5c0   1.502674   1.502674
# 29     http://www.indeed.com/rc/clk?jk=78f1a9a1e62191ef   1.502674   1.502674
# ...                                                 ...        ...        ...
# 13108  http://www.indeed.com/rc/clk?jk=5d731bfd520450cd        NaN        NaN
# 13109  http://www.indeed.com/rc/clk?jk=65ec1f25972d992b        NaN        NaN
# 13110  http://www.indeed.com/rc/clk?jk=8d1e1f06592788ab        NaN        NaN
# 13111  http://www.indeed.com/rc/clk?jk=f7b51f642226d60c        NaN        NaN
# 13112  http://www.indeed.com/rc/clk?jk=d7b8192c8ed6599f        NaN        NaN
# 13113  http://www.indeed.com/rc/clk?jk=95d2ca6db8e5c267        NaN        NaN
# 13114  http://www.indeed.com/rc/clk?jk=c3d60a2a43db94fe        NaN        NaN
# 13115  http://www.indeed.com/rc/clk?jk=2d12ad4b56eb3cb8        NaN        NaN
# 13116  http://www.indeed.com/rc/clk?jk=d156a798af051399        NaN        NaN
# 13117  http://www.indeed.com/rc/clk?jk=11cf38718f8c5eec        NaN        NaN
# 13118  http://www.indeed.com/rc/clk?jk=88b5434ff5ebee2c        NaN        NaN
# 13119  http://www.indeed.com/rc/clk?jk=f94515b4ae33dd47        NaN        NaN
# 13120  http://www.indeed.com/rc/clk?jk=d3afe33484d088a4        NaN        NaN
# 13121  http://www.indeed.com/rc/clk?jk=0640e5d08d73f155        NaN        NaN
# 13122  http://www.indeed.com/rc/clk?jk=0e486be090f66c4e        NaN        NaN
# 13123  http://www.indeed.com/rc/clk?jk=46cdbbd2f5a93a98        NaN        NaN
# 13124  http://www.indeed.com/rc/clk?jk=0cb4527a47b567d7        NaN        NaN
# 13125  http://www.indeed.com/rc/clk?jk=1636eef60b3362f7        NaN        NaN
# 13126  http://www.indeed.com/rc/clk?jk=50a2e75ed126754e        NaN        NaN
# 13127  http://www.indeed.com/rc/clk?jk=8e3b71a666945af0        NaN        NaN
# 13128  http://www.indeed.com/rc/clk?jk=f9957b82b86276f7        NaN        NaN
# 13129  http://www.indeed.com/rc/clk?jk=5a6bca92e8012c2a        NaN        NaN
# 13130  http://www.indeed.com/rc/clk?jk=cb8cea591851c2a5        NaN        NaN
# 13131  http://www.indeed.com/rc/clk?jk=14777a837760f869        NaN        NaN
# 13132  http://www.indeed.com/rc/clk?jk=664005e69d87418a        NaN        NaN
# 13133  http://www.indeed.com/rc/clk?jk=7b3a98f4ccc83b68        NaN        NaN
# 13134  http://www.indeed.com/rc/clk?jk=f0341f282e4dc253        NaN        NaN
# 13135  http://www.indeed.com/rc/clk?jk=cad4d0671d1752c3        NaN        NaN
# 13136  http://www.indeed.com/rc/clk?jk=8a102fe16026588b        NaN        NaN
# 13137  http://www.indeed.com/rc/clk?jk=269a60a59d86d234        NaN        NaN
#
#        COL_new_x  COL_new_y
# 0       1.502674   1.502674
# 1       1.502674   1.502674
# 2       1.502674   1.502674
# 3       1.502674   1.502674
# 4       1.502674   1.502674
# 5       1.502674   1.502674
# 6       1.502674   1.502674
# 7       1.502674   1.502674
# 8       1.502674   1.502674
# 9       1.502674   1.502674
# 10      1.502674   1.502674
# 11      1.502674   1.502674
# 12      1.502674   1.502674
# 13      1.502674   1.502674
# 14      1.502674   1.502674
# 15      1.502674   1.502674
# 16      1.502674   1.502674
# 17      1.502674   1.502674
# 18      1.502674   1.502674
# 19      1.502674   1.502674
# 20      1.502674   1.502674
# 21      1.502674   1.502674
# 22      1.502674   1.502674
# 23      1.502674   1.502674
# 24      1.502674   1.502674
# 25      1.502674   1.502674
# 26      1.502674   1.502674
# 27      1.502674   1.502674
# 28      1.502674   1.502674
# 29      1.502674   1.502674
# ...          ...        ...
# 13108        NaN        NaN
# 13109        NaN        NaN
# 13110        NaN        NaN
# 13111        NaN        NaN
# 13112        NaN        NaN
# 13113        NaN        NaN
# 13114        NaN        NaN
# 13115        NaN        NaN
# 13116        NaN        NaN
# 13117        NaN        NaN
# 13118        NaN        NaN
# 13119        NaN        NaN
# 13120        NaN        NaN
# 13121        NaN        NaN
# 13122        NaN        NaN
# 13123        NaN        NaN
# 13124        NaN        NaN
# 13125        NaN        NaN
# 13126        NaN        NaN
# 13127        NaN        NaN
# 13128        NaN        NaN
# 13129        NaN        NaN
# 13130        NaN        NaN
# 13131        NaN        NaN
# 13132        NaN        NaN
# 13133        NaN        NaN
# 13134        NaN        NaN
# 13135        NaN        NaN
# 13136        NaN        NaN
# 13137        NaN        NaN
#
# [13138 rows x 16 columns]

# %%
#Cleans title
master_df['title'] = map(lambda x: x.lower(), master_df['title'])
master_df['title'] = (master_df['title'].replace( 'sr.','senior ', regex=True))
master_df['title'] = (master_df['title'].replace( 'senior  ','senior ', regex=True))
#Remove title from database
temp_df = master_df.T
temp_df = temp_df[[ind for ind, x in enumerate(master_df['title']) if "title" not in x]].T
master_df = temp_df.reset_index(drop=True)
#Remove Intern from database
temp_df = master_df.T
temp_df = temp_df[[ind for ind, x in enumerate(master_df['title']) if "intern" not in x]].T
master_df = temp_df.reset_index(drop=True)
#Remove Devop from database
temp_df = master_df.T
temp_df = temp_df[[ind for ind, x in enumerate(master_df['title']) if "devop" not in x]].T
master_df = temp_df.reset_index(drop=True)
df_range = len(master_df)
master_df['level'] = 0
#Entry = 0
#Middle = 1
#Senior = 2
for x in range(df_range):
    if "associate" in master_df['title'][x] or "junior" in master_df['title'][x] or "entry" in master_df['title'][x]:
        master_df['level'][x] = 0
    elif "senior" in master_df['title'][x] or "principal" in master_df['title'][x] or "lead" in master_df['title'][x]:
        master_df['level'][x] = 2
    else:
        master_df['level'][x] = 1

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE
