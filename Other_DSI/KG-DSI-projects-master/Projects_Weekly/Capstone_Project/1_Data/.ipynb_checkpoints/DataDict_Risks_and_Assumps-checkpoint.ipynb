# %% [markdown]
# # Data: Dictionary, Risks and Assumptions

# %% [markdown]
# #### For project context, aims, and problem statement, please check out my accompanying git hub blog post at this link:
# https://kgracia44.github.io/capstone_post/

# %% [markdown]
# ____________________________________________________________________________________________________________________
#
# ### --Data Dictionary (describing the contents of each variable) --
#
# ##### (for csv file of data_dict, see data_dict_capstone.csv in git hub folder)

# %%
import pandas as pd

data_dict = pd.read_csv('data_dict_capstone.csv')

data_dict
# Out:
#        Variable Name  Total (not null) Values           data type  \
# 0               Wave                    34017  str (dtype object)
# 1             StFCID                    34017  str (dtype object)
# 2   RepDate_outcomes                    34017      datetime64[ns]
# 3           OutcmRpt                    34017  str (dtype object)
# 4           OutcmDte                    29882      datetime64[ns]
# 5           OutcmFCS                    34017  str (dtype object)
# 6            CurrFTE                    34017  str (dtype object)
# 7            CurrPTE                    34017  str (dtype object)
# 8         EmplySklls                    34017  str (dtype object)
# 9          SocSecrty                    34017  str (dtype object)
# 10           EducAid                    34017  str (dtype object)
# 11          PubFinAs                    34017  str (dtype object)
# 12         PubFoodAs                    34017  str (dtype object)
# 13         PubHousAs                    34017  str (dtype object)
# 14         OthrFinAs                    34017  str (dtype object)
# 15        HighEdCert                    33816  str (dtype object)
# 16        CurrenRoll                    34017  str (dtype object)
# 17         CnctAdult                    34017  str (dtype object)
# 18          Homeless                    34017  str (dtype object)
# 19          SubAbuse                    34017  str (dtype object)
# 20            Incarc                    34017  str (dtype object)
# 21          Children                    34017  str (dtype object)
# 22          Marriage                    34017  str (dtype object)
# 23          Medicaid                    34017  str (dtype object)
# 24        OthrHlthIn                    34017  str (dtype object)
# 25         MedicalIn                    34017  str (dtype object)
# 26       MentlHlthIn                    34017  str (dtype object)
# 27        PrescripIn                    34017  str (dtype object)
# 28       SampleState                    34017  str (dtype object)
# 29          InSample                    15448  str (dtype object)
# ..               ...                      ...                 ...
# 41            AmIAKN                    34017               int64
# 42             Asian                    34017               int64
# 43          BlkAfrAm                    34017               int64
# 44          HawaiiPI                    34017               int64
# 45             White                    34017               int64
# 46          RaceUnkn                    34017               int64
# 47          RaceDcln                    34017               int64
# 48          HisOrgin                    34017               int64
# 49          FCStatSv                    34017               int64
# 50           TribeSv                    34017               int64
# 51        DelinqntSv                    34017               int64
# 52          EdLevlSv                    34017               int64
# 53          SpecEdSv                    34017               int64
# 54            ILNAsv                    34017               int64
# 55          AcSuppSv                    34017               int64
# 56        PSEdSuppSv                    34017               int64
# 57          CareerSv                    34017               int64
# 58         EmplyTrSv                    34017               int64
# 59          BudgetSv                    34017               int64
# 60          HousEdSv                    34017               int64
# 61          HlthEdSv                    34017               int64
# 62         FamSuppSv                    34017               int64
# 63          MentorSv                    34017               int64
# 64             SILsv                    34017               int64
# 65         RmBrdFASv                    34017               int64
# 66        EducFinaSv                    34017               int64
# 67        OthrFinaSv                    34017               int64
# 68              Race                    34017               int64
# 69          RaceEthn                    34017               int64
# 70             AgeMP                    34017               int64
#
#               variable type  \
# 0               categorical
# 1         unique ID/tracker
# 2   date -- periods A and B
# 3               categorical
# 4                      date
# 5               categorical
# 6               categorical
# 7               categorical
# 8               categorical
# 9               categorical
# 10              categorical
# 11              categorical
# 12              categorical
# 13              categorical
# 14              categorical
# 15              categorical
# 16              categorical
# 17              categorical
# 18              categorical
# 19              categorical
# 20              categorical
# 21              categorical
# 22              categorical
# 23              categorical
# 24              categorical
# 25              categorical
# 26              categorical
# 27              categorical
# 28              categorical
# 29              categorical
# ..                      ...
# 41              categorical
# 42              categorical
# 43              categorical
# 44              categorical
# 45              categorical
# 46              categorical
# 47              categorical
# 48              categorical
# 49              categorical
# 50              categorical
# 51              categorical
# 52              categorical
# 53              categorical
# 54              categorical
# 55              categorical
# 56              categorical
# 57              categorical
# 58              categorical
# 59              categorical
# 60              categorical
# 61              categorical
# 62              categorical
# 63              categorical
# 64              categorical
# 65              categorical
# 66              categorical
# 67              categorical
# 68              categorical
# 69              categorical
# 70              categorical
#
#                                                values  \
# 0   Wave 1: Age 17 Baseline Survey; Wave 2: Age 19...
# 1        Confidential (combo of state and rec number)
# 2   yyyymm [where “yyyy” and “mm” correspond to th...
# 3   Youth participated = 1; Youth declined = 2; Pa...
# 4   [mm/dd/yyyy] where: yyyy is the year; mm is th...
# 5   Yes, is in FC on Date; No, is not in FC on Dat...
# 6        Yes, employed full time; No; Declined; Blank
# 7        Yes, employed part time; No; Declined; Blank
# 8                            Yes; No; Declined; Blank
# 9                            Yes; No; Declined; Blank
# 10                           Yes; No; Declined; Blank
# 11  Yes; No; Declined; Blank; Not applicable (in F...
# 12  Yes; No; Declined; Blank; Not applicable (in F...
# 13  Yes; No; Declined; Blank; Not applicable (in F...
# 14                           Yes; No; Declined; Blank
# 15  High school diploma/GED; Vocational certificat...
# 16                           Yes; No; Declined; Blank
# 17                           Yes; No; Declined; Blank
# 18                           Yes; No; Declined; Blank
# 19                           Yes; No; Declined; Blank
# 20                           Yes; No; Declined; Blank
# 21                           Yes; No; Declined; Blank
# 22           Yes; No; Declined; Blank; Not Applicable
# 23              Yes; No; Declined; Blank; Do not know
# 24  Yes; No; Declined; Blank; Do not know; ‘Not ap...
# 25  Yes; No; Declined; Blank; Do not know; ‘Not ap...
# 26  Yes; No; Declined; Blank; Do not know; ‘Not ap...
# 27  Yes; No; Declined; Blank; Do not know; ‘Not ap...
# 28                                            Yes; No
# 29              Yes; No; Missing = Not a Sample State
# ..                                                ...
# 41  1 = Yes (which means this racial category appl...
# 42  1 = Yes (which means this racial category appl...
# 43  1 = Yes (which means this racial category appl...
# 44  1 = Yes (which means this racial category appl...
# 45  1 = Yes (which means this racial category appl...
# 46                                    1 = Yes; 0 = No
# 47                                    1 = Yes; 0 = No
# 48  “Yes” = 1 and means the youth self-identifies ...
# 49                                    Yes = 1; No = 0
# 50                        Yes = 1; No = 0; Blank = 77
# 51                        Yes = 1; No = 0; Blank = 77
# 52  0 = Less than 6th grade; 6 = 6th grade; 7 = 7t...
# 53                        Yes = 1; No = 0; Blank = 77
# 54                        Yes = 1; No = 0; Blank = 77
# 55                        Yes = 1; No = 0; Blank = 77
# 56                        Yes = 1; No = 0; Blank = 77
# 57                        Yes = 1; No = 0; Blank = 77
# 58                        Yes = 1; No = 0; Blank = 77
# 59                        Yes = 1; No = 0; Blank = 77
# 60                        Yes = 1; No = 0; Blank = 77
# 61                        Yes = 1; No = 0; Blank = 77
# 62                        Yes = 1; No = 0; Blank = 77
# 63                        Yes = 1; No = 0; Blank = 77
# 64                        Yes = 1; No = 0; Blank = 77
# 65                        Yes = 1; No = 0; Blank = 77
# 66                        Yes = 1; No = 0; Blank = 77
# 67                        Yes = 1; No = 0; Blank = 77
# 68  White = 1; Black/African American = 2; Am Id/A...
# 69  Non-Hispanic White = 1; NH Black/African Ameri...
# 70                                       Ages 14 - 20
#
#                                           description
# 0   Indicates what wave (first survey or follow-up...
# 1   Use this variable to follow records longitudin...
# 2   The report date corresponds with the end of th...
# 3   The outcomes reporting status represents the y...
# 4   The date of outcome data collection is the lat...
# 5   The youth is in foster care if the youth is un...
# 6   A youth is employed full-time if employed at l...
# 7   A youth is employed part-time if employed betw...
# 8   A youth has obtained employment-related skills...
# 9   A youth is receiving some of Social Security i...
# 10  A youth is receiving educational aid if using ...
# 11  A youth is receiving public financial assistan...
# 12  A youth is receiving public food assistance if...
# 13  A youth is receiving public housing assistance...
# 14  A youth has other financial support if receivi...
# 15  A youth has received an education certificate ...
# 16  “Yes” means the youth is enrolled in and atten...
# 17  A youth has a connection to an adult if, as  o...
# 18  A youth is considered to have experienced home...
# 19  A youth has received a substance abuse referra...
# 20  A youth is considered to have been incarcerate...
# 21  A youth is considered to have a child if the y...
# 22  A youth is married at the time of the child’s ...
# 23  A youth is receiving Medicaid if the youth is ...
# 24  A youth has other health insurance if the yout...
# 25  If the youth has indicated that he or she has ...
# 26  If the youth has indicated that he or she has ...
# 27  If the youth has indicated that he or she has ...
# 28  State opted to follow a sample of its Cohort y...
# 29  Youth is included in the follow up sample for ...
# ..                                                ...
# 41  In general, a youth’s race is determined by th...
# 42  An Asian youth has origins in any of the origi...
# 43  A Black or African American youth has origins ...
# 44  A Native Hawaiian or Other Pacific Islander yo...
# 45  A White youth has origins in any of the origin...
# 46  “Yes” means the race, or at least one race of ...
# 47  “Yes” means the youth or parent has declined t...
# 48  In general, a youth’s ethnicity is determined ...
# 49  The youth receiving services is or was in fost...
# 50  The youth is enrolled in or eligible for membe...
# 51  Adjudicated delinquent means that a State or F...
# 52  The highest educational level completed by the...
# 53  The term ‘‘special education,’’ means specific...
# 54  An independent living needs assessment is a sy...
# 55  Academic supports are services designed to hel...
# 56  Post-secondary educational support are service...
# 57  Career preparation services focus on developin...
# 58  Employment programs and vocational training ar...
# 59  Budget and financial management assistance inc...
# 60  Housing education includes assistance or train...
# 61  Health education and risk prevention includes ...
# 62  Family support and healthy marriage education....
# 63  Mentoring means that the youth has been matche...
# 64  Supervised independent living means that the y...
# 65  Room and board financial assistance is a payme...
# 66  Education financial assistance is a payment th...
# 67  Other financial assistance includes any other ...
# 68  Race re-coded to one variable. This variable i...
# 69  Race/ethnicity re-coded to one variable. This ...
# 70  Age at the mid-point of the 6-month period den...
#
# [71 rows x 6 columns]

# %% [markdown]
# ____________________________________________________________________________________________________________________
#
# ### -- Risks and Assumptions --
#
# - Risk: Data incomplete
#
#   1) Issue: Full complement of baseline data will not be complete until after May 15 of "A" pd for next FY
#
#   2) Issue: For follow-up surveys (Waves 2+): responses collected anytime in 6 mo. period
#
#   3) Issue: States are encouraged, but not required, to collect data early in period to avoid performing survey in 1
#      period and reporting results in next pd.
#
#
#   - Assumptions:
#
#       - Survey collected and reported in same fiscal year
#       - Regardless of whether data is complete for each reporting period, will be looking at data by fiscal year
#       - If date is needed for any part of the analysis, the date reported will be used
#
# ____________________________________________________________________________________________________________________
# ____________________________________________________________________________________________________________________
#
# - Risk: Sample data (n) not representative of baseline population (N)
#
#   1) Data sets exclude data from the following states:
#
#      a) Connecticutt (due to Confidentiality Restrictions; excluded from raw dataset by National Data Archive on Child Abuse and Neglect (NDACAN))
#
#      b) NY and Puerto Rico did not participate in wave 2 survey for cohort 1, so data for participants from those states are missing
#
#      c) I had to drop data from the following states: "HI", "IN", "KY", "MS", "OR", "TX", "TN" because the unique ID column--the one I need for tracking participants from baseline to surveys--for those states were corrupted. Could not use in my dataset and there is no way to impute or fix on my end.
#
#   2) Self-selection bias:
#
#      a) For baseline population demographic and services data: no sampling done; data collected for all population
#
#      b) N = population consists of ALL youth in foster care at age 17 = baseline population
#
#      c) N_no_states = baseline population excluding 7 states due to data quality issue
#
#      d) Participation in survey is completely voluntary; no incentive to participate
#
#      e) If respondents are significantly different from non-respondents (due to combination of response rate variation across states and survey design constraints), survey results are potentially biased and not representative of non respondents and overall, not adequately representative of outcomes of foster care youth population of 17 and 19 year olds for whom survey is intended to assess.
#
#      f) Cohorts population = n
#
#      - Cohort 1, Wave 1:
#          - Self-selected, non-probabilistic sample of youth in baseline
#          - Self-selection because youth are not randomly selected
#
#      - Cohort 1 and Cohort 2, Wave 2+:
#          - Optional probabilistic sampling; choice is left up to state
#          - If sampling method chosen, only done once (so wave 2 sampled pop. = wave 3 sampled pop.). Sample
#            size calculation is standard (using Finite Population Correction; plus 30% of pop. size for
#            attrition). Sample size based on Baseline population.
#
#      - In FY 2011 (cohort 1, wave 2 and 3): 12 states opted for sampling.
#          - Only these 12 states employed sampling methods that address selection bias, and only for wave 2
#            participants
#
#      - No states had more than 5,000 youth in their cohorts
#
#
#
#    - Assumptions:
#
#        - The Children’s Bureau employed a weighting methodology with the NYTD survey responses to identify and
#          correct potential non-response bias.
#        - Assuming that the weighting methodology was appropriate and effective, then assuming no selection bias and
#          that cohorts are representative.
#        - I will conduct hypothesis testing during the exploratory data analysis to determine if the sample population
#          (n) is representative of the baseline population (N_no_states)
#
# ____________________________________________________________________________________________________________________
# ____________________________________________________________________________________________________________________
#
# - Risk: Non-standardization of survey administration and data collection
#
#   1) There is only one regulation concerning survey administration: Surveys are administered to the participant
#      directly, meaning no one can answer for youth, nor can data from other sources be used to answer survey
#      questions.
#
#      - However, nothing in place to enforce or ensure proper survey administration
#
#   2) Surveys can be administered in person, via internet, via phone
#
#   3) Data collection procedures are not standardized across states or local entities
#
#
#    - Assumptions:
#
#        - Responses are from foster youth participant and no one else
#        - Response rates varied dramatically by state; this may be a reflection of variance in data collection
#          procedures
#
# ____________________________________________________________________________________________________________________
# ____________________________________________________________________________________________________________________
#
# - Risk: Raw data/Initial dataset
#
#   1) Raw data already had imputed values for data that was missing from initial reporting:
#
#      - Missing values for covariates were imputed using a recursive hot deck algorithm seeded with a sort list of
#        state by sex.
#
#   2) For services data (raw dataset A) only: County FIPS code with fewer than 1,000 records are recoded to 8
#      (LcLFIPSSv)
#
#
#    - Assumptions:
#
#        - Assuming data imputation done correctly and based on valid methodology.
#        - Excluding LcLFIPSSv from analysis because I do not have codebook for values for this feature
#            - Perhaps can use in future
