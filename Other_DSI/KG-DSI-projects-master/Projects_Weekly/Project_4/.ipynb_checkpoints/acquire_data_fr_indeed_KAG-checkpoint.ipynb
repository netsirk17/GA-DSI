# %% [markdown]
# # Web Scraping for Indeed.com

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from IPython.display import HTML
import re
import numpy as np
import pandas as pd

# %%
## YOUR CODE HERE

i = requests.get(URL)
i_soup = BeautifulSoup(i.content, "lxml")
i_soup
# Out:
# <!DOCTYPE html>\n<html lang="en">\n<head>\n<meta content="text/html;charset=unicode-escape" http-equiv="content-type"/>\n<!-- pll --><script src="/s/4a89ac5/en_US.js" type="text/javascript"></script>\n<link href="/s/a6a334e/jobsearch_all.css" rel="stylesheet" type="text/css"/>\n<link href="http://rss.indeed.com/rss?q=data+scientist+%2420%2C000&amp;l=New+York" rel="alternate" title="Data Scientist $20,000 Jobs, Employment in New York State" type="application/rss+xml"/>\n<link href="/m/jobs?q=data+scientist+%2420%2C000&amp;l=New+York" media="handheld" rel="alternate"/>\n<script type="text/javascript">\n    \n    window['closureReadyCallbacks'] = [];\n\n    function call_when_jsall_loaded(cb) {\n        if (window['closureReady']) {\n            cb();\n        } else {\n            window['closureReadyCallbacks'].push(cb);\n        }\n    }\n</script>\n<script src="/s/0579f05/jobsearch-all-compiled.js" type="text/javascript"></script>\n<script type="text/javascript">\nvar pingUrlsForGA = [];\n\nvar searchUID = '1an4l861qa3dgflm';\nvar tk = '1an4l861qa3dgflm';\n\nvar loggedIn = false;\nvar myindeed = true;\nvar userEmail = '';\nvar tellFriendEmail = '';\nvar globalLoginURL = 'http:\\/\\/www.indeed.com\\/account\\/login?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%2B%2420%2C000%26l%3DNew%2BYork%26start%3D10';\nvar globalRegisterURL = 'http:\\/\\/www.indeed.com\\/account\\/register?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%2B%2420%2C000%26l%3DNew%2BYork%26start%3D10';\nvar searchKey = '60e10e972da47133';\nvar searchState = 'q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=10';\nvar searchQS = 'q=data+scientist+$20,000&l=New+York&start=10';\nvar eventType = 'jobsearch';\nvar locale = 'en_US';\nfunction clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1an4l861qa3dgflm&jsa=9578'; a.href = jsh; }\nfunction sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }\nfunction sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }\nfunction ptk(st,p) {document.cookie = 'PTK="tk=1an4l861qa3dgflm&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}\nfunction rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}\n</script>\n<script type="text/javascript">\nfunction loadJSAsync( ) {\nfor ( var i = 0; i < arguments.length; i++ ) {\nvar url = arguments[i];\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\ns.async = true;\ns.src = url;\nel.parentNode.insertBefore(s, el);\n})();\n}\n}\n</script>\n<meta content="2,252  Data Scientist $20,000 Jobs available in New York State on Indeed.com.  one search.  all jobs." name="description"/>\n<meta content="Data Scientist $20,000 Jobs, Employment in New York State, New York State careers, New York State employment, New York State job listings, New York State job search, New York State search engine, work in New York State" name="keywords"/>\n<link href="/jobs?q=Data+Scientist+$20,000&amp;l=New+York+State&amp;start=10" rel="canonical"/><link href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York" rel="prev"/>\n<link href="/jobs?q=data+scientist+%2420%2C000&amp;l=New+York&amp;start=20" rel="next"/><style type="text/css">\n#recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }\n#recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }\n</style>\n<script type="text/javascript">\nvar indeedCsrfToken = 'nwroAIPdzz7bNVKlCkbpy0yGuqkxi5go';\nvar hashedCsrfToken = '45465af53c20083a6d0c49b89aedb325';\n</script>\n<style type="text/css">\n.jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{font-family:"Fira Sans", sans-serif !important}\n</style>\n<style type="text/cs ...

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %%
## YOUR CODE HERE

def mark_sponsored(soup_file):
    sponsored_col = []
    for result in soup_file.findAll('div', {'class' : re.compile('row.*')}):
        if len(result.findAll('span', class_='sdn')) > 0 :
            entry = 'True'
            sponsored_col.append(entry)
        else:
            entry = 'False'
            sponsored_col.append(entry)
    return sponsored_col

def extract_location_from_result(soup_file):
    location_col = []
    for d in soup_file.findAll('span', class_='location'):
        entry = d.text
        location_col.append(entry)
    return location_col

def extract_company_from_result(soup_file):
    company_col = []
    for d in soup_file.findAll('span', class_='company'):
        entry = d.text
        company_col.append(entry)
    return company_col

def extract_job_from_result(soup_file):
    job_col = []
    for result in soup_file.findAll('a', {'data-tn-element' : re.compile('job.*')}):
        entry = result.text
        job_col.append(entry)
    return job_col

def extract_salary_from_result(soup_file):
    salary_col = []
    for result in soup_file.findAll('div', {'class' : re.compile('row.*')}):
        sal = result.findAll('nobr')
        if len(sal) > 0 :
            rstring = str(sal)
            salary_col.append(rstring)
        else:
            salary_col.append(np.nan)
    return salary_col

# %%
print mark_sponsored(i_soup)
print
print extract_job_from_result(i_soup)
print
print extract_company_from_result(i_soup)
print
print extract_location_from_result(i_soup)
print 
print extract_salary_from_result(i_soup)
# Out:
# ['True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True']
#
# [u'Junior Data Scientist', u'Sr. Data Scientist, Learning Services', u'Data Scientist \u2013 Predictive Analytics', u'Team Lead, Data Analysis', u'Postdoctoral Research Scientist', u'Senior Data Scientist', u'Data Engineer, Analytics Technology', u'Data Analyst', u'Quantitative Researcher in Machine Learning', u'Research Associate, R&D', u'Senior Data Scientist', u'Research Data Associate', u'Lead Data Scientist, US RMBS', u'Machine Learning Expert Job', u'Data Scientist']
#
# [u'\n\n    UncommonGoods', u'\n\n    Chegg', u'\n\n    Gallup', u'\n\n\n    WebMD\n', u'\n\n\n    Columbia University\n', u'\n\n    Celmatix\n', u'\n\n\n    NBCUniversal\n', u'\n\n\n    NYU Langone Medical Center\n', u'\n\n    Two Sigma Investments, LLC.\n', u'\n\n    Stemline Therapeutics, Inc.\n', u'\n\n\n    About.com\n', u'\n\n\n    NYU Langone Medical Center\n', u'\n\n\n    DBRS\n', u'\n    SRC and SRCTec', u'\n    AbilTo, Inc']
#
# [u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY', u'Palisades, NY', u'New York, NY 10005 (Financial District area)', u'New York, NY', u'New York, NY 10016 (Gramercy area)', u'New York, NY', u'New York, NY 10022 (Midtown area)', u'New York, NY 10018 (Clinton area)', u'New York, NY 10016 (Gramercy area)', u'New York, NY 10005 (Financial District area)', u'Syracuse, NY', u'New York, NY']
#
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
def build_jobpost_db(soup_file):

    company = extract_company_from_result(soup_file) 
    job = extract_job_from_result(soup_file)
    location = extract_location_from_result(soup_file)
    salary = extract_salary_from_result(soup_file)
    sponsored = mark_sponsored(soup_file)
    
    jobdf = pd.DataFrame({'Job' : job, 'Company' : company, 'Location' : location, 'Salary' : salary, 'Sponsored' : \
                                                                                          sponsored})
    
    return jobdf

# %%
build_jobpost_db(i_soup)
# Out:
#                                    Company  \
# 0                    \n\n    UncommonGoods
# 1                            \n\n    Chegg
# 2                           \n\n    Gallup
# 3                        \n\n\n    WebMD\n
# 4          \n\n\n    Columbia University\n
# 5                       \n\n    Celmatix\n
# 6                 \n\n\n    NBCUniversal\n
# 7   \n\n\n    NYU Langone Medical Center\n
# 8    \n\n    Two Sigma Investments, LLC.\n
# 9    \n\n    Stemline Therapeutics, Inc.\n
# 10                   \n\n\n    About.com\n
# 11  \n\n\n    NYU Langone Medical Center\n
# 12                        \n\n\n    DBRS\n
# 13                    \n    SRC and SRCTec
# 14                       \n    AbilTo, Inc
#
#                                             Job  \
# 0                         Junior Data Scientist
# 1         Sr. Data Scientist, Learning Services
# 2         Data Scientist – Predictive Analytics
# 3                      Team Lead, Data Analysis
# 4               Postdoctoral Research Scientist
# 5                         Senior Data Scientist
# 6           Data Engineer, Analytics Technology
# 7                                  Data Analyst
# 8   Quantitative Researcher in Machine Learning
# 9                       Research Associate, R&D
# 10                        Senior Data Scientist
# 11                      Research Data Associate
# 12                 Lead Data Scientist, US RMBS
# 13                  Machine Learning Expert Job
# 14                               Data Scientist
#
#                                         Location  Salary Sponsored
# 0                                   New York, NY     NaN      True
# 1                                   New York, NY     NaN      True
# 2                                   New York, NY     NaN      True
# 3                                   New York, NY     NaN     False
# 4                                  Palisades, NY     NaN     False
# 5   New York, NY 10005 (Financial District area)     NaN     False
# 6                                   New York, NY     NaN     False
# 7             New York, NY 10016 (Gramercy area)     NaN     False
# 8                                   New York, NY     NaN     False
# 9              New York, NY 10022 (Midtown area)     NaN     False
# 10             New York, NY 10018 (Clinton area)     NaN     False
# 11            New York, NY 10016 (Gramercy area)     NaN     False
# 12  New York, NY 10005 (Financial District area)     NaN     False
# 13                                  Syracuse, NY     NaN      True
# 14                                  New York, NY     NaN      True

# %% [markdown]
# #### Scaling code to collect results from multiple cities and starting points.

# %%
max_results_per_city = 100

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Denver', 'Las+Vegas', 'San+Jose', 'Boulder', 'Covallis','Seattle', 'Fort+Collins', 'Provo', 'Burlington', 'Boston']):
    for start in range(0, max_results_per_city, 10):
        URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={city}&start={start}".format(**locals())
        # Grab the results from the request (as above)
        i = requests.get(URL)
        i_soup = BeautifulSoup(i.content, "lxml")
        # Append to the full set of results
        results.append(i_soup)

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE
list_of_dfs = []

for soup_file in results:
    list_of_dfs.append(build_jobpost_db(soup_file))

jobsdf = pd.concat(list_of_dfs)
jobsdf = jobsdf.reset_index()
    
jobsdf
# Out:
#       index                                         Company  \
# 0         0                  \n    LENA Research Foundation
# 1         1                           \n\n    Alteryx, Inc.
# 2         2                             \n\n    CyberCoders
# 3         3                 \n\n\n    Navigant Consulting\n
# 4         4                                \n\n    cliexa\n
# 5         5              \n\n\n    University of Colorado\n
# 6         6                       \n\n    Somalogic, Inc.\n
# 7         7                              \n\n\n    Oracle\n
# 8         8                              \n\n\n    Ibotta\n
# 9         9              \n\n\n    University of Colorado\n
# 10       10                            \n\n\n    Deloitte\n
# 11       11                            \n\n\n    Deloitte\n
# 12       12                       \n\n\n    Planet Pharma\n
# 13       13                       \n    Specialty Chemicals
# 14       14                   \n    Eventus Solutions Group
# 15        0                   \n    Eventus Solutions Group
# 16        1                           \n\n    Alteryx, Inc.
# 17        2                       \n    Specialty Chemicals
# 18        3                      \n\n\n    Ball Aerospace\n
# 19        4                         \n\n    Corgenix, Inc\n
# 20        5                                \n\n\n    UCAR\n
# 21        6                   \n\n    Specialty Chemicals\n
# 22        7                                 \n\n\n    IMM\n
# 23        8                              \n\n\n    Archer\n
# 24        9        \n\n\n    Southwest Research Institute\n
# 25       10                              \n\n\n    OnDeck\n
# 26       11   \n\n    Stanley Brothers Social Enterprises\n
# 27       12          \n\n\n    Department Of The Interior\n
# 28       13                             \n\n    CyberCoders
# 29       14                  \n    LENA Research Foundation
# ...     ...                                             ...
# 1899      0                       \n\n    RetailMeNot, Inc.
# 1900      1                                \n    Sense Corp
# 1901      2                              \n\n    MaxPoint\n
# 1902      3                              \n\n\n    NVIDIA\n
# 1903      4                      \n\n\n    Alcatel-Lucent\n
# 1904      5                     \n\n    Ocean Conservancy\n
# 1905      6                          \n\n\n    CDK Global\n
# 1906      7                     \n\n\n    Express Scripts\n
# 1907      8                     \n\n    Signature Science\n
# 1908      9        \n\n    The University of Texas System\n
# 1909     10            \n\n\n    Thermo Fisher Scientific\n
# 1910     11                      \n\n    Emoters Robotics\n
# 1911     12                                  \n\n    Indeed
# 1912     13                         \n\n    Main Street Hub
# 1913     14                                  \n\n    Indeed
# 1914      0                       \n\n    RetailMeNot, Inc.
# 1915      1                                \n    Sense Corp
# 1916      2                       \n\n\n    Gartner, Inc.\n
# 1917      3                              \n\n    MaxPoint\n
# 1918      4                       \n\n\n    The Jag Group\n
# 1919      5                              \n\n\n    Natera\n
# 1920      6  \n\n    TEL Technology Center, America, Inc.\n
# 1921      7                              \n\n    Zilliant\n
# 1922      8                             \n\n    Galvanize\n
# 1923      9                              \n\n\n    Indeed\n
# 1924     10       \n\n\n    University of Texas at Austin\n
# 1925     11                            \n\n\n    HomeAway\n
# 1926     12                                  \n\n    Indeed
# 1927     13                         \n\n    Main Street Hub
# 1928     14                                  \n\n    Indeed
#
#                                                     Job  \
# 0     Sr. Research Engineer: Machine Learning and Co...
# 1                   Product Manager, Advanced Analytics
# 2                                        Data Scientist
# 3                                      Research Analyst
# 4                                 Data Scientist Intern
# 5                            Professional Research Asst
# 6     Bioinformatics Assoc. II/Sr. Assoc./Analyst/Sc...
# 7     Senior Product Manager - Measurement, Oracle D...
# 8                                 Senior Data Scientist
# 9                                    Research Associate
# 10                           Big Data Senior Consultant
# 11                                     Big Data Manager
# 12                               Statistical Programmer
# 13                                   Research Scientist
# 14                                Junior Data Scientist
# 15                                Junior Data Scientist
# 16                  Product Manager, Advanced Analytics
# 17                                   Research Scientist
# 18    Administrative Associate II - National Defense...
# 19              Postdoctoral Fellow - Assay Development
# 20                                          Engineer II
# 21                                   Research Scientist
# 22                         Software Engineer ? Big Data
# 23                                    Software Engineer
# 24                SR. RESEARCH SCIENTIST - HELIOPHYSICS
# 25                        Business Intelligence Analyst
# 26                   Research and Development Scientist
# 27               Statistician, GS-1530-12 (DEU-PERM-DS)
# 28                                       Data Scientist
# 29    Sr. Research Engineer: Machine Learning and Co...
# ...                                                 ...
# 1899                                 Sr. Data Scientist
# 1900                                     Data Scientist
# 1901               Senior Data Scientist - Econometrics
# 1902  Research Scientist for Computer Vision / Machi...
# 1903                           Software Developer Co-op
# 1904   Conservation Biologist, Gulf Restoration Program
# 1905                          Business Security Officer
# 1906                  Senior Quantitative UX Researcher
# 1907                          Bioinformatics Specialist
# 1908                     Institutional Research Analyst
# 1909                              Application Scientist
# 1910  Robotics software engineer (involves machine l...
# 1911                                      Data Engineer
# 1912                                     Data Scientist
# 1913                                     Data Scientist
# 1914                                 Sr. Data Scientist
# 1915                                     Data Scientist
# 1916        Content Marketing Analyst, Gartner Research
# 1917           Senior Data Scientist - Machine Learning
# 1918           Senior Data Scientist - Machine Learning
# 1919                             Clinical Data Reporter
# 1920                                          Scientist
# 1921            Senior Software Engineer – Science Team
# 1922               Associate Instructor, Data Scientist
# 1923                                     Data Scientist
# 1924  Engineering Scientist Associate - GNSS Analyst...
# 1925                            Research Data Scientist
# 1926                                      Data Engineer
# 1927                                     Data Scientist
# 1928                                     Data Scientist
#
#                                                Location  \
# 0                                           Boulder, CO
# 1                                        Broomfield, CO
# 2                                           Boulder, CO
# 3                                           Boulder, CO
# 4                                           Boulder, CO
# 5                                           Boulder, CO
# 6                                     Boulder, CO 80301
# 7                                        Broomfield, CO
# 8                          Denver, CO 80202 (Lodo area)
# 9                                           Boulder, CO
# 10                 Denver, CO 80203 (Capitol Hill area)
# 11                 Denver, CO 80203 (Capitol Hill area)
# 12                                           Denver, CO
# 13                                           Denver, CO
# 14                                        Englewood, CO
# 15                                        Englewood, CO
# 16                                       Broomfield, CO
# 17                                           Denver, CO
# 18                                       Broomfield, CO
# 19                                 Broomfield, CO 80020
# 20                                       Broomfield, CO
# 21                                           Denver, CO
# 22                                    Boulder, CO 80302
# 23                                          Boulder, CO
# 24                                          Boulder, CO
# 25                                           Denver, CO
# 26                                    Boulder, CO 80301
# 27                                         Lakewood, CO
# 28                                          Boulder, CO
# 29                                          Boulder, CO
# ...                                                 ...
# 1899                                         Austin, TX
# 1900                                         Austin, TX
# 1901                  Austin, TX 78759 (Arboretum area)
# 1902                                         Austin, TX
# 1903                                         Austin, TX
# 1904                   Austin, TX 78701 (Downtown area)
# 1905                                         Austin, TX
# 1906                                         Austin, TX
# 1907                                         Austin, TX
# 1908                                         Austin, TX
# 1909                                         Austin, TX
# 1910                                         Austin, TX
# 1911                                         Austin, TX
# 1912                                         Austin, TX
# 1913                                         Austin, TX
# 1914                                         Austin, TX
# 1915                                         Austin, TX
# 1916                                         Austin, TX
# 1917                  Austin, TX 78759 (Arboretum area)
# 1918                 Austin, TX 73301 (St Edwards area)
# 1919                                   Austin, TX 78731
# 1920                                         Austin, TX
# 1921  Austin, TX 78704 (South Lamar-South Congress a...
# 1922                                         Austin, TX
# 1923                  Austin, TX 78759 (Arboretum area)
# 1924                                         Austin, TX
# 1925  Austin, TX 78704 (South Lamar-South Congress a...
# 1926                                         Austin, TX
# 1927                                         Austin, TX
# 1928                                         Austin, TX
#
#                                         Salary Sponsored
# 0                                          NaN      True
# 1                                          NaN      True
# 2                                          NaN      True
# 3                                          NaN     False
# 4                                          NaN     False
# 5                                          NaN     False
# 6                                          NaN     False
# 7                                          NaN     False
# 8                                          NaN     False
# 9                                          NaN     False
# 10                                         NaN     False
# 11                                         NaN     False
# 12                                         NaN     False
# 13                                         NaN      True
# 14                                         NaN      True
# 15                                         NaN      True
# 16                                         NaN      True
# 17                                         NaN      True
# 18                                         NaN     False
# 19                                         NaN     False
# 20                                         NaN     False
# 21                                         NaN     False
# 22                                         NaN     False
# 23                                         NaN     False
# 24                                         NaN     False
# 25                                         NaN     False
# 26                                         NaN     False
# 27     [<nobr>$76,341 - $99,243 a year</nobr>]     False
# 28                                         NaN      True
# 29                                         NaN      True
# ...                                        ...       ...
# 1899                                       NaN      True
# 1900                                       NaN      True
# 1901                                       NaN     False
# 1902                                       NaN     False
# 1903                                       NaN     False
# 1904                                       NaN     False
# 1905                                       NaN     False
# 1906                                       NaN     False
# 1907                                       NaN     False
# 1908             [<nobr>$4,459 a month</nobr>]     False
# 1909                                       NaN     False
# 1910  [<nobr>$70,000 - $100,000 a year</nobr>]     False
# 1911                                       NaN      True
# 1912                                       NaN      True
# 1913                                       NaN      True
# 1914                                       NaN      True
# 1915                                       NaN      True
# 1916                                       NaN     False
# 1917                                       NaN     False
# 1918                                       NaN     False
# 1919                                       NaN     False
# 1920                                       NaN     False
# 1921                                       NaN     False
# 1922                                       NaN     False
# 1923                                       NaN     False
# 1924    [<nobr>$5,400 - $6,500 a month</nobr>]     False
# 1925                                       NaN     False
# 1926                                       NaN      True
# 1927                                       NaN      True
# 1928                                       NaN      True
#
# [1929 rows x 6 columns]

# %%
## Save as csv
jobsdf.to_csv('jobScrape.csv', encoding='utf-8')

# %%
jobsdf
# Out:
#                                              Company  \
# 0                     \n    LENA Research Foundation
# 1                              \n\n    Alteryx, Inc.
# 2                                \n\n    CyberCoders
# 3                    \n\n\n    Navigant Consulting\n
# 4                                   \n\n    cliexa\n
# 5                 \n\n\n    University of Colorado\n
# 6                          \n\n    Somalogic, Inc.\n
# 7                                 \n\n\n    Oracle\n
# 8                                 \n\n\n    Ibotta\n
# 9                 \n\n\n    University of Colorado\n
# 10                              \n\n\n    Deloitte\n
# 11                              \n\n\n    Deloitte\n
# 12                         \n\n\n    Planet Pharma\n
# 13                         \n    Specialty Chemicals
# 14                     \n    Eventus Solutions Group
# 15                     \n    Eventus Solutions Group
# 16                             \n\n    Alteryx, Inc.
# 17                         \n    Specialty Chemicals
# 18                        \n\n\n    Ball Aerospace\n
# 19                           \n\n    Corgenix, Inc\n
# 20                                  \n\n\n    UCAR\n
# 21                     \n\n    Specialty Chemicals\n
# 22                                   \n\n\n    IMM\n
# 23                                \n\n\n    Archer\n
# 24          \n\n\n    Southwest Research Institute\n
# 25                                \n\n\n    OnDeck\n
# 26     \n\n    Stanley Brothers Social Enterprises\n
# 27            \n\n\n    Department Of The Interior\n
# 28                               \n\n    CyberCoders
# 29                    \n    LENA Research Foundation
# ...                                              ...
# 1899                       \n\n    RetailMeNot, Inc.
# 1900                                \n    Sense Corp
# 1901                              \n\n    MaxPoint\n
# 1902                              \n\n\n    NVIDIA\n
# 1903                      \n\n\n    Alcatel-Lucent\n
# 1904                     \n\n    Ocean Conservancy\n
# 1905                          \n\n\n    CDK Global\n
# 1906                     \n\n\n    Express Scripts\n
# 1907                     \n\n    Signature Science\n
# 1908        \n\n    The University of Texas System\n
# 1909            \n\n\n    Thermo Fisher Scientific\n
# 1910                      \n\n    Emoters Robotics\n
# 1911                                  \n\n    Indeed
# 1912                         \n\n    Main Street Hub
# 1913                                  \n\n    Indeed
# 1914                       \n\n    RetailMeNot, Inc.
# 1915                                \n    Sense Corp
# 1916                       \n\n\n    Gartner, Inc.\n
# 1917                              \n\n    MaxPoint\n
# 1918                       \n\n\n    The Jag Group\n
# 1919                              \n\n\n    Natera\n
# 1920  \n\n    TEL Technology Center, America, Inc.\n
# 1921                              \n\n    Zilliant\n
# 1922                             \n\n    Galvanize\n
# 1923                              \n\n\n    Indeed\n
# 1924       \n\n\n    University of Texas at Austin\n
# 1925                            \n\n\n    HomeAway\n
# 1926                                  \n\n    Indeed
# 1927                         \n\n    Main Street Hub
# 1928                                  \n\n    Indeed
#
#                                                     Job  \
# 0     Sr. Research Engineer: Machine Learning and Co...
# 1                   Product Manager, Advanced Analytics
# 2                                        Data Scientist
# 3                                      Research Analyst
# 4                                 Data Scientist Intern
# 5                            Professional Research Asst
# 6     Bioinformatics Assoc. II/Sr. Assoc./Analyst/Sc...
# 7     Senior Product Manager - Measurement, Oracle D...
# 8                                 Senior Data Scientist
# 9                                    Research Associate
# 10                           Big Data Senior Consultant
# 11                                     Big Data Manager
# 12                               Statistical Programmer
# 13                                   Research Scientist
# 14                                Junior Data Scientist
# 15                                Junior Data Scientist
# 16                  Product Manager, Advanced Analytics
# 17                                   Research Scientist
# 18    Administrative Associate II - National Defense...
# 19              Postdoctoral Fellow - Assay Development
# 20                                          Engineer II
# 21                                   Research Scientist
# 22                         Software Engineer ? Big Data
# 23                                    Software Engineer
# 24                SR. RESEARCH SCIENTIST - HELIOPHYSICS
# 25                        Business Intelligence Analyst
# 26                   Research and Development Scientist
# 27               Statistician, GS-1530-12 (DEU-PERM-DS)
# 28                                       Data Scientist
# 29    Sr. Research Engineer: Machine Learning and Co...
# ...                                                 ...
# 1899                                 Sr. Data Scientist
# 1900                                     Data Scientist
# 1901               Senior Data Scientist - Econometrics
# 1902  Research Scientist for Computer Vision / Machi...
# 1903                           Software Developer Co-op
# 1904   Conservation Biologist, Gulf Restoration Program
# 1905                          Business Security Officer
# 1906                  Senior Quantitative UX Researcher
# 1907                          Bioinformatics Specialist
# 1908                     Institutional Research Analyst
# 1909                              Application Scientist
# 1910  Robotics software engineer (involves machine l...
# 1911                                      Data Engineer
# 1912                                     Data Scientist
# 1913                                     Data Scientist
# 1914                                 Sr. Data Scientist
# 1915                                     Data Scientist
# 1916        Content Marketing Analyst, Gartner Research
# 1917           Senior Data Scientist - Machine Learning
# 1918           Senior Data Scientist - Machine Learning
# 1919                             Clinical Data Reporter
# 1920                                          Scientist
# 1921            Senior Software Engineer – Science Team
# 1922               Associate Instructor, Data Scientist
# 1923                                     Data Scientist
# 1924  Engineering Scientist Associate - GNSS Analyst...
# 1925                            Research Data Scientist
# 1926                                      Data Engineer
# 1927                                     Data Scientist
# 1928                                     Data Scientist
#
#                                                Location  \
# 0                                           Boulder, CO
# 1                                        Broomfield, CO
# 2                                           Boulder, CO
# 3                                           Boulder, CO
# 4                                           Boulder, CO
# 5                                           Boulder, CO
# 6                                     Boulder, CO 80301
# 7                                        Broomfield, CO
# 8                          Denver, CO 80202 (Lodo area)
# 9                                           Boulder, CO
# 10                 Denver, CO 80203 (Capitol Hill area)
# 11                 Denver, CO 80203 (Capitol Hill area)
# 12                                           Denver, CO
# 13                                           Denver, CO
# 14                                        Englewood, CO
# 15                                        Englewood, CO
# 16                                       Broomfield, CO
# 17                                           Denver, CO
# 18                                       Broomfield, CO
# 19                                 Broomfield, CO 80020
# 20                                       Broomfield, CO
# 21                                           Denver, CO
# 22                                    Boulder, CO 80302
# 23                                          Boulder, CO
# 24                                          Boulder, CO
# 25                                           Denver, CO
# 26                                    Boulder, CO 80301
# 27                                         Lakewood, CO
# 28                                          Boulder, CO
# 29                                          Boulder, CO
# ...                                                 ...
# 1899                                         Austin, TX
# 1900                                         Austin, TX
# 1901                  Austin, TX 78759 (Arboretum area)
# 1902                                         Austin, TX
# 1903                                         Austin, TX
# 1904                   Austin, TX 78701 (Downtown area)
# 1905                                         Austin, TX
# 1906                                         Austin, TX
# 1907                                         Austin, TX
# 1908                                         Austin, TX
# 1909                                         Austin, TX
# 1910                                         Austin, TX
# 1911                                         Austin, TX
# 1912                                         Austin, TX
# 1913                                         Austin, TX
# 1914                                         Austin, TX
# 1915                                         Austin, TX
# 1916                                         Austin, TX
# 1917                  Austin, TX 78759 (Arboretum area)
# 1918                 Austin, TX 73301 (St Edwards area)
# 1919                                   Austin, TX 78731
# 1920                                         Austin, TX
# 1921  Austin, TX 78704 (South Lamar-South Congress a...
# 1922                                         Austin, TX
# 1923                  Austin, TX 78759 (Arboretum area)
# 1924                                         Austin, TX
# 1925  Austin, TX 78704 (South Lamar-South Congress a...
# 1926                                         Austin, TX
# 1927                                         Austin, TX
# 1928                                         Austin, TX
#
#                                         Salary Sponsored
# 0                                          NaN      True
# 1                                          NaN      True
# 2                                          NaN      True
# 3                                          NaN     False
# 4                                          NaN     False
# 5                                          NaN     False
# 6                                          NaN     False
# 7                                          NaN     False
# 8                                          NaN     False
# 9                                          NaN     False
# 10                                         NaN     False
# 11                                         NaN     False
# 12                                         NaN     False
# 13                                         NaN      True
# 14                                         NaN      True
# 15                                         NaN      True
# 16                                         NaN      True
# 17                                         NaN      True
# 18                                         NaN     False
# 19                                         NaN     False
# 20                                         NaN     False
# 21                                         NaN     False
# 22                                         NaN     False
# 23                                         NaN     False
# 24                                         NaN     False
# 25                                         NaN     False
# 26                                         NaN     False
# 27     [<nobr>$76,341 - $99,243 a year</nobr>]     False
# 28                                         NaN      True
# 29                                         NaN      True
# ...                                        ...       ...
# 1899                                       NaN      True
# 1900                                       NaN      True
# 1901                                       NaN     False
# 1902                                       NaN     False
# 1903                                       NaN     False
# 1904                                       NaN     False
# 1905                                       NaN     False
# 1906                                       NaN     False
# 1907                                       NaN     False
# 1908             [<nobr>$4,459 a month</nobr>]     False
# 1909                                       NaN     False
# 1910  [<nobr>$70,000 - $100,000 a year</nobr>]     False
# 1911                                       NaN      True
# 1912                                       NaN      True
# 1913                                       NaN      True
# 1914                                       NaN      True
# 1915                                       NaN      True
# 1916                                       NaN     False
# 1917                                       NaN     False
# 1918                                       NaN     False
# 1919                                       NaN     False
# 1920                                       NaN     False
# 1921                                       NaN     False
# 1922                                       NaN     False
# 1923                                       NaN     False
# 1924    [<nobr>$5,400 - $6,500 a month</nobr>]     False
# 1925                                       NaN     False
# 1926                                       NaN      True
# 1927                                       NaN      True
# 1928                                       NaN      True
#
# [1929 rows x 5 columns]
