# %% [markdown]
# # Web Scraping for Indeed.com

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
from IPython.display import HTML
import re
import numpy as np
import pandas as pd

# %%
## YOUR CODE HERE

i = requests.get(URL)
i_soup = BeautifulSoup(i.content, "lxml")
i_soup

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %%
## YOUR CODE HERE

def mark_sponsored(soup_file):
    sponsored_col = []
    for result in soup_file.findAll('div', {'class' : re.compile('row.*')}):
        if len(result.findAll('span', class_='sdn')) > 0 :
            entry = 'True'
            sponsored_col.append(entry)
        else:
            entry = 'False'
            sponsored_col.append(entry)
    return sponsored_col

def extract_location_from_result(soup_file):
    location_col = []
    for d in soup_file.findAll('span', class_='location'):
        entry = d.text
        location_col.append(entry)
    return location_col

def extract_company_from_result(soup_file):
    company_col = []
    for d in soup_file.findAll('span', class_='company'):
        entry = d.text
        company_col.append(entry)
    return company_col

def extract_job_from_result(soup_file):
    job_col = []
    for result in soup_file.findAll('a', {'data-tn-element' : re.compile('job.*')}):
        entry = result.text
        job_col.append(entry)
    return job_col

def extract_salary_from_result(soup_file):
    salary_col = []
    for result in soup_file.findAll('div', {'class' : re.compile('row.*')}):
        sal = result.findAll('nobr')
        if len(sal) > 0 :
            rstring = str(sal)
            salary_col.append(rstring)
        else:
            salary_col.append(np.nan)
    return salary_col

# %%
type(i_soup)
# Out:
# bs4.BeautifulSoup

# %%
print mark_sponsored(i_soup)
print
print extract_job_from_result(i_soup)
print
print extract_company_from_result(i_soup)
print
print extract_location_from_result(i_soup)
print 
print extract_salary_from_result(i_soup)
# Out:
# ['True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True']
#
# [u'Machine Learning Quantitative Analyst', u'Data Engineer', u'Deep Learning Data Scientist', u'AVP Quantitative Analyst', u'Senior Data Scientist', u'Reporting Analyst', u'Experiment Data Analyst / Statistician', u'Senior Data Scientist', u'Senior Data Scientist', u'Senior Data Scientist - Verticals', u'Research Scientist', u'Quantitative Analyst', u'Data Scientist / Lead Quantitative Analyst', u'Data Scientist, Imaging Informatics', u'Data Scientist - Relocation to China (Chinese Visa required)']
#
# [u'\n\n        Bloomberg', u'\n\n        Indeed', u'\n    WorkFusion', u'\n\n\n        Barclays\n', u'\n\n    7Park Data\n', u'\n\n\n        PlaceIQ\n', u'\n\n\n        Dow Jones\n', u'\n\n\n        Capital Group\n', u'\n\n\n        CAPCO\n', u'\n\n\n        Bloomberg\n', u'\n\n\n        Yahoo! Inc.\n', u'\n\n    StreetID\n', u'\n\n\n        Guidepoint Global\n', u'\n\n        Memorial Sloan Kettering', u'\n\n        Booking.com']
#
# [u'New York, NY', u'New York, NY 10036', u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY 10001 (Chelsea area)', u'New York, NY 10111 (Midtown area)', u'New York, NY 10271 (Financial District area)', u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY']
#
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '[<nobr>$120,000 a year</nobr>]', nan, nan, nan]

# %%
def build_jobpost_db(soup_file):

    company = extract_company_from_result(soup_file) 
    job = extract_job_from_result(soup_file)
    location = extract_location_from_result(soup_file)
    salary = extract_salary_from_result(soup_file)
    sponsored = mark_sponsored(soup_file)
    
    jobdf = pd.DataFrame({'Job' : job, 'Company' : company, 'Location' : location, 'Salary' : salary, 'Sponsored' : \
                                                                                          sponsored})
    
    return jobdf

# %%
build_jobpost_db(i_soup)
# Out:
#                                  Company  \
# 0                  \n\n        Bloomberg
# 1                     \n\n        Indeed
# 2                       \n    WorkFusion
# 3               \n\n\n        Barclays\n
# 4                   \n\n    7Park Data\n
# 5                \n\n\n        PlaceIQ\n
# 6              \n\n\n        Dow Jones\n
# 7          \n\n\n        Capital Group\n
# 8                  \n\n\n        CAPCO\n
# 9              \n\n\n        Bloomberg\n
# 10           \n\n\n        Yahoo! Inc.\n
# 11                    \n\n    StreetID\n
# 12     \n\n\n        Guidepoint Global\n
# 13  \n\n        Memorial Sloan Kettering
# 14               \n\n        Booking.com
#
#                                                   Job  \
# 0               Machine Learning Quantitative Analyst
# 1                                       Data Engineer
# 2                        Deep Learning Data Scientist
# 3                            AVP Quantitative Analyst
# 4                               Senior Data Scientist
# 5                                   Reporting Analyst
# 6              Experiment Data Analyst / Statistician
# 7                               Senior Data Scientist
# 8                               Senior Data Scientist
# 9                   Senior Data Scientist - Verticals
# 10                                 Research Scientist
# 11                               Quantitative Analyst
# 12         Data Scientist / Lead Quantitative Analyst
# 13                Data Scientist, Imaging Informatics
# 14  Data Scientist - Relocation to China (Chinese ...
#
#                                         Location  \
# 0                                   New York, NY
# 1                             New York, NY 10036
# 2                                   New York, NY
# 3                                   New York, NY
# 4                                   New York, NY
# 5                                   New York, NY
# 6              New York, NY 10001 (Chelsea area)
# 7              New York, NY 10111 (Midtown area)
# 8   New York, NY 10271 (Financial District area)
# 9                                   New York, NY
# 10                                  New York, NY
# 11                                  New York, NY
# 12                                  New York, NY
# 13                                  New York, NY
# 14                                  New York, NY
#
#                             Salary Sponsored
# 0                              NaN      True
# 1                              NaN      True
# 2                              NaN      True
# 3                              NaN     False
# 4                              NaN     False
# 5                              NaN     False
# 6                              NaN     False
# 7                              NaN     False
# 8                              NaN     False
# 9                              NaN     False
# 10                             NaN     False
# 11  [<nobr>$120,000 a year</nobr>]     False
# 12                             NaN     False
# 13                             NaN      True
# 14                             NaN      True

# %% [markdown]
# #### Scaling code to collect results from multiple cities and starting points.

# %%
max_results_per_city = 10

results = []

for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Denver', 'Las+Vegas', 'San+Jose', 'Boulder', 'Covallis','Seattle', 'Fort+Collins', 'Provo', 'Burlington', 'Boston']):
    for start in range(0, max_results_per_city, 10):
        URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={city}&start={start}".format(**locals())
        # Grab the results from the request (as above)
        i = requests.get(URL)
        i_soup = BeautifulSoup(i.content, "lxml")
        # Append to the full set of results
        results.append(i_soup)

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE
list_of_dfs = []

for soup_file in results:
    list_of_dfs.append(build_jobpost_db(soup_file))

jobsdf = pd.concat(list_of_dfs)
jobsdf = jobsdf.reset_index()
    
jobsdf
# Out:
#      index                                            Company  \
# 0        0                            \n\n        Return Path
# 1        1                                    \n    RefactorU
# 2        2                                \n\n        Pearson
# 3        3                              \n\n    CaliberMind\n
# 4        4                                \n\n    RefactorU\n
# 5        5                             \n\n\n        Oracle\n
# 6        6                             \n\n\n        Google\n
# 7        7             \n\n\n        University of Colorado\n
# 8        8                             \n\n    Wiland, Inc.\n
# 9        9                            \n\n\n        Agilent\n
# 10      10                            \n\n\n        Labcorp\n
# 11      11              \n\n\n        Denver Public Schools\n
# 12      12                      \n\n\n        KBI Biopharma\n
# 13      13                     \n    LENA Research Foundation
# 14      14                                \n\n        Pearson
# 15       0                                   \n\n        HERE
# 16       1                                      \n    Precima
# 17       2                     \n\n        Allstate Insurance
# 18       3               \n\n    BMW Technology Corporation\n
# 19       4  \n\n\n        Metropolitan Water Reclamation D...
# 20       5                             \n\n\n        Google\n
# 21       6                             \n\n\n        Kaplan\n
# 22       7  \n\n    National Opinion Research Center (NORC)\n
# 23       8        \n\n\n        The Boston Consulting Group\n
# 24       9            \n\n\n        Northwestern University\n
# 25      10                            \n\n    Kelton Global\n
# 26      11            \n\n\n        Northwestern University\n
# 27      12  \n\n    National Opinion Research Center (NORC)\n
# 28      13                     \n\n        Allstate Insurance
# 29      14                    \n\n        ABBOTT LABORATORIES
# ..     ...                                                ...
# 164      0                                \n    Businessolver
# 165      1                                   \n\n        HERE
# 166      2     \n    Altius Institute for Biomedical Sciences
# 167      3                          \n\n    Allen Institute\n
# 168      4                                   \n\n    Lenati\n
# 169      5                                \n\n    HERO.Jobs\n
# 170      6                                \n\n\n        SDL\n
# 171      7                              \n\n    Z2 DataLabs\n
# 172      8               \n\n\n        Amazon Corporate LLC\n
# 173      9                                   \n\n    UMetis\n
# 174     10               \n\n\n        Amazon Corporate LLC\n
# 175     11               \n\n\n        Amazon Corporate LLC\n
# 176     12                          \n\n\n        Microsoft\n
# 177     13                               \n\n        T-Mobile
# 178     14                            \n\n        CyberCoders
# 179      0                              \n    Cognitive Scale
# 180      1                              \n    Cognitive Scale
# 181      2                                 \n\n        Indeed
# 182      3                              \n\n\n        Apple\n
# 183      4                                 \n\n\n        3M\n
# 184      5      \n\n\n        CCC Information Services Inc.\n
# 185      6                     \n\n\n        General Motors\n
# 186      7                                \n\n\n        IBM\n
# 187      8                              \n\n    LawnStarter\n
# 188      9                                \n\n\n        IBM\n
# 189     10                           \n\n\n        HomeAway\n
# 190     11                                \n\n\n        IBM\n
# 191     12                             \n\n\n        Google\n
# 192     13                              \n    Cognitive Scale
# 193     14                                     \n    MaxPoint
#
#                                                    Job  \
# 0                                       Data Scientist
# 1    Data Scientist (Curriculum Developer / Instruc...
# 2                            Machine Learning Engineer
# 3                                Senior Data Scientist
# 4    Data Scientist (Curriculum Developer / Instruc...
# 5             Senior Data Scientist - Retail Analytics
# 6    Cloud Instructor (Big Data, Machine Learning),...
# 7                         Managing Director for STROBE
# 8                                         Statistician
# 9                        Analytical Services Scientist
# 10                                 Statistical Analyst
# 11                            RESEARCH ANALYST – 16996
# 12                            PD Scientist II-DSP #230
# 13   Sr. Research Engineer: Machine Learning and Co...
# 14          Senior Research Engineer, Machine Learning
# 15                            Principal Data Scientist
# 16                                      Data Scientist
# 17                               Junior Data Scientist
# 18   Machine Learning Researcher - BMW Technology C...
# 19                 Senior Environmental Soil Scientist
# 20   Machine Learning Deployment Engineer, Professi...
# 21                               Senior Data Scientist
# 22                                        Statistician
# 23                Knowledge Analyst - Data Engineering
# 24                               Research Data Analyst
# 25                      Analyst, Quantitative Research
# 26                                 Statistical Analyst
# 27                                 Senior Statistician
# 28                               Data Scientist Intern
# 29               Statistical Data Analyst / Programmer
# ..                                                 ...
# 164                          Machine Learning Engineer
# 165     Lead Analytics Engineer - Predictive Analytics
# 166                 Computational Scientist / Engineer
# 167                Python Developer (Microscopy Tools)
# 168  Consultant, Statistical Analysis and Predictiv...
# 169    Machine Learning Engineer - Big Data, Python, R
# 170                              Senior Data Scientist
# 171    Data Science Instructor (Local Candidates ONLY)
# 172                                 Research Scientist
# 173                                  Big Data Engineer
# 174                                  Applied Scientist
# 175                                   Business Analyst
# 176                              Senior Data Scientist
# 177                                 Big Data Scientist
# 178                                     Data Scientist
# 179                                     Data Scientist
# 180               Software Engineer - Machine Learning
# 181                                      Data Engineer
# 182                              Data Science Engineer
# 183  3M HIS Specialist, Algorithm Data Engineers (M...
# 184              Data Automation & Operations Engineer
# 185  Senior Artificial Intelligence Programmer / Re...
# 186                    Watson Health - Biostatistician
# 187                              Senior Data Scientist
# 188            Entry Level Cognitive Software Engineer
# 189          Market Research Analyst - Consumer Trends
# 190  WW (CoC) - Talent & Engagement - Talent Analyt...
# 191  Cloud Instructor (Big Data, Machine Learning),...
# 192                                    Statistical NLP
# 193       Senior Data Scientist - Geospatial Analytics
#
#                                               Location  \
# 0                                 Broomfield, CO 80021
# 1                                          Boulder, CO
# 2                                       Centennial, CO
# 3                                          Boulder, CO
# 4                                          Boulder, CO
# 5                                      Westminster, CO
# 6                                    Boulder, CO 80302
# 7                                          Boulder, CO
# 8                                      Niwot, CO 80503
# 9                                          Boulder, CO
# 10                                          Denver, CO
# 11                                          Denver, CO
# 12                                         Boulder, CO
# 13                                         Boulder, CO
# 14                                      Centennial, CO
# 15                                   Chicago, IL 60601
# 16                                         Chicago, IL
# 17                                Northbrook, IL 60062
# 18                                         Chicago, IL
# 19                                         Chicago, IL
# 20                                         Chicago, IL
# 21                                         Chicago, IL
# 22                                         Chicago, IL
# 23                       Chicago, IL 60654 (Loop area)
# 24                                         Chicago, IL
# 25                                         Chicago, IL
# 26                                         Chicago, IL
# 27                                         Chicago, IL
# 28                                Northbrook, IL 60065
# 29                                     Des Plaines, IL
# ..                                                 ...
# 164                                        Seattle, WA
# 165                                  Seattle, WA 98101
# 166                                  Seattle, WA 98121
# 167  Seattle, WA 98103 (Green Lake - Wallingford area)
# 168                Seattle, WA 98119 (Queen Anne area)
# 169                                        Seattle, WA
# 170                  Seattle, WA 98199 (Magnolia area)
# 171                                       Bellevue, WA
# 172                                        Seattle, WA
# 173                 Bellevue, WA 98004 (Downtown area)
# 174                                        Seattle, WA
# 175                                        Seattle, WA
# 176                                  Redmond, WA 98052
# 177                                 Bellevue, WA 98006
# 178                                        Seattle, WA
# 179                                   Austin, TX 78730
# 180                                   Austin, TX 78730
# 181                                   Austin, TX 78731
# 182                                         Austin, TX
# 183              Austin, TX 78753 (Windsor Hills area)
# 184                                         Austin, TX
# 185                                         Austin, TX
# 186                                         Austin, TX
# 187                                         Austin, TX
# 188                                         Austin, TX
# 189                                         Austin, TX
# 190                                         Austin, TX
# 191                                         Austin, TX
# 192                                   Austin, TX 78730
# 193                                   Austin, TX 78759
#
#                                         Salary Sponsored
# 0                                          NaN      True
# 1                                          NaN      True
# 2                                          NaN      True
# 3               [<nobr>$120,000 a year</nobr>]     False
# 4                                          NaN     False
# 5                                          NaN     False
# 6                                          NaN     False
# 7    [<nobr>$100,000 - $115,000 a year</nobr>]     False
# 8                                          NaN     False
# 9                                          NaN     False
# 10                                         NaN     False
# 11     [<nobr>$57,580 - $69,098 a year</nobr>]     False
# 12                                         NaN     False
# 13                                         NaN      True
# 14                                         NaN      True
# 15                                         NaN      True
# 16                                         NaN      True
# 17                                         NaN      True
# 18                                         NaN     False
# 19    [<nobr>$93,257 - $137,114 a year</nobr>]     False
# 20                                         NaN     False
# 21                                         NaN     False
# 22                                         NaN     False
# 23                                         NaN     False
# 24                                         NaN     False
# 25                                         NaN     False
# 26                                         NaN     False
# 27                                         NaN     False
# 28                                         NaN      True
# 29                                         NaN      True
# ..                                         ...       ...
# 164                                        NaN      True
# 165                                        NaN      True
# 166                                        NaN      True
# 167                                        NaN     False
# 168                                        NaN     False
# 169             [<nobr>$160,000 a year</nobr>]     False
# 170                                        NaN     False
# 171                [<nobr>$150 an hour</nobr>]     False
# 172                                        NaN     False
# 173                                        NaN     False
# 174                                        NaN     False
# 175                                        NaN     False
# 176                                        NaN     False
# 177                                        NaN      True
# 178                                        NaN      True
# 179                                        NaN      True
# 180                                        NaN      True
# 181                                        NaN      True
# 182                                        NaN     False
# 183                                        NaN     False
# 184                                        NaN     False
# 185                                        NaN     False
# 186                                        NaN     False
# 187                                        NaN     False
# 188                                        NaN     False
# 189                                        NaN     False
# 190                                        NaN     False
# 191                                        NaN     False
# 192                                        NaN      True
# 193                                        NaN      True
#
# [194 rows x 6 columns]

# %%
## Save as csv
jobsdf.to_csv('jobScrape.csv', encoding='utf-8')

# %%
jobsdf
# Out:
#                                              Company  \
# 0                     \n    LENA Research Foundation
# 1                              \n\n    Alteryx, Inc.
# 2                                \n\n    CyberCoders
# 3                    \n\n\n    Navigant Consulting\n
# 4                                   \n\n    cliexa\n
# 5                 \n\n\n    University of Colorado\n
# 6                          \n\n    Somalogic, Inc.\n
# 7                                 \n\n\n    Oracle\n
# 8                                 \n\n\n    Ibotta\n
# 9                 \n\n\n    University of Colorado\n
# 10                              \n\n\n    Deloitte\n
# 11                              \n\n\n    Deloitte\n
# 12                         \n\n\n    Planet Pharma\n
# 13                         \n    Specialty Chemicals
# 14                     \n    Eventus Solutions Group
# 15                     \n    Eventus Solutions Group
# 16                             \n\n    Alteryx, Inc.
# 17                         \n    Specialty Chemicals
# 18                        \n\n\n    Ball Aerospace\n
# 19                           \n\n    Corgenix, Inc\n
# 20                                  \n\n\n    UCAR\n
# 21                     \n\n    Specialty Chemicals\n
# 22                                   \n\n\n    IMM\n
# 23                                \n\n\n    Archer\n
# 24          \n\n\n    Southwest Research Institute\n
# 25                                \n\n\n    OnDeck\n
# 26     \n\n    Stanley Brothers Social Enterprises\n
# 27            \n\n\n    Department Of The Interior\n
# 28                               \n\n    CyberCoders
# 29                    \n    LENA Research Foundation
# ...                                              ...
# 1899                       \n\n    RetailMeNot, Inc.
# 1900                                \n    Sense Corp
# 1901                              \n\n    MaxPoint\n
# 1902                              \n\n\n    NVIDIA\n
# 1903                      \n\n\n    Alcatel-Lucent\n
# 1904                     \n\n    Ocean Conservancy\n
# 1905                          \n\n\n    CDK Global\n
# 1906                     \n\n\n    Express Scripts\n
# 1907                     \n\n    Signature Science\n
# 1908        \n\n    The University of Texas System\n
# 1909            \n\n\n    Thermo Fisher Scientific\n
# 1910                      \n\n    Emoters Robotics\n
# 1911                                  \n\n    Indeed
# 1912                         \n\n    Main Street Hub
# 1913                                  \n\n    Indeed
# 1914                       \n\n    RetailMeNot, Inc.
# 1915                                \n    Sense Corp
# 1916                       \n\n\n    Gartner, Inc.\n
# 1917                              \n\n    MaxPoint\n
# 1918                       \n\n\n    The Jag Group\n
# 1919                              \n\n\n    Natera\n
# 1920  \n\n    TEL Technology Center, America, Inc.\n
# 1921                              \n\n    Zilliant\n
# 1922                             \n\n    Galvanize\n
# 1923                              \n\n\n    Indeed\n
# 1924       \n\n\n    University of Texas at Austin\n
# 1925                            \n\n\n    HomeAway\n
# 1926                                  \n\n    Indeed
# 1927                         \n\n    Main Street Hub
# 1928                                  \n\n    Indeed
#
#                                                     Job  \
# 0     Sr. Research Engineer: Machine Learning and Co...
# 1                   Product Manager, Advanced Analytics
# 2                                        Data Scientist
# 3                                      Research Analyst
# 4                                 Data Scientist Intern
# 5                            Professional Research Asst
# 6     Bioinformatics Assoc. II/Sr. Assoc./Analyst/Sc...
# 7     Senior Product Manager - Measurement, Oracle D...
# 8                                 Senior Data Scientist
# 9                                    Research Associate
# 10                           Big Data Senior Consultant
# 11                                     Big Data Manager
# 12                               Statistical Programmer
# 13                                   Research Scientist
# 14                                Junior Data Scientist
# 15                                Junior Data Scientist
# 16                  Product Manager, Advanced Analytics
# 17                                   Research Scientist
# 18    Administrative Associate II - National Defense...
# 19              Postdoctoral Fellow - Assay Development
# 20                                          Engineer II
# 21                                   Research Scientist
# 22                         Software Engineer ? Big Data
# 23                                    Software Engineer
# 24                SR. RESEARCH SCIENTIST - HELIOPHYSICS
# 25                        Business Intelligence Analyst
# 26                   Research and Development Scientist
# 27               Statistician, GS-1530-12 (DEU-PERM-DS)
# 28                                       Data Scientist
# 29    Sr. Research Engineer: Machine Learning and Co...
# ...                                                 ...
# 1899                                 Sr. Data Scientist
# 1900                                     Data Scientist
# 1901               Senior Data Scientist - Econometrics
# 1902  Research Scientist for Computer Vision / Machi...
# 1903                           Software Developer Co-op
# 1904   Conservation Biologist, Gulf Restoration Program
# 1905                          Business Security Officer
# 1906                  Senior Quantitative UX Researcher
# 1907                          Bioinformatics Specialist
# 1908                     Institutional Research Analyst
# 1909                              Application Scientist
# 1910  Robotics software engineer (involves machine l...
# 1911                                      Data Engineer
# 1912                                     Data Scientist
# 1913                                     Data Scientist
# 1914                                 Sr. Data Scientist
# 1915                                     Data Scientist
# 1916        Content Marketing Analyst, Gartner Research
# 1917           Senior Data Scientist - Machine Learning
# 1918           Senior Data Scientist - Machine Learning
# 1919                             Clinical Data Reporter
# 1920                                          Scientist
# 1921            Senior Software Engineer – Science Team
# 1922               Associate Instructor, Data Scientist
# 1923                                     Data Scientist
# 1924  Engineering Scientist Associate - GNSS Analyst...
# 1925                            Research Data Scientist
# 1926                                      Data Engineer
# 1927                                     Data Scientist
# 1928                                     Data Scientist
#
#                                                Location  \
# 0                                           Boulder, CO
# 1                                        Broomfield, CO
# 2                                           Boulder, CO
# 3                                           Boulder, CO
# 4                                           Boulder, CO
# 5                                           Boulder, CO
# 6                                     Boulder, CO 80301
# 7                                        Broomfield, CO
# 8                          Denver, CO 80202 (Lodo area)
# 9                                           Boulder, CO
# 10                 Denver, CO 80203 (Capitol Hill area)
# 11                 Denver, CO 80203 (Capitol Hill area)
# 12                                           Denver, CO
# 13                                           Denver, CO
# 14                                        Englewood, CO
# 15                                        Englewood, CO
# 16                                       Broomfield, CO
# 17                                           Denver, CO
# 18                                       Broomfield, CO
# 19                                 Broomfield, CO 80020
# 20                                       Broomfield, CO
# 21                                           Denver, CO
# 22                                    Boulder, CO 80302
# 23                                          Boulder, CO
# 24                                          Boulder, CO
# 25                                           Denver, CO
# 26                                    Boulder, CO 80301
# 27                                         Lakewood, CO
# 28                                          Boulder, CO
# 29                                          Boulder, CO
# ...                                                 ...
# 1899                                         Austin, TX
# 1900                                         Austin, TX
# 1901                  Austin, TX 78759 (Arboretum area)
# 1902                                         Austin, TX
# 1903                                         Austin, TX
# 1904                   Austin, TX 78701 (Downtown area)
# 1905                                         Austin, TX
# 1906                                         Austin, TX
# 1907                                         Austin, TX
# 1908                                         Austin, TX
# 1909                                         Austin, TX
# 1910                                         Austin, TX
# 1911                                         Austin, TX
# 1912                                         Austin, TX
# 1913                                         Austin, TX
# 1914                                         Austin, TX
# 1915                                         Austin, TX
# 1916                                         Austin, TX
# 1917                  Austin, TX 78759 (Arboretum area)
# 1918                 Austin, TX 73301 (St Edwards area)
# 1919                                   Austin, TX 78731
# 1920                                         Austin, TX
# 1921  Austin, TX 78704 (South Lamar-South Congress a...
# 1922                                         Austin, TX
# 1923                  Austin, TX 78759 (Arboretum area)
# 1924                                         Austin, TX
# 1925  Austin, TX 78704 (South Lamar-South Congress a...
# 1926                                         Austin, TX
# 1927                                         Austin, TX
# 1928                                         Austin, TX
#
#                                         Salary Sponsored
# 0                                          NaN      True
# 1                                          NaN      True
# 2                                          NaN      True
# 3                                          NaN     False
# 4                                          NaN     False
# 5                                          NaN     False
# 6                                          NaN     False
# 7                                          NaN     False
# 8                                          NaN     False
# 9                                          NaN     False
# 10                                         NaN     False
# 11                                         NaN     False
# 12                                         NaN     False
# 13                                         NaN      True
# 14                                         NaN      True
# 15                                         NaN      True
# 16                                         NaN      True
# 17                                         NaN      True
# 18                                         NaN     False
# 19                                         NaN     False
# 20                                         NaN     False
# 21                                         NaN     False
# 22                                         NaN     False
# 23                                         NaN     False
# 24                                         NaN     False
# 25                                         NaN     False
# 26                                         NaN     False
# 27     [<nobr>$76,341 - $99,243 a year</nobr>]     False
# 28                                         NaN      True
# 29                                         NaN      True
# ...                                        ...       ...
# 1899                                       NaN      True
# 1900                                       NaN      True
# 1901                                       NaN     False
# 1902                                       NaN     False
# 1903                                       NaN     False
# 1904                                       NaN     False
# 1905                                       NaN     False
# 1906                                       NaN     False
# 1907                                       NaN     False
# 1908             [<nobr>$4,459 a month</nobr>]     False
# 1909                                       NaN     False
# 1910  [<nobr>$70,000 - $100,000 a year</nobr>]     False
# 1911                                       NaN      True
# 1912                                       NaN      True
# 1913                                       NaN      True
# 1914                                       NaN      True
# 1915                                       NaN      True
# 1916                                       NaN     False
# 1917                                       NaN     False
# 1918                                       NaN     False
# 1919                                       NaN     False
# 1920                                       NaN     False
# 1921                                       NaN     False
# 1922                                       NaN     False
# 1923                                       NaN     False
# 1924    [<nobr>$5,400 - $6,500 a month</nobr>]     False
# 1925                                       NaN     False
# 1926                                       NaN      True
# 1927                                       NaN      True
# 1928                                       NaN      True
#
# [1929 rows x 5 columns]
